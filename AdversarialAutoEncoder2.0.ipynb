# %% [markdown]
# # AutoEncoder Adversario

# %% [markdown]
# ## Preparacion del entorno

# %% [markdown]
# Librerias

# %%
import tensorflow as tf
from tensorflow import keras

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
from keras import Sequential
from keras.applications import mobilenet
from keras.layers import Input, Dense, LeakyReLU, GlobalAveragePooling2D, Reshape
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# Num GPUs Available:  1

# %% [markdown]
# Variables globales

# %%
ruta = "adversarialautoencoder2.0/wasserstein"
nombre = "AAE2.0_15000e"

# %% [markdown]
# Creamos las carpetas para almacenar el output

# %%
try:
    os.makedirs(ruta)
except OSError:
    print("Carpeta %s ya existe" % (ruta))
try:
    os.mkdir(ruta+"/output")
except OSError:
    print("Carpeta %s ya existe" % (ruta+"/output"))

# %% [markdown]
# Funcion para extraer los datos de los ficheros

# %%
# https://www.cs.toronto.edu/~kriz/cifar.html
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin')
    return dict

# %% [markdown]
# Extraemos los datos del fichero.

# %%
batch1 = unpickle("Input\cifar-10-batches-py\data_batch_1")
batch2 = unpickle("Input\cifar-10-batches-py\data_batch_2")
batch3 = unpickle("Input\cifar-10-batches-py\data_batch_3")
batch4 = unpickle("Input\cifar-10-batches-py\data_batch_4")
batch5 = unpickle("Input\cifar-10-batches-py\data_batch_5")

# %% [markdown]
# En cifar10 los datos estan almacenados en un diccionario que contiene el nombre del lote, las etiquetas para clasificacion, los datos (imagenes) y los nombres de fichero correspondientes.

# %%
print(batch1.keys())
for i in batch1:
    print(i, type(batch1[i]))
# Out:
# dict_keys(['batch_label', 'labels', 'data', 'filenames'])
# batch_label <class 'str'>
# labels <class 'list'>
# data <class 'numpy.ndarray'>
# filenames <class 'list'>

# %% [markdown]
# Las imagenes vienen en el modo ``channelsfirst``, en este modo, tenemos 3 matrices de la dimension de la imagen, una para cada canal. Muchas de las funciones admiten por defecto el modo ``chanelslast`` en el que tenemos una matriz de la dimension de la imagen y cada posicion tiene un vector con los codigos de color de cada punto.
#
# Por simplicidad, como paso de preprocesamiento, voy a transformar las imagenes de ``channelsfirst`` a ``channelslast``.

# %%
# https://www.binarystudy.com/2021/09/how-to-load-preprocess-visualize-CIFAR-10-and-CIFAR-100.html
imagen = batch1["data"][0]
imagen = imagen.reshape(3,32,32)
imagen=imagen.transpose(1,2,0)
print(imagen.shape)
# Out:
# (32, 32, 3)

# %%
plt.imshow(imagen)

# %% [markdown]
# ## Preparacion de los datos

# %% [markdown]
# Cargamos todas las imagenes de entrenamiento en la variable ``X_train`` y borramos todo lo demás ya que no lo vamos a utilizar.

# %%
print(batch1["data"].shape)
X_train = batch1["data"].reshape(10000, 3, 32, 32)
del batch1
X_train = np.concatenate((X_train, batch2["data"].reshape(10000, 3, 32, 32)))
del batch2
X_train = np.concatenate((X_train, batch3["data"].reshape(10000, 3, 32, 32)))
del batch3
X_train = np.concatenate((X_train, batch4["data"].reshape(10000, 3, 32, 32)))
del batch4
X_train = np.concatenate((X_train, batch5["data"].reshape(10000, 3, 32, 32)))
del batch5
X_train = X_train.transpose(0,2,3,1)
X_train=X_train/255
# Out:
# (10000, 3072)

# %%
print(X_train.shape)
plt.figure()
f, arrx = plt.subplots(1,2)
arrx[0].imshow(X_train[np.random.randint(0,X_train.shape[0])])
arrx[1].imshow(X_train[np.random.randint(0,X_train.shape[0])])
for a in arrx:
    a.axis("off")
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ## Arquitectura del ``Autoencoder``

# %% [markdown]
# Tamaño de la capa latente:

# %%
dim_latente = 20

# %% [markdown]
# Tamaño de las imagenes:

# %%
img_shape = X_train[0].shape

# %% [markdown]
# ### Regla de la piramide geometrica

# %% [markdown]
# La regla de la piramide geometrica sirve para ayudar determinar el tamaño de las capas ocultas en base al tamaño de las capas de input y output y al numero de capas ocultas.
#
# Esta aproximacion esta propuesta por Masters(1993):
# >  "For a three layer network with n input and m output neurons, the hidden layer would have sqrt(N * M) neurons."
# >
# > -- <cite> Masters, Timothy. Pratical neural network recipes in C++. Morgan Kaufmann, 1993.</cite>
#
# [Enlace al artículo](https://eulertech.wordpress.com/2018/01/02/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-network/)

# %%
def pyramid_rule(h_layers, input_size, output_size):
    if h_layers < 1:
        print("No layers")
        return
    print("Layers for input %d and output %d:" % (input_size,  output_size))
    rate = (input_size/output_size)**(1/(h_layers+1))
    for l in range(h_layers):
        layer_size = output_size*(rate**(h_layers-l))
        layer_size = round(layer_size)
        print("Layer %d: %d neurons" % (l+1, layer_size))
    return

# %% [markdown]
# ### EMD(Earth Mover's Distance)

# %% [markdown]
# EMD es una medida de distancia entre distribuciones de probabilidad, que consiste en representar ambas distribuciones como montones de tierra, en los que la distancia se determina en cuanto es el trabajo minimo que llevaria transformar un monticulo en otro. Matematicamente a EMD se la conoce como la métrica de Wasserstein.
#
# Segun [este artículo](https://machinelearningmastery.com/how-to-implement-wasserstein-loss-for-generative-adversarial-networks/) esta metrica se puede aplicar de la siguiente manera:

# %%
def wasserstein_loss(y_true, y_pred):
	return keras.backend.mean(y_true * y_pred)

# %% [markdown]
# ### Encoder

# %% [markdown]
# El ``encoder`` va a ser un modelo basado en ``transfer learning``, vamos a tomar la red de ``mobilenet``, entranada para imagenes de ``imagenet`` sin las capa de clasificacion final, con una entrada de tamaño _img\_shape_ y en el output colocamos la 'representacion latente' una codificacion de la imagen que nos permitiría reconstruirla con un ``decoder``.

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/mobilenet/preprocess_input
# https://keras.io/guides/transfer_learning/
def build_encoder(dim_latente, img_shape):
    inputs = Input(shape=img_shape)
    x=tf.cast(inputs, tf.float32)
    #x=keras.applications.mobilenet.preprocess_input(x)  #dataformat por defecto es chanel last
    core = mobilenet.MobileNet(input_shape=(img_shape), weights="imagenet", include_top=False)
    core.trainable = False
    model = core(x, training=False)
    model = GlobalAveragePooling2D()(model)
    repr_latente = keras.layers.Dense(dim_latente)(model)
    return keras.Model(inputs, repr_latente)

# %% [markdown]
# ### Decoder

# %% [markdown]
# El ``decoder`` toma la codificacion latente y decodifica en una imagen. En este caso vamos a utilizar la regla de la piramide geometrica para determinar las capas, en este caso van a ser 2 capas ocultas.

# %%
pyramid_rule(2, dim_latente, np.prod(img_shape))
# Out:
# Layers for input 20 and output 3072:
# Layer 1: 107 neurons
# Layer 2: 574 neurons

# %%
def build_myDecoder(dim_latente, img_shape):
    model = keras.Sequential()
    model.add(Dense(107, input_dim=dim_latente))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(574))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(np.prod(img_shape), activation=keras.activations.tanh))
    #model.add(ReLU())
    model.add(Reshape(img_shape))
    z = Input(shape=(dim_latente))
    img =  model(z)
    return keras.Model(z,img)

# %% [markdown]
# ### Discriminator

# %% [markdown]
# El discriminador va a tener como entrada la codificacion latente de las imagenes y como salida una neurona que discrimina entre imagenes "reales" y "falsas". De esta forma entrenamos al encoder para que codifique con la distribucion que usemos para generar las "imagenes reales", en este caso, una distribución normal.

# %%
pyramid_rule(2, dim_latente, 1)
# Out:
# Layers for input 20 and output 1:
# Layer 1: 7 neurons
# Layer 2: 3 neurons

# %%
def build_discriminator(dim_latente):
    model = Sequential()
    model.add(Dense(7, input_dim=dim_latente))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation="sigmoid"))
    encoded = Input(shape=dim_latente)
    valid = model(encoded)
    return keras.Model(encoded, valid)

# %% [markdown]
# ### Red completa

# %% [markdown]
# Parametros

# %%
optimizer = keras.optimizers.Adam(0.0002, 0.5)
loss=wasserstein_loss
#loss="mse"

# %% [markdown]
# Discriminador

# %%
discriminator = build_discriminator(dim_latente)
discriminator.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# Encoder y decoder

# %%
encoder = build_encoder(dim_latente, img_shape)
decoder = build_myDecoder(dim_latente, img_shape)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# Autoencoder

# %%
# el encoder toma un imagen y la codifica y el decoder toma la codificacion e intenta regenerar la imagen
img = Input(shape=img_shape)
encoded = encoder(img)
reconstructed = decoder(encoded)

# para el autoencoder adversario solo queremos entrenar el generador, no el discriminador
discriminator.trainable=False

# El discriminador evalua la validez de la codificacion
validez = discriminator(encoded)

# Autoencoder adversario 
a_autoencoder = keras.Model(img, [reconstructed, validez])
a_autoencoder.compile(loss=["mse", "binary_crossentropy"], loss_weights=[0.999, 0.001], optimizer=optimizer)

# %% [markdown]
# ## Entrenamiento

# %% [markdown]
# ### Funciones de muestreo

# %%
def sample_imgs(dataset, model, epoch, sample_size=5, save_imgs=True):
    # Tomamos sample_size imagenes de muestra
    ids = np.random.randint(0,dataset.shape[0], sample_size)
    sample=dataset[ids]
    # Intentamos regenerar las imagenes
    gen_img = model.predict(sample)[0]
    # Guardamos una grafica con la muestra (arriba) y las imagenes generadas (abajo)
    f, axxs = plt.subplots(2,sample_size)
    for j in range(sample_size):
        axxs[0,j].imshow(sample[j])
        axxs[1,j].imshow(gen_img[j])
    for i in axxs:
        for j in i:
            j.axis("off")
    if save_imgs:
        f.savefig(ruta+"/output/generationCIFAR10_e%d.png" % (epoch))
        plt.close()

# %%
def true_sampler(dim_latente, batch_size):
    return np.random.normal(size=(batch_size, dim_latente))

# %%
def generate_samples(dim_latente, decoder, epoch):
    sample_shape = (5,5)
    latent_samples = true_sampler(dim_latente, np.prod(sample_shape))
    samples=decoder.predict(latent_samples)#*0.5 +0.5
    fig, axxs = plt.subplots(sample_shape[0], sample_shape[1])
    s=0
    for i in range(sample_shape[0]):
        for j in range(sample_shape[1]):
            axxs[i,j].imshow(samples[s])
            axxs[i,j].axis("off")
            s+=1
    fig.savefig(ruta+"\output\\"+nombre+"progresscifar10_e%d.png" % (epoch))
    plt.close()

# %%
sample_from = unpickle("Input\cifar-10-batches-py\\test_batch")
sample_from = sample_from["data"]
sample_from.shape
# Out:
# (10000, 3072)

# %%
sample_from = sample_from.reshape(10000,3,32,32)
sample_from = sample_from.transpose(0,2,3,1)
sample_from = sample_from/255

# %%
plt.imshow(sample_from[np.random.randint(0,sample_from.shape[0])])

# %% [markdown]
# ### Ciclo de entrenamiento

# %%
# https://github.com/mrquincle/keras-adversarial-autoencoders/blob/master/Keras%20Adversarial%20Autoencoder%20MNIST.ipynb
epochs=15000
batch_size=120
sample_interval=1000

valid = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))

for epoch in range(epochs+1):
    # lote de imagenes
    idx = np.random.randint(0, X_train.shape[0], batch_size)
    imgs = X_train[idx]

    latent_fake = encoder.predict(imgs)
    latent_true =true_sampler(dim_latente, batch_size)

    #entrenamos el discriminador
    dis_loss_real = discriminator.train_on_batch(latent_true, valid)
    dis_loss_fake = discriminator.train_on_batch(latent_fake, fake)
    dis_avg_loss = 0.5*np.add(dis_loss_fake, dis_loss_real)

    # entrenamos al autoencoder
    aae_loss = a_autoencoder.train_on_batch(imgs,[imgs, valid])
    
    # monitorizamos el progreso
    if epoch % 10==0:
        print("Epoch: %d Disc: (loss = %f, acc = %.2f%%) AAE: (mse = %f, b_ce = %f)" % (epoch, dis_avg_loss[0], 100*dis_avg_loss[1], aae_loss[0], aae_loss[1]))
    # Hacemos una muestra visual
    if epoch % sample_interval==0:
        # sample_imgs(sample_from, autoencoder, epoch)
        generate_samples(dim_latente, decoder, epoch)
# Out:
# Epoch: 0 Disc: (loss = 0.203635, acc = 65.83%) AAE: (mse = 0.284848, b_ce = 0.284352)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 10 Disc: (loss = 0.193953, acc = 63.33%) AAE: (mse = 0.242564, b_ce = 0.242022)
# Epoch: 20 Disc: (loss = 0.204391, acc = 66.67%) AAE: (mse = 0.107524, b_ce = 0.106827)
# Epoch: 30 Disc: (loss = 0.191478, acc = 62.92%) AAE: (mse = 0.082563, b_ce = 0.081824)
# Epoch: 40 Disc: (loss = 0.193699, acc = 60.83%) AAE: (mse = 0.078632, b_ce = 0.077886)
# Epoch: 50 Disc: (loss = 0.183295, acc = 62.08%) AAE: (mse = 0.085460, b_ce = 0.084706)
# Epoch: 60 Disc: (loss = 0.191138, acc = 61.67%) AAE: (mse = 0.078783, b_ce = 0.078023)
# Epoch: 70 Disc: (loss = 0.178228, acc = 62.92%) AAE: (mse = 0.076975, b_ce = 0.076203)
# Epoch: 80 Disc: (loss = 0.172548, acc = 60.42%) AAE: (mse = 0.075549, b_ce = 0.074771)
# Epoch: 90 Disc: (loss = 0.151903, acc = 55.42%) AAE: (mse = 0.071029, b_ce = 0.070230)
# Epoch: 100 Disc: (loss = 0.156358, acc = 56.67%) AAE: (mse = 0.071308, b_ce = 0.070509)
# Epoch: 110 Disc: (loss = 0.172092, acc = 59.17%) AAE: (mse = 0.071985, b_ce = 0.071169)
# Epoch: 120 Disc: (loss = 0.169274, acc = 59.17%) AAE: (mse = 0.073679, b_ce = 0.072858)
# Epoch: 130 Disc: (loss = 0.155549, acc = 57.50%) AAE: (mse = 0.074252, b_ce = 0.073422)
# Epoch: 140 Disc: (loss = 0.150260, acc = 54.17%) AAE: (mse = 0.066595, b_ce = 0.065751)
# Epoch: 150 Disc: (loss = 0.144962, acc = 55.42%) AAE: (mse = 0.067010, b_ce = 0.066148)
# Epoch: 160 Disc: (loss = 0.148578, acc = 52.08%) AAE: (mse = 0.066191, b_ce = 0.065338)
# Epoch: 170 Disc: (loss = 0.139344, acc = 52.92%) AAE: (mse = 0.071407, b_ce = 0.070529)
# Epoch: 180 Disc: (loss = 0.146724, acc = 55.83%) AAE: (mse = 0.065278, b_ce = 0.064361)
# Epoch: 190 Disc: (loss = 0.152644, acc = 55.42%) AAE: (mse = 0.061728, b_ce = 0.060814)
# Epoch: 200 Disc: (loss = 0.132152, acc = 53.33%) AAE: (mse = 0.064441, b_ce = 0.063507)
# Epoch: 210 Disc: (loss = 0.121089, acc = 51.67%) AAE: (mse = 0.063119, b_ce = 0.062173)
# Epoch: 220 Disc: (loss = 0.136419, acc = 53.75%) AAE: (mse = 0.059751, b_ce = 0.058788)
# Epoch: 230 Disc: (loss = 0.119736, acc = 53.33%) AAE: (mse = 0.062073, b_ce = 0.061108)
# Epoch: 240 Disc: (loss = 0.121901, acc = 52.08%) AAE: (mse = 0.058443, b_ce = 0.057442)
# Epoch: 250 Disc: (loss = 0.127007, acc = 52.92%) AAE: (mse = 0.069177, b_ce = 0.068176)
# Epoch: 260 Disc: (loss = 0.115538, acc = 52.92%) AAE: (mse = 0.056298, b_ce = 0.055287)
# Epoch: 270 Disc: (loss = 0.111750, acc = 51.25%) AAE: (mse = 0.068823, b_ce = 0.067820)
# Epoch: 280 Disc: (loss = 0.113181, acc = 50.00%) AAE: (mse = 0.063026, b_ce = 0.061999)
# Epoch: 290 Disc: (loss = 0.113036, acc = 52.08%) AAE: (mse = 0.064452, b_ce = 0.063417)
# Epoch: 300 Disc: (loss = 0.109501, acc = 52.08%) AAE: (mse = 0.064707, b_ce = 0.063656)
# Epoch: 310 Disc: (loss = 0.104735, acc = 52.50%) AAE: (mse = 0.061435, b_ce = 0.060381)
# Epoch: 320 Disc: (loss = 0.093643, acc = 51.25%) AAE: (mse = 0.061316, b_ce = 0.060230)
# Epoch: 330 Disc: (loss = 0.101459, acc = 50.83%) AAE: (mse = 0.061658, b_ce = 0.060570)
# Epoch: 340 Disc: (loss = 0.106527, acc = 51.25%) AAE: (mse = 0.061553, b_ce = 0.060459)
# Epoch: 350 Disc: (loss = 0.107615, acc = 52.08%) AAE: (mse = 0.063675, b_ce = 0.062572)
# Epoch: 360 Disc: (loss = 0.099062, acc = 50.83%) AAE: (mse = 0.063537, b_ce = 0.062419)
# Epoch: 370 Disc: (loss = 0.092352, acc = 51.25%) AAE: (mse = 0.061974, b_ce = 0.060849)
# Epoch: 380 Disc: (loss = 0.085597, acc = 50.42%) AAE: (mse = 0.057518, b_ce = 0.056384)
# Epoch: 390 Disc: (loss = 0.086210, acc = 50.83%) AAE: (mse = 0.058705, b_ce = 0.057544)
# Epoch: 400 Disc: (loss = 0.077999, acc = 50.42%) AAE: (mse = 0.065529, b_ce = 0.064363)
# Epoch: 410 Disc: (loss = 0.076911, acc = 50.00%) AAE: (mse = 0.064065, b_ce = 0.062903)
# Epoch: 420 Disc: (loss = 0.079886, acc = 50.42%) AAE: (mse = 0.060629, b_ce = 0.059461)
# Epoch: 430 Disc: (loss = 0.074051, acc = 50.00%) AAE: (mse = 0.067224, b_ce = 0.066033)
# Epoch: 440 Disc: (loss = 0.073723, acc = 50.00%) AAE: (mse = 0.059286, b_ce = 0.058090)
# Epoch: 450 Disc: (loss = 0.071579, acc = 50.00%) AAE: (mse = 0.059076, b_ce = 0.057862)
# Epoch: 460 Disc: (loss = 0.064986, acc = 50.00%) AAE: (mse = 0.061199, b_ce = 0.059970)
# Epoch: 470 Disc: (loss = 0.068571, acc = 50.00%) AAE: (mse = 0.060637, b_ce = 0.059397)
# Epoch: 480 Disc: (loss = 0.059575, acc = 50.00%) AAE: (mse = 0.058720, b_ce = 0.057469)
# Epoch: 490 Disc: (loss = 0.064090, acc = 50.00%) AAE: (mse = 0.058434, b_ce = 0.057172)
# Epoch: 500 Disc: (loss = 0.067677, acc = 50.00%) AAE: (mse = 0.064124, b_ce = 0.062847)
# Epoch: 510 Disc: (loss = 0.075533, acc = 50.00%) AAE: (mse = 0.070200, b_ce = 0.068925)
# Epoch: 520 Disc: (loss = 0.065761, acc = 50.42%) AAE: (mse = 0.063983, b_ce = 0.062682)
# Epoch: 530 Disc: (loss = 0.060336, acc = 50.00%) AAE: (mse = 0.057221, b_ce = 0.055891)
# Epoch: 540 Disc: (loss = 0.059689, acc = 50.00%) AAE: (mse = 0.060296, b_ce = 0.058961)
# Epoch: 550 Disc: (loss = 0.045191, acc = 50.00%) AAE: (mse = 0.059424, b_ce = 0.058072)
# Epoch: 560 Disc: (loss = 0.061140, acc = 50.00%) AAE: (mse = 0.065510, b_ce = 0.064155)
# Epoch: 570 Disc: (loss = 0.049546, acc = 50.00%) AAE: (mse = 0.061513, b_ce = 0.060141)
# Epoch: 580 Disc: (loss = 0.056719, acc = 50.00%) AAE: (mse = 0.066633, b_ce = 0.065260)
# Epoch: 590 Disc: (loss = 0.047898, acc = 50.00%) AAE: (mse = 0.063253, b_ce = 0.061865)
# Epoch: 600 Disc: (loss = 0.053912, acc = 50.00%) AAE: (mse = 0.063349, b_ce = 0.061956)
# Epoch: 610 Disc: (loss = 0.053536, acc = 50.00%) AAE: (mse = 0.060086, b_ce = 0.058680)
# Epoch: 620 Disc: (loss = 0.048544, acc = 50.00%) AAE: (mse = 0.058412, b_ce = 0.056977)
# Epoch: 630 Disc: (loss = 0.058300, acc = 50.00%) AAE: (mse = 0.060373, b_ce = 0.058915)
# Epoch: 640 Disc: (loss = 0.044924, acc = 50.00%) AAE: (mse = 0.065170, b_ce = 0.063720)
# Epoch: 650 Disc: (loss = 0.036154, acc = 50.00%) AAE: (mse = 0.058195, b_ce = 0.056717)
# Epoch: 660 Disc: (loss = 0.045470, acc = 50.00%) AAE: (mse = 0.060661, b_ce = 0.059190)
# Epoch: 670 Disc: (loss = 0.033834, acc = 50.00%) AAE: (mse = 0.063084, b_ce = 0.061592)
# Epoch: 680 Disc: (loss = 0.039923, acc = 50.00%) AAE: (mse = 0.059554, b_ce = 0.058037)
# Epoch: 690 Disc: (loss = 0.035141, acc = 50.00%) AAE: (mse = 0.062432, b_ce = 0.060917)
# Epoch: 700 Disc: (loss = 0.035836, acc = 50.00%) AAE: (mse = 0.061607, b_ce = 0.060069)
# Epoch: 710 Disc: (loss = 0.041161, acc = 50.00%) AAE: (mse = 0.065193, b_ce = 0.063647)
# Epoch: 720 Disc: (loss = 0.037120, acc = 50.00%) AAE: (mse = 0.060036, b_ce = 0.058475)
# Epoch: 730 Disc: (loss = 0.031300, acc = 50.00%) AAE: (mse = 0.063228, b_ce = 0.061646)
# Epoch: 740 Disc: (loss = 0.031556, acc = 50.00%) AAE: (mse = 0.062966, b_ce = 0.061379)
# Epoch: 750 Disc: (loss = 0.030466, acc = 50.00%) AAE: (mse = 0.066804, b_ce = 0.065201)
# Epoch: 760 Disc: (loss = 0.033027, acc = 50.00%) AAE: (mse = 0.062620, b_ce = 0.061000)
# Epoch: 770 Disc: (loss = 0.025948, acc = 50.00%) AAE: (mse = 0.057327, b_ce = 0.055688)
# Epoch: 780 Disc: (loss = 0.031206, acc = 50.00%) AAE: (mse = 0.057078, b_ce = 0.055432)
# Epoch: 790 Disc: (loss = 0.028322, acc = 50.00%) AAE: (mse = 0.059496, b_ce = 0.057823)
# Epoch: 800 Disc: (loss = 0.027163, acc = 50.00%) AAE: (mse = 0.061670, b_ce = 0.060003)
# Epoch: 810 Disc: (loss = 0.025469, acc = 50.00%) AAE: (mse = 0.060106, b_ce = 0.058421)
# Epoch: 820 Disc: (loss = 0.029141, acc = 50.00%) AAE: (mse = 0.067433, b_ce = 0.065732)
# Epoch: 830 Disc: (loss = 0.025856, acc = 50.00%) AAE: (mse = 0.063515, b_ce = 0.061812)
# Epoch: 840 Disc: (loss = 0.024647, acc = 50.00%) AAE: (mse = 0.069264, b_ce = 0.067540)
# Epoch: 850 Disc: (loss = 0.023953, acc = 50.00%) AAE: (mse = 0.055706, b_ce = 0.053966)
# Epoch: 860 Disc: (loss = 0.028636, acc = 50.00%) AAE: (mse = 0.060307, b_ce = 0.058552)
# Epoch: 870 Disc: (loss = 0.023584, acc = 50.00%) AAE: (mse = 0.064042, b_ce = 0.062287)
# Epoch: 880 Disc: (loss = 0.023747, acc = 50.00%) AAE: (mse = 0.059054, b_ce = 0.057269)
# Epoch: 890 Disc: (loss = 0.025249, acc = 50.00%) AAE: (mse = 0.060968, b_ce = 0.059181)
# Epoch: 900 Disc: (loss = 0.018127, acc = 50.00%) AAE: (mse = 0.061867, b_ce = 0.060059)
# Epoch: 910 Disc: (loss = 0.019139, acc = 50.00%) AAE: (mse = 0.065611, b_ce = 0.063795)
# Epoch: 920 Disc: (loss = 0.016124, acc = 50.00%) AAE: (mse = 0.066476, b_ce = 0.064639)
# Epoch: 930 Disc: (loss = 0.018233, acc = 50.00%) AAE: (mse = 0.059743, b_ce = 0.057882)
# Epoch: 940 Disc: (loss = 0.018391, acc = 50.00%) AAE: (mse = 0.060347, b_ce = 0.058484)
# Epoch: 950 Disc: (loss = 0.016444, acc = 50.00%) AAE: (mse = 0.061241, b_ce = 0.059365)
# Epoch: 960 Disc: (loss = 0.020079, acc = 50.00%) AAE: (mse = 0.062813, b_ce = 0.060918)
# Epoch: 970 Disc: (loss = 0.016732, acc = 50.00%) AAE: (mse = 0.063352, b_ce = 0.061442)
# Epoch: 980 Disc: (loss = 0.015955, acc = 50.00%) AAE: (mse = 0.058848, b_ce = 0.056924)
# Epoch: 990 Disc: (loss = 0.015819, acc = 50.00%) AAE: (mse = 0.062769, b_ce = 0.060833)
# Epoch: 1000 Disc: (loss = 0.016057, acc = 50.00%) AAE: (mse = 0.060772, b_ce = 0.058824)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 1010 Disc: (loss = 0.014224, acc = 50.00%) AAE: (mse = 0.062399, b_ce = 0.060439)
# Epoch: 1020 Disc: (loss = 0.013593, acc = 50.00%) AAE: (mse = 0.058045, b_ce = 0.056066)
# Epoch: 1030 Disc: (loss = 0.014493, acc = 50.00%) AAE: (mse = 0.067045, b_ce = 0.065071)
# Epoch: 1040 Disc: (loss = 0.013319, acc = 50.00%) AAE: (mse = 0.066802, b_ce = 0.064808)
# Epoch: 1050 Disc: (loss = 0.012664, acc = 50.00%) AAE: (mse = 0.061398, b_ce = 0.059378)
# Epoch: 1060 Disc: (loss = 0.013183, acc = 50.00%) AAE: (mse = 0.062111, b_ce = 0.060081)
# Epoch: 1070 Disc: (loss = 0.011220, acc = 50.00%) AAE: (mse = 0.064325, b_ce = 0.062292)
# Epoch: 1080 Disc: (loss = 0.011726, acc = 50.00%) AAE: (mse = 0.062639, b_ce = 0.060587)
# Epoch: 1090 Disc: (loss = 0.012781, acc = 50.00%) AAE: (mse = 0.064769, b_ce = 0.062694)
# Epoch: 1100 Disc: (loss = 0.013667, acc = 50.00%) AAE: (mse = 0.062249, b_ce = 0.060161)
# Epoch: 1110 Disc: (loss = 0.011947, acc = 50.00%) AAE: (mse = 0.064328, b_ce = 0.062222)
# Epoch: 1120 Disc: (loss = 0.009018, acc = 50.00%) AAE: (mse = 0.059142, b_ce = 0.057022)
# Epoch: 1130 Disc: (loss = 0.012698, acc = 50.00%) AAE: (mse = 0.066706, b_ce = 0.064581)
# Epoch: 1140 Disc: (loss = 0.009595, acc = 50.00%) AAE: (mse = 0.063627, b_ce = 0.061482)
# Epoch: 1150 Disc: (loss = 0.010200, acc = 50.00%) AAE: (mse = 0.068656, b_ce = 0.066505)
# Epoch: 1160 Disc: (loss = 0.008235, acc = 50.00%) AAE: (mse = 0.060377, b_ce = 0.058199)
# Epoch: 1170 Disc: (loss = 0.010802, acc = 50.00%) AAE: (mse = 0.065501, b_ce = 0.063310)
# Epoch: 1180 Disc: (loss = 0.008413, acc = 50.00%) AAE: (mse = 0.058024, b_ce = 0.055821)
# Epoch: 1190 Disc: (loss = 0.008960, acc = 50.00%) AAE: (mse = 0.062500, b_ce = 0.060284)
# Epoch: 1200 Disc: (loss = 0.008377, acc = 50.00%) AAE: (mse = 0.065760, b_ce = 0.063530)
# Epoch: 1210 Disc: (loss = 0.010445, acc = 50.00%) AAE: (mse = 0.061619, b_ce = 0.059354)
# Epoch: 1220 Disc: (loss = 0.009955, acc = 50.00%) AAE: (mse = 0.063664, b_ce = 0.061388)
# Epoch: 1230 Disc: (loss = 0.008002, acc = 50.00%) AAE: (mse = 0.062959, b_ce = 0.060680)
# Epoch: 1240 Disc: (loss = 0.008520, acc = 50.00%) AAE: (mse = 0.060955, b_ce = 0.058655)
# Epoch: 1250 Disc: (loss = 0.007077, acc = 50.00%) AAE: (mse = 0.061738, b_ce = 0.059428)
# Epoch: 1260 Disc: (loss = 0.009320, acc = 50.00%) AAE: (mse = 0.062935, b_ce = 0.060612)
# Epoch: 1270 Disc: (loss = 0.007343, acc = 50.00%) AAE: (mse = 0.061045, b_ce = 0.058699)
# Epoch: 1280 Disc: (loss = 0.006365, acc = 50.00%) AAE: (mse = 0.057847, b_ce = 0.055479)
# Epoch: 1290 Disc: (loss = 0.007923, acc = 50.00%) AAE: (mse = 0.062003, b_ce = 0.059628)
# Epoch: 1300 Disc: (loss = 0.007412, acc = 50.00%) AAE: (mse = 0.061505, b_ce = 0.059114)
# Epoch: 1310 Disc: (loss = 0.008386, acc = 50.00%) AAE: (mse = 0.062221, b_ce = 0.059819)
# Epoch: 1320 Disc: (loss = 0.007411, acc = 50.00%) AAE: (mse = 0.060542, b_ce = 0.058115)
# Epoch: 1330 Disc: (loss = 0.007268, acc = 50.00%) AAE: (mse = 0.062295, b_ce = 0.059866)
# Epoch: 1340 Disc: (loss = 0.006699, acc = 50.00%) AAE: (mse = 0.062794, b_ce = 0.060345)
# Epoch: 1350 Disc: (loss = 0.008876, acc = 50.00%) AAE: (mse = 0.063883, b_ce = 0.061433)
# Epoch: 1360 Disc: (loss = 0.006528, acc = 50.00%) AAE: (mse = 0.068564, b_ce = 0.066093)
# Epoch: 1370 Disc: (loss = 0.004930, acc = 50.00%) AAE: (mse = 0.068531, b_ce = 0.066037)
# Epoch: 1380 Disc: (loss = 0.006565, acc = 50.00%) AAE: (mse = 0.054033, b_ce = 0.051510)
# Epoch: 1390 Disc: (loss = 0.004808, acc = 50.00%) AAE: (mse = 0.061315, b_ce = 0.058780)
# Epoch: 1400 Disc: (loss = 0.007118, acc = 50.00%) AAE: (mse = 0.064892, b_ce = 0.062344)
# Epoch: 1410 Disc: (loss = 0.005604, acc = 50.00%) AAE: (mse = 0.060857, b_ce = 0.058311)
# Epoch: 1420 Disc: (loss = 0.005916, acc = 50.00%) AAE: (mse = 0.065054, b_ce = 0.062481)
# Epoch: 1430 Disc: (loss = 0.005310, acc = 50.00%) AAE: (mse = 0.064103, b_ce = 0.061512)
# Epoch: 1440 Disc: (loss = 0.005342, acc = 50.00%) AAE: (mse = 0.059310, b_ce = 0.056704)
# Epoch: 1450 Disc: (loss = 0.005031, acc = 50.00%) AAE: (mse = 0.062209, b_ce = 0.059592)
# Epoch: 1460 Disc: (loss = 0.005065, acc = 50.00%) AAE: (mse = 0.063287, b_ce = 0.060656)
# Epoch: 1470 Disc: (loss = 0.004811, acc = 50.00%) AAE: (mse = 0.065147, b_ce = 0.062514)
# Epoch: 1480 Disc: (loss = 0.005311, acc = 50.00%) AAE: (mse = 0.063716, b_ce = 0.061063)
# Epoch: 1490 Disc: (loss = 0.005693, acc = 50.00%) AAE: (mse = 0.066286, b_ce = 0.063606)
# Epoch: 1500 Disc: (loss = 0.005208, acc = 50.00%) AAE: (mse = 0.055796, b_ce = 0.053094)
# Epoch: 1510 Disc: (loss = 0.004227, acc = 50.00%) AAE: (mse = 0.064768, b_ce = 0.062071)
# Epoch: 1520 Disc: (loss = 0.003678, acc = 50.00%) AAE: (mse = 0.061951, b_ce = 0.059240)
# Epoch: 1530 Disc: (loss = 0.003862, acc = 50.00%) AAE: (mse = 0.065447, b_ce = 0.062717)
# Epoch: 1540 Disc: (loss = 0.004032, acc = 50.00%) AAE: (mse = 0.069187, b_ce = 0.066437)
# Epoch: 1550 Disc: (loss = 0.003559, acc = 50.00%) AAE: (mse = 0.063789, b_ce = 0.061028)
# Epoch: 1560 Disc: (loss = 0.004020, acc = 50.00%) AAE: (mse = 0.068702, b_ce = 0.065924)
# Epoch: 1570 Disc: (loss = 0.003915, acc = 50.00%) AAE: (mse = 0.059807, b_ce = 0.057012)
# Epoch: 1580 Disc: (loss = 0.003179, acc = 50.00%) AAE: (mse = 0.063133, b_ce = 0.060327)
# Epoch: 1590 Disc: (loss = 0.003614, acc = 50.00%) AAE: (mse = 0.065767, b_ce = 0.062954)
# Epoch: 1600 Disc: (loss = 0.003474, acc = 50.00%) AAE: (mse = 0.068259, b_ce = 0.065424)
# Epoch: 1610 Disc: (loss = 0.003727, acc = 50.00%) AAE: (mse = 0.063455, b_ce = 0.060593)
# Epoch: 1620 Disc: (loss = 0.004315, acc = 50.00%) AAE: (mse = 0.064393, b_ce = 0.061528)
# Epoch: 1630 Disc: (loss = 0.003679, acc = 50.00%) AAE: (mse = 0.063014, b_ce = 0.060138)
# Epoch: 1640 Disc: (loss = 0.003687, acc = 50.00%) AAE: (mse = 0.063901, b_ce = 0.061001)
# Epoch: 1650 Disc: (loss = 0.002882, acc = 50.00%) AAE: (mse = 0.059679, b_ce = 0.056757)
# Epoch: 1660 Disc: (loss = 0.003160, acc = 50.00%) AAE: (mse = 0.063962, b_ce = 0.061030)
# Epoch: 1670 Disc: (loss = 0.003792, acc = 50.00%) AAE: (mse = 0.062197, b_ce = 0.059240)
# Epoch: 1680 Disc: (loss = 0.002909, acc = 50.00%) AAE: (mse = 0.065460, b_ce = 0.062505)
# Epoch: 1690 Disc: (loss = 0.003278, acc = 50.00%) AAE: (mse = 0.060990, b_ce = 0.058019)
# Epoch: 1700 Disc: (loss = 0.002559, acc = 50.00%) AAE: (mse = 0.064208, b_ce = 0.061222)
# Epoch: 1710 Disc: (loss = 0.003029, acc = 50.00%) AAE: (mse = 0.061624, b_ce = 0.058619)
# Epoch: 1720 Disc: (loss = 0.002496, acc = 50.00%) AAE: (mse = 0.061307, b_ce = 0.058284)
# Epoch: 1730 Disc: (loss = 0.002443, acc = 50.00%) AAE: (mse = 0.064366, b_ce = 0.061333)
# Epoch: 1740 Disc: (loss = 0.002737, acc = 50.00%) AAE: (mse = 0.066446, b_ce = 0.063412)
# Epoch: 1750 Disc: (loss = 0.002976, acc = 50.00%) AAE: (mse = 0.065117, b_ce = 0.062066)
# Epoch: 1760 Disc: (loss = 0.002434, acc = 50.00%) AAE: (mse = 0.063713, b_ce = 0.060640)
# Epoch: 1770 Disc: (loss = 0.002530, acc = 50.00%) AAE: (mse = 0.066532, b_ce = 0.063449)
# Epoch: 1780 Disc: (loss = 0.002929, acc = 50.00%) AAE: (mse = 0.066223, b_ce = 0.063113)
# Epoch: 1790 Disc: (loss = 0.002407, acc = 50.00%) AAE: (mse = 0.060638, b_ce = 0.057516)
# Epoch: 1800 Disc: (loss = 0.002949, acc = 50.00%) AAE: (mse = 0.060955, b_ce = 0.057825)
# Epoch: 1810 Disc: (loss = 0.001925, acc = 50.00%) AAE: (mse = 0.061238, b_ce = 0.058094)
# Epoch: 1820 Disc: (loss = 0.002396, acc = 50.00%) AAE: (mse = 0.063211, b_ce = 0.060050)
# Epoch: 1830 Disc: (loss = 0.002281, acc = 50.00%) AAE: (mse = 0.066592, b_ce = 0.063428)
# Epoch: 1840 Disc: (loss = 0.002219, acc = 50.00%) AAE: (mse = 0.067442, b_ce = 0.064259)
# Epoch: 1850 Disc: (loss = 0.002428, acc = 50.00%) AAE: (mse = 0.061884, b_ce = 0.058675)
# Epoch: 1860 Disc: (loss = 0.002652, acc = 50.00%) AAE: (mse = 0.062501, b_ce = 0.059282)
# Epoch: 1870 Disc: (loss = 0.002334, acc = 50.00%) AAE: (mse = 0.059967, b_ce = 0.056732)
# Epoch: 1880 Disc: (loss = 0.002329, acc = 50.00%) AAE: (mse = 0.064704, b_ce = 0.061454)
# Epoch: 1890 Disc: (loss = 0.002258, acc = 50.00%) AAE: (mse = 0.066519, b_ce = 0.063269)
# Epoch: 1900 Disc: (loss = 0.002069, acc = 50.00%) AAE: (mse = 0.061988, b_ce = 0.058714)
# Epoch: 1910 Disc: (loss = 0.001656, acc = 50.00%) AAE: (mse = 0.067846, b_ce = 0.064565)
# Epoch: 1920 Disc: (loss = 0.002973, acc = 50.00%) AAE: (mse = 0.061128, b_ce = 0.057823)
# Epoch: 1930 Disc: (loss = 0.002053, acc = 50.00%) AAE: (mse = 0.068408, b_ce = 0.065095)
# Epoch: 1940 Disc: (loss = 0.002013, acc = 50.00%) AAE: (mse = 0.060949, b_ce = 0.057617)
# Epoch: 1950 Disc: (loss = 0.002397, acc = 50.00%) AAE: (mse = 0.063590, b_ce = 0.060250)
# Epoch: 1960 Disc: (loss = 0.001841, acc = 50.00%) AAE: (mse = 0.063784, b_ce = 0.060416)
# Epoch: 1970 Disc: (loss = 0.002089, acc = 50.00%) AAE: (mse = 0.061807, b_ce = 0.058435)
# Epoch: 1980 Disc: (loss = 0.002010, acc = 50.00%) AAE: (mse = 0.063997, b_ce = 0.060613)
# Epoch: 1990 Disc: (loss = 0.001803, acc = 50.00%) AAE: (mse = 0.064956, b_ce = 0.061556)
# Epoch: 2000 Disc: (loss = 0.001938, acc = 50.00%) AAE: (mse = 0.065093, b_ce = 0.061668)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 2010 Disc: (loss = 0.002116, acc = 50.00%) AAE: (mse = 0.061094, b_ce = 0.057656)
# Epoch: 2020 Disc: (loss = 0.001658, acc = 50.00%) AAE: (mse = 0.063400, b_ce = 0.059961)
# Epoch: 2030 Disc: (loss = 0.002031, acc = 50.00%) AAE: (mse = 0.066124, b_ce = 0.062668)
# Epoch: 2040 Disc: (loss = 0.001579, acc = 50.00%) AAE: (mse = 0.063568, b_ce = 0.060100)
# Epoch: 2050 Disc: (loss = 0.001575, acc = 50.00%) AAE: (mse = 0.066925, b_ce = 0.063440)
# Epoch: 2060 Disc: (loss = 0.001355, acc = 50.00%) AAE: (mse = 0.068284, b_ce = 0.064787)
# Epoch: 2070 Disc: (loss = 0.001924, acc = 50.00%) AAE: (mse = 0.062020, b_ce = 0.058508)
# Epoch: 2080 Disc: (loss = 0.001476, acc = 50.00%) AAE: (mse = 0.063910, b_ce = 0.060390)
# Epoch: 2090 Disc: (loss = 0.001262, acc = 50.00%) AAE: (mse = 0.068770, b_ce = 0.065232)
# Epoch: 2100 Disc: (loss = 0.001469, acc = 50.00%) AAE: (mse = 0.067495, b_ce = 0.063953)
# Epoch: 2110 Disc: (loss = 0.001776, acc = 50.00%) AAE: (mse = 0.060649, b_ce = 0.057077)
# Epoch: 2120 Disc: (loss = 0.001461, acc = 50.00%) AAE: (mse = 0.064374, b_ce = 0.060791)
# Epoch: 2130 Disc: (loss = 0.001121, acc = 50.00%) AAE: (mse = 0.068351, b_ce = 0.064758)
# Epoch: 2140 Disc: (loss = 0.001339, acc = 50.00%) AAE: (mse = 0.060481, b_ce = 0.056863)
# Epoch: 2150 Disc: (loss = 0.001332, acc = 50.00%) AAE: (mse = 0.064563, b_ce = 0.060938)
# Epoch: 2160 Disc: (loss = 0.001363, acc = 50.00%) AAE: (mse = 0.062272, b_ce = 0.058631)
# Epoch: 2170 Disc: (loss = 0.001460, acc = 50.00%) AAE: (mse = 0.061114, b_ce = 0.057470)
# Epoch: 2180 Disc: (loss = 0.001391, acc = 50.00%) AAE: (mse = 0.064510, b_ce = 0.060853)
# Epoch: 2190 Disc: (loss = 0.001344, acc = 50.00%) AAE: (mse = 0.069742, b_ce = 0.066067)
# Epoch: 2200 Disc: (loss = 0.001381, acc = 50.00%) AAE: (mse = 0.061747, b_ce = 0.058056)
# Epoch: 2210 Disc: (loss = 0.001054, acc = 50.00%) AAE: (mse = 0.065851, b_ce = 0.062148)
# Epoch: 2220 Disc: (loss = 0.001131, acc = 50.00%) AAE: (mse = 0.065044, b_ce = 0.061331)
# Epoch: 2230 Disc: (loss = 0.001310, acc = 50.00%) AAE: (mse = 0.057564, b_ce = 0.053828)
# Epoch: 2240 Disc: (loss = 0.001041, acc = 50.00%) AAE: (mse = 0.065814, b_ce = 0.062081)
# Epoch: 2250 Disc: (loss = 0.001428, acc = 50.00%) AAE: (mse = 0.061717, b_ce = 0.057966)
# Epoch: 2260 Disc: (loss = 0.001194, acc = 50.00%) AAE: (mse = 0.066261, b_ce = 0.062496)
# Epoch: 2270 Disc: (loss = 0.001228, acc = 50.00%) AAE: (mse = 0.063130, b_ce = 0.059355)
# Epoch: 2280 Disc: (loss = 0.001319, acc = 50.00%) AAE: (mse = 0.065361, b_ce = 0.061561)
# Epoch: 2290 Disc: (loss = 0.001285, acc = 50.00%) AAE: (mse = 0.064791, b_ce = 0.060986)
# Epoch: 2300 Disc: (loss = 0.001085, acc = 50.00%) AAE: (mse = 0.062923, b_ce = 0.059105)
# Epoch: 2310 Disc: (loss = 0.001111, acc = 50.00%) AAE: (mse = 0.060188, b_ce = 0.056355)
# Epoch: 2320 Disc: (loss = 0.001080, acc = 50.00%) AAE: (mse = 0.064887, b_ce = 0.061051)
# Epoch: 2330 Disc: (loss = 0.001102, acc = 50.00%) AAE: (mse = 0.068156, b_ce = 0.064307)
# Epoch: 2340 Disc: (loss = 0.001332, acc = 50.00%) AAE: (mse = 0.064951, b_ce = 0.061073)
# Epoch: 2350 Disc: (loss = 0.001021, acc = 50.00%) AAE: (mse = 0.061355, b_ce = 0.057468)
# Epoch: 2360 Disc: (loss = 0.000913, acc = 50.00%) AAE: (mse = 0.065911, b_ce = 0.062009)
# Epoch: 2370 Disc: (loss = 0.001053, acc = 50.00%) AAE: (mse = 0.061542, b_ce = 0.057620)
# Epoch: 2380 Disc: (loss = 0.001228, acc = 50.00%) AAE: (mse = 0.071645, b_ce = 0.067721)
# Epoch: 2390 Disc: (loss = 0.000916, acc = 50.00%) AAE: (mse = 0.059557, b_ce = 0.055614)
# Epoch: 2400 Disc: (loss = 0.001079, acc = 50.00%) AAE: (mse = 0.062861, b_ce = 0.058909)
# Epoch: 2410 Disc: (loss = 0.000843, acc = 50.00%) AAE: (mse = 0.064861, b_ce = 0.060898)
# Epoch: 2420 Disc: (loss = 0.000822, acc = 50.00%) AAE: (mse = 0.066511, b_ce = 0.062539)
# Epoch: 2430 Disc: (loss = 0.000651, acc = 50.00%) AAE: (mse = 0.063296, b_ce = 0.059308)
# Epoch: 2440 Disc: (loss = 0.000933, acc = 50.00%) AAE: (mse = 0.062792, b_ce = 0.058790)
# Epoch: 2450 Disc: (loss = 0.000770, acc = 50.00%) AAE: (mse = 0.065799, b_ce = 0.061780)
# Epoch: 2460 Disc: (loss = 0.000840, acc = 50.00%) AAE: (mse = 0.068301, b_ce = 0.064269)
# Epoch: 2470 Disc: (loss = 0.000796, acc = 50.00%) AAE: (mse = 0.063195, b_ce = 0.059156)
# Epoch: 2480 Disc: (loss = 0.000884, acc = 50.00%) AAE: (mse = 0.064552, b_ce = 0.060492)
# Epoch: 2490 Disc: (loss = 0.000830, acc = 50.00%) AAE: (mse = 0.066581, b_ce = 0.062512)
# Epoch: 2500 Disc: (loss = 0.000743, acc = 50.00%) AAE: (mse = 0.066391, b_ce = 0.062308)
# Epoch: 2510 Disc: (loss = 0.000804, acc = 50.00%) AAE: (mse = 0.063453, b_ce = 0.059362)
# Epoch: 2520 Disc: (loss = 0.000818, acc = 50.00%) AAE: (mse = 0.066767, b_ce = 0.062663)
# Epoch: 2530 Disc: (loss = 0.000780, acc = 50.00%) AAE: (mse = 0.066807, b_ce = 0.062697)
# Epoch: 2540 Disc: (loss = 0.000795, acc = 50.00%) AAE: (mse = 0.067461, b_ce = 0.063330)
# Epoch: 2550 Disc: (loss = 0.000558, acc = 50.00%) AAE: (mse = 0.066824, b_ce = 0.062685)
# Epoch: 2560 Disc: (loss = 0.000634, acc = 50.00%) AAE: (mse = 0.067411, b_ce = 0.063257)
# Epoch: 2570 Disc: (loss = 0.000636, acc = 50.00%) AAE: (mse = 0.066934, b_ce = 0.062765)
# Epoch: 2580 Disc: (loss = 0.000676, acc = 50.00%) AAE: (mse = 0.065224, b_ce = 0.061044)
# Epoch: 2590 Disc: (loss = 0.000667, acc = 50.00%) AAE: (mse = 0.060160, b_ce = 0.055961)
# Epoch: 2600 Disc: (loss = 0.000643, acc = 50.00%) AAE: (mse = 0.063532, b_ce = 0.059334)
# Epoch: 2610 Disc: (loss = 0.000719, acc = 50.00%) AAE: (mse = 0.074246, b_ce = 0.070036)
# Epoch: 2620 Disc: (loss = 0.000731, acc = 50.00%) AAE: (mse = 0.064529, b_ce = 0.060291)
# Epoch: 2630 Disc: (loss = 0.000654, acc = 50.00%) AAE: (mse = 0.071441, b_ce = 0.067208)
# Epoch: 2640 Disc: (loss = 0.000657, acc = 50.00%) AAE: (mse = 0.065814, b_ce = 0.061548)
# Epoch: 2650 Disc: (loss = 0.000618, acc = 50.00%) AAE: (mse = 0.063694, b_ce = 0.059430)
# Epoch: 2660 Disc: (loss = 0.000599, acc = 50.00%) AAE: (mse = 0.061016, b_ce = 0.056735)
# Epoch: 2670 Disc: (loss = 0.000415, acc = 50.00%) AAE: (mse = 0.063036, b_ce = 0.058742)
# Epoch: 2680 Disc: (loss = 0.000573, acc = 50.00%) AAE: (mse = 0.067637, b_ce = 0.063330)
# Epoch: 2690 Disc: (loss = 0.000709, acc = 50.00%) AAE: (mse = 0.067295, b_ce = 0.062973)
# Epoch: 2700 Disc: (loss = 0.000582, acc = 50.00%) AAE: (mse = 0.066171, b_ce = 0.061844)
# Epoch: 2710 Disc: (loss = 0.000582, acc = 50.00%) AAE: (mse = 0.064884, b_ce = 0.060546)
# Epoch: 2720 Disc: (loss = 0.000459, acc = 50.00%) AAE: (mse = 0.062747, b_ce = 0.058396)
# Epoch: 2730 Disc: (loss = 0.000480, acc = 50.00%) AAE: (mse = 0.064191, b_ce = 0.059823)
# Epoch: 2740 Disc: (loss = 0.000635, acc = 50.00%) AAE: (mse = 0.067777, b_ce = 0.063398)
# Epoch: 2750 Disc: (loss = 0.000444, acc = 50.00%) AAE: (mse = 0.063355, b_ce = 0.058961)
# Epoch: 2760 Disc: (loss = 0.000473, acc = 50.00%) AAE: (mse = 0.073854, b_ce = 0.069457)
# Epoch: 2770 Disc: (loss = 0.000668, acc = 50.00%) AAE: (mse = 0.066100, b_ce = 0.061686)
# Epoch: 2780 Disc: (loss = 0.000611, acc = 50.00%) AAE: (mse = 0.063694, b_ce = 0.059263)
# Epoch: 2790 Disc: (loss = 0.000491, acc = 50.00%) AAE: (mse = 0.060781, b_ce = 0.056333)
# Epoch: 2800 Disc: (loss = 0.000487, acc = 50.00%) AAE: (mse = 0.067981, b_ce = 0.063527)
# Epoch: 2810 Disc: (loss = 0.000460, acc = 50.00%) AAE: (mse = 0.066349, b_ce = 0.061887)
# Epoch: 2820 Disc: (loss = 0.000491, acc = 50.00%) AAE: (mse = 0.064017, b_ce = 0.059537)
# Epoch: 2830 Disc: (loss = 0.000541, acc = 50.00%) AAE: (mse = 0.065291, b_ce = 0.060802)
# Epoch: 2840 Disc: (loss = 0.000408, acc = 50.00%) AAE: (mse = 0.060650, b_ce = 0.056144)
# Epoch: 2850 Disc: (loss = 0.000536, acc = 50.00%) AAE: (mse = 0.062638, b_ce = 0.058115)
# Epoch: 2860 Disc: (loss = 0.000452, acc = 50.00%) AAE: (mse = 0.063895, b_ce = 0.059367)
# Epoch: 2870 Disc: (loss = 0.000523, acc = 50.00%) AAE: (mse = 0.063539, b_ce = 0.058999)
# Epoch: 2880 Disc: (loss = 0.000300, acc = 50.00%) AAE: (mse = 0.066568, b_ce = 0.062014)
# Epoch: 2890 Disc: (loss = 0.000543, acc = 50.00%) AAE: (mse = 0.062649, b_ce = 0.058085)
# Epoch: 2900 Disc: (loss = 0.000520, acc = 50.00%) AAE: (mse = 0.063544, b_ce = 0.058958)
# Epoch: 2910 Disc: (loss = 0.000415, acc = 50.00%) AAE: (mse = 0.062971, b_ce = 0.058376)
# Epoch: 2920 Disc: (loss = 0.000330, acc = 50.00%) AAE: (mse = 0.071720, b_ce = 0.067120)
# Epoch: 2930 Disc: (loss = 0.000392, acc = 50.00%) AAE: (mse = 0.061466, b_ce = 0.056846)
# Epoch: 2940 Disc: (loss = 0.000454, acc = 50.00%) AAE: (mse = 0.064186, b_ce = 0.059554)
# Epoch: 2950 Disc: (loss = 0.000450, acc = 50.00%) AAE: (mse = 0.067671, b_ce = 0.063037)
# Epoch: 2960 Disc: (loss = 0.000416, acc = 50.00%) AAE: (mse = 0.064775, b_ce = 0.060122)
# Epoch: 2970 Disc: (loss = 0.000439, acc = 50.00%) AAE: (mse = 0.064648, b_ce = 0.059978)
# Epoch: 2980 Disc: (loss = 0.000409, acc = 50.00%) AAE: (mse = 0.062360, b_ce = 0.057678)
# Epoch: 2990 Disc: (loss = 0.000365, acc = 50.00%) AAE: (mse = 0.066949, b_ce = 0.062259)
# Epoch: 3000 Disc: (loss = 0.000337, acc = 50.00%) AAE: (mse = 0.065252, b_ce = 0.060546)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 3010 Disc: (loss = 0.000387, acc = 50.00%) AAE: (mse = 0.067139, b_ce = 0.062421)
# Epoch: 3020 Disc: (loss = 0.000377, acc = 50.00%) AAE: (mse = 0.065014, b_ce = 0.060286)
# Epoch: 3030 Disc: (loss = 0.000355, acc = 50.00%) AAE: (mse = 0.066201, b_ce = 0.061461)
# Epoch: 3040 Disc: (loss = 0.000394, acc = 50.00%) AAE: (mse = 0.063396, b_ce = 0.058641)
# Epoch: 3050 Disc: (loss = 0.000309, acc = 50.00%) AAE: (mse = 0.061625, b_ce = 0.056855)
# Epoch: 3060 Disc: (loss = 0.000342, acc = 50.00%) AAE: (mse = 0.066441, b_ce = 0.061659)
# Epoch: 3070 Disc: (loss = 0.000370, acc = 50.00%) AAE: (mse = 0.065347, b_ce = 0.060561)
# Epoch: 3080 Disc: (loss = 0.000377, acc = 50.00%) AAE: (mse = 0.061093, b_ce = 0.056289)
# Epoch: 3090 Disc: (loss = 0.000333, acc = 50.00%) AAE: (mse = 0.068034, b_ce = 0.063224)
# Epoch: 3100 Disc: (loss = 0.000354, acc = 50.00%) AAE: (mse = 0.065868, b_ce = 0.061045)
# Epoch: 3110 Disc: (loss = 0.000414, acc = 50.00%) AAE: (mse = 0.060804, b_ce = 0.055971)
# Epoch: 3120 Disc: (loss = 0.000341, acc = 50.00%) AAE: (mse = 0.073949, b_ce = 0.069111)
# Epoch: 3130 Disc: (loss = 0.000317, acc = 50.00%) AAE: (mse = 0.061996, b_ce = 0.057132)
# Epoch: 3140 Disc: (loss = 0.000341, acc = 50.00%) AAE: (mse = 0.061771, b_ce = 0.056901)
# Epoch: 3150 Disc: (loss = 0.000380, acc = 50.00%) AAE: (mse = 0.063320, b_ce = 0.058441)
# Epoch: 3160 Disc: (loss = 0.000296, acc = 50.00%) AAE: (mse = 0.066553, b_ce = 0.061659)
# Epoch: 3170 Disc: (loss = 0.000241, acc = 50.00%) AAE: (mse = 0.059159, b_ce = 0.054246)
# Epoch: 3180 Disc: (loss = 0.000275, acc = 50.00%) AAE: (mse = 0.065370, b_ce = 0.060451)
# Epoch: 3190 Disc: (loss = 0.000285, acc = 50.00%) AAE: (mse = 0.065909, b_ce = 0.060981)
# Epoch: 3200 Disc: (loss = 0.000240, acc = 50.00%) AAE: (mse = 0.065708, b_ce = 0.060767)
# Epoch: 3210 Disc: (loss = 0.000326, acc = 50.00%) AAE: (mse = 0.063549, b_ce = 0.058595)
# Epoch: 3220 Disc: (loss = 0.000251, acc = 50.00%) AAE: (mse = 0.066281, b_ce = 0.061319)
# Epoch: 3230 Disc: (loss = 0.000315, acc = 50.00%) AAE: (mse = 0.064667, b_ce = 0.059696)
# Epoch: 3240 Disc: (loss = 0.000231, acc = 50.00%) AAE: (mse = 0.061788, b_ce = 0.056798)
# Epoch: 3250 Disc: (loss = 0.000206, acc = 50.00%) AAE: (mse = 0.059852, b_ce = 0.054849)
# Epoch: 3260 Disc: (loss = 0.000293, acc = 50.00%) AAE: (mse = 0.071292, b_ce = 0.066286)
# Epoch: 3270 Disc: (loss = 0.000314, acc = 50.00%) AAE: (mse = 0.067461, b_ce = 0.062437)
# Epoch: 3280 Disc: (loss = 0.000326, acc = 50.00%) AAE: (mse = 0.063864, b_ce = 0.058826)
# Epoch: 3290 Disc: (loss = 0.000246, acc = 50.00%) AAE: (mse = 0.064052, b_ce = 0.059004)
# Epoch: 3300 Disc: (loss = 0.000276, acc = 50.00%) AAE: (mse = 0.066277, b_ce = 0.061219)
# Epoch: 3310 Disc: (loss = 0.000248, acc = 50.00%) AAE: (mse = 0.068748, b_ce = 0.063671)
# Epoch: 3320 Disc: (loss = 0.000223, acc = 50.00%) AAE: (mse = 0.066562, b_ce = 0.061476)
# Epoch: 3330 Disc: (loss = 0.000229, acc = 50.00%) AAE: (mse = 0.069274, b_ce = 0.064181)
# Epoch: 3340 Disc: (loss = 0.000243, acc = 50.00%) AAE: (mse = 0.066576, b_ce = 0.061472)
# Epoch: 3350 Disc: (loss = 0.000218, acc = 50.00%) AAE: (mse = 0.067783, b_ce = 0.062667)
# Epoch: 3360 Disc: (loss = 0.000261, acc = 50.00%) AAE: (mse = 0.066834, b_ce = 0.061712)
# Epoch: 3370 Disc: (loss = 0.000234, acc = 50.00%) AAE: (mse = 0.064354, b_ce = 0.059208)
# Epoch: 3380 Disc: (loss = 0.000203, acc = 50.00%) AAE: (mse = 0.057292, b_ce = 0.052131)
# Epoch: 3390 Disc: (loss = 0.000194, acc = 50.00%) AAE: (mse = 0.060620, b_ce = 0.055452)
# Epoch: 3400 Disc: (loss = 0.000205, acc = 50.00%) AAE: (mse = 0.070768, b_ce = 0.065594)
# Epoch: 3410 Disc: (loss = 0.000260, acc = 50.00%) AAE: (mse = 0.063586, b_ce = 0.058393)
# Epoch: 3420 Disc: (loss = 0.000195, acc = 50.00%) AAE: (mse = 0.070388, b_ce = 0.065190)
# Epoch: 3430 Disc: (loss = 0.000209, acc = 50.00%) AAE: (mse = 0.065119, b_ce = 0.059906)
# Epoch: 3440 Disc: (loss = 0.000219, acc = 50.00%) AAE: (mse = 0.072829, b_ce = 0.067613)
# Epoch: 3450 Disc: (loss = 0.000159, acc = 50.00%) AAE: (mse = 0.068367, b_ce = 0.063129)
# Epoch: 3460 Disc: (loss = 0.000215, acc = 50.00%) AAE: (mse = 0.060020, b_ce = 0.054764)
# Epoch: 3470 Disc: (loss = 0.000181, acc = 50.00%) AAE: (mse = 0.061698, b_ce = 0.056433)
# Epoch: 3480 Disc: (loss = 0.000174, acc = 50.00%) AAE: (mse = 0.063509, b_ce = 0.058231)
# Epoch: 3490 Disc: (loss = 0.000207, acc = 50.00%) AAE: (mse = 0.065779, b_ce = 0.060489)
# Epoch: 3500 Disc: (loss = 0.000175, acc = 50.00%) AAE: (mse = 0.060107, b_ce = 0.054802)
# Epoch: 3510 Disc: (loss = 0.000213, acc = 50.00%) AAE: (mse = 0.066323, b_ce = 0.061016)
# Epoch: 3520 Disc: (loss = 0.000208, acc = 50.00%) AAE: (mse = 0.063300, b_ce = 0.057975)
# Epoch: 3530 Disc: (loss = 0.000193, acc = 50.00%) AAE: (mse = 0.066188, b_ce = 0.060849)
# Epoch: 3540 Disc: (loss = 0.000221, acc = 50.00%) AAE: (mse = 0.066696, b_ce = 0.061348)
# Epoch: 3550 Disc: (loss = 0.000166, acc = 50.00%) AAE: (mse = 0.065947, b_ce = 0.060592)
# Epoch: 3560 Disc: (loss = 0.000148, acc = 50.00%) AAE: (mse = 0.059095, b_ce = 0.053722)
# Epoch: 3570 Disc: (loss = 0.000205, acc = 50.00%) AAE: (mse = 0.067291, b_ce = 0.061910)
# Epoch: 3580 Disc: (loss = 0.000150, acc = 50.00%) AAE: (mse = 0.061500, b_ce = 0.056103)
# Epoch: 3590 Disc: (loss = 0.000173, acc = 50.00%) AAE: (mse = 0.065272, b_ce = 0.059871)
# Epoch: 3600 Disc: (loss = 0.000158, acc = 50.00%) AAE: (mse = 0.067949, b_ce = 0.062530)
# Epoch: 3610 Disc: (loss = 0.000180, acc = 50.00%) AAE: (mse = 0.065738, b_ce = 0.060313)
# Epoch: 3620 Disc: (loss = 0.000222, acc = 50.00%) AAE: (mse = 0.070134, b_ce = 0.064697)
# Epoch: 3630 Disc: (loss = 0.000203, acc = 50.00%) AAE: (mse = 0.062170, b_ce = 0.056718)
# Epoch: 3640 Disc: (loss = 0.000194, acc = 50.00%) AAE: (mse = 0.063551, b_ce = 0.058083)
# Epoch: 3650 Disc: (loss = 0.000180, acc = 50.00%) AAE: (mse = 0.064712, b_ce = 0.059235)
# Epoch: 3660 Disc: (loss = 0.000147, acc = 50.00%) AAE: (mse = 0.065351, b_ce = 0.059860)
# Epoch: 3670 Disc: (loss = 0.000153, acc = 50.00%) AAE: (mse = 0.067405, b_ce = 0.061901)
# Epoch: 3680 Disc: (loss = 0.000126, acc = 50.00%) AAE: (mse = 0.060378, b_ce = 0.054854)
# Epoch: 3690 Disc: (loss = 0.000172, acc = 50.00%) AAE: (mse = 0.066290, b_ce = 0.060768)
# Epoch: 3700 Disc: (loss = 0.000148, acc = 50.00%) AAE: (mse = 0.071106, b_ce = 0.065577)
# Epoch: 3710 Disc: (loss = 0.000187, acc = 50.00%) AAE: (mse = 0.062321, b_ce = 0.056765)
# Epoch: 3720 Disc: (loss = 0.000150, acc = 50.00%) AAE: (mse = 0.064920, b_ce = 0.059353)
# Epoch: 3730 Disc: (loss = 0.000185, acc = 50.00%) AAE: (mse = 0.068380, b_ce = 0.062808)
# Epoch: 3740 Disc: (loss = 0.000110, acc = 50.00%) AAE: (mse = 0.068905, b_ce = 0.063318)
# Epoch: 3750 Disc: (loss = 0.000133, acc = 50.00%) AAE: (mse = 0.070489, b_ce = 0.064896)
# Epoch: 3760 Disc: (loss = 0.000128, acc = 50.00%) AAE: (mse = 0.065338, b_ce = 0.059725)
# Epoch: 3770 Disc: (loss = 0.000147, acc = 50.00%) AAE: (mse = 0.067625, b_ce = 0.062003)
# Epoch: 3780 Disc: (loss = 0.000119, acc = 50.00%) AAE: (mse = 0.067646, b_ce = 0.062012)
# Epoch: 3790 Disc: (loss = 0.000173, acc = 50.00%) AAE: (mse = 0.066368, b_ce = 0.060722)
# Epoch: 3800 Disc: (loss = 0.000110, acc = 50.00%) AAE: (mse = 0.068866, b_ce = 0.063212)
# Epoch: 3810 Disc: (loss = 0.000138, acc = 50.00%) AAE: (mse = 0.067462, b_ce = 0.061799)
# Epoch: 3820 Disc: (loss = 0.000118, acc = 50.00%) AAE: (mse = 0.066609, b_ce = 0.060935)
# Epoch: 3830 Disc: (loss = 0.000165, acc = 50.00%) AAE: (mse = 0.064116, b_ce = 0.058428)
# Epoch: 3840 Disc: (loss = 0.000135, acc = 50.00%) AAE: (mse = 0.070813, b_ce = 0.065120)
# Epoch: 3850 Disc: (loss = 0.000175, acc = 50.00%) AAE: (mse = 0.071285, b_ce = 0.065575)
# Epoch: 3860 Disc: (loss = 0.000163, acc = 50.00%) AAE: (mse = 0.067394, b_ce = 0.061673)
# Epoch: 3870 Disc: (loss = 0.000141, acc = 50.00%) AAE: (mse = 0.065145, b_ce = 0.059414)
# Epoch: 3880 Disc: (loss = 0.000124, acc = 50.00%) AAE: (mse = 0.066356, b_ce = 0.060614)
# Epoch: 3890 Disc: (loss = 0.000157, acc = 50.00%) AAE: (mse = 0.067445, b_ce = 0.061691)
# Epoch: 3900 Disc: (loss = 0.000116, acc = 50.00%) AAE: (mse = 0.070065, b_ce = 0.064301)
# Epoch: 3910 Disc: (loss = 0.000079, acc = 50.00%) AAE: (mse = 0.069145, b_ce = 0.063372)
# Epoch: 3920 Disc: (loss = 0.000096, acc = 50.00%) AAE: (mse = 0.067025, b_ce = 0.061235)
# Epoch: 3930 Disc: (loss = 0.000164, acc = 50.00%) AAE: (mse = 0.058716, b_ce = 0.052908)
# Epoch: 3940 Disc: (loss = 0.000134, acc = 50.00%) AAE: (mse = 0.071654, b_ce = 0.065846)
# Epoch: 3950 Disc: (loss = 0.000105, acc = 50.00%) AAE: (mse = 0.061451, b_ce = 0.055617)
# Epoch: 3960 Disc: (loss = 0.000120, acc = 50.00%) AAE: (mse = 0.063823, b_ce = 0.057976)
# Epoch: 3970 Disc: (loss = 0.000155, acc = 50.00%) AAE: (mse = 0.068228, b_ce = 0.062377)
# Epoch: 3980 Disc: (loss = 0.000118, acc = 50.00%) AAE: (mse = 0.069010, b_ce = 0.063148)
# Epoch: 3990 Disc: (loss = 0.000114, acc = 50.00%) AAE: (mse = 0.061990, b_ce = 0.056106)
# Epoch: 4000 Disc: (loss = 0.000096, acc = 50.00%) AAE: (mse = 0.061952, b_ce = 0.056059)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 4010 Disc: (loss = 0.000125, acc = 50.00%) AAE: (mse = 0.066265, b_ce = 0.060361)
# Epoch: 4020 Disc: (loss = 0.000104, acc = 50.00%) AAE: (mse = 0.061241, b_ce = 0.055329)
# Epoch: 4030 Disc: (loss = 0.000101, acc = 50.00%) AAE: (mse = 0.072266, b_ce = 0.066350)
# Epoch: 4040 Disc: (loss = 0.000077, acc = 50.00%) AAE: (mse = 0.070608, b_ce = 0.064678)
# Epoch: 4050 Disc: (loss = 0.000126, acc = 50.00%) AAE: (mse = 0.068251, b_ce = 0.062302)
# Epoch: 4060 Disc: (loss = 0.000087, acc = 50.00%) AAE: (mse = 0.065704, b_ce = 0.059749)
# Epoch: 4070 Disc: (loss = 0.000083, acc = 50.00%) AAE: (mse = 0.068317, b_ce = 0.062347)
# Epoch: 4080 Disc: (loss = 0.000087, acc = 50.00%) AAE: (mse = 0.065247, b_ce = 0.059269)
# Epoch: 4090 Disc: (loss = 0.000089, acc = 50.00%) AAE: (mse = 0.060512, b_ce = 0.054519)
# Epoch: 4100 Disc: (loss = 0.000109, acc = 50.00%) AAE: (mse = 0.067751, b_ce = 0.061760)
# Epoch: 4110 Disc: (loss = 0.000088, acc = 50.00%) AAE: (mse = 0.064055, b_ce = 0.058045)
# Epoch: 4120 Disc: (loss = 0.000090, acc = 50.00%) AAE: (mse = 0.068422, b_ce = 0.062404)
# Epoch: 4130 Disc: (loss = 0.000128, acc = 50.00%) AAE: (mse = 0.061935, b_ce = 0.055908)
# Epoch: 4140 Disc: (loss = 0.000069, acc = 50.00%) AAE: (mse = 0.062035, b_ce = 0.055993)
# Epoch: 4150 Disc: (loss = 0.000081, acc = 50.00%) AAE: (mse = 0.066337, b_ce = 0.060285)
# Epoch: 4160 Disc: (loss = 0.000078, acc = 50.00%) AAE: (mse = 0.069758, b_ce = 0.063699)
# Epoch: 4170 Disc: (loss = 0.000062, acc = 50.00%) AAE: (mse = 0.065535, b_ce = 0.059468)
# Epoch: 4180 Disc: (loss = 0.000071, acc = 50.00%) AAE: (mse = 0.063502, b_ce = 0.057416)
# Epoch: 4190 Disc: (loss = 0.000087, acc = 50.00%) AAE: (mse = 0.067370, b_ce = 0.061283)
# Epoch: 4200 Disc: (loss = 0.000069, acc = 50.00%) AAE: (mse = 0.059638, b_ce = 0.053527)
# Epoch: 4210 Disc: (loss = 0.000077, acc = 50.00%) AAE: (mse = 0.065633, b_ce = 0.059514)
# Epoch: 4220 Disc: (loss = 0.000095, acc = 50.00%) AAE: (mse = 0.067594, b_ce = 0.061465)
# Epoch: 4230 Disc: (loss = 0.000058, acc = 50.00%) AAE: (mse = 0.071015, b_ce = 0.064881)
# Epoch: 4240 Disc: (loss = 0.000091, acc = 50.00%) AAE: (mse = 0.067173, b_ce = 0.061023)
# Epoch: 4250 Disc: (loss = 0.000069, acc = 50.00%) AAE: (mse = 0.067769, b_ce = 0.061612)
# Epoch: 4260 Disc: (loss = 0.000090, acc = 50.00%) AAE: (mse = 0.066997, b_ce = 0.060818)
# Epoch: 4270 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.063794, b_ce = 0.057603)
# Epoch: 4280 Disc: (loss = 0.000071, acc = 50.00%) AAE: (mse = 0.069989, b_ce = 0.063788)
# Epoch: 4290 Disc: (loss = 0.000072, acc = 50.00%) AAE: (mse = 0.070137, b_ce = 0.063930)
# Epoch: 4300 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.062142, b_ce = 0.055913)
# Epoch: 4310 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.068450, b_ce = 0.062219)
# Epoch: 4320 Disc: (loss = 0.000050, acc = 50.00%) AAE: (mse = 0.062982, b_ce = 0.056735)
# Epoch: 4330 Disc: (loss = 0.000059, acc = 50.00%) AAE: (mse = 0.066233, b_ce = 0.059985)
# Epoch: 4340 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.067320, b_ce = 0.061053)
# Epoch: 4350 Disc: (loss = 0.000066, acc = 50.00%) AAE: (mse = 0.070220, b_ce = 0.063945)
# Epoch: 4360 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.065179, b_ce = 0.058884)
# Epoch: 4370 Disc: (loss = 0.000078, acc = 50.00%) AAE: (mse = 0.074280, b_ce = 0.067991)
# Epoch: 4380 Disc: (loss = 0.000063, acc = 50.00%) AAE: (mse = 0.068984, b_ce = 0.062669)
# Epoch: 4390 Disc: (loss = 0.000068, acc = 50.00%) AAE: (mse = 0.064258, b_ce = 0.057932)
# Epoch: 4400 Disc: (loss = 0.000065, acc = 50.00%) AAE: (mse = 0.067489, b_ce = 0.061155)
# Epoch: 4410 Disc: (loss = 0.000069, acc = 50.00%) AAE: (mse = 0.062468, b_ce = 0.056116)
# Epoch: 4420 Disc: (loss = 0.000051, acc = 50.00%) AAE: (mse = 0.069277, b_ce = 0.062921)
# Epoch: 4430 Disc: (loss = 0.000042, acc = 50.00%) AAE: (mse = 0.064838, b_ce = 0.058471)
# Epoch: 4440 Disc: (loss = 0.000046, acc = 50.00%) AAE: (mse = 0.066750, b_ce = 0.060375)
# Epoch: 4450 Disc: (loss = 0.000071, acc = 50.00%) AAE: (mse = 0.070115, b_ce = 0.063734)
# Epoch: 4460 Disc: (loss = 0.000069, acc = 50.00%) AAE: (mse = 0.072322, b_ce = 0.065927)
# Epoch: 4470 Disc: (loss = 0.000048, acc = 50.00%) AAE: (mse = 0.070972, b_ce = 0.064570)
# Epoch: 4480 Disc: (loss = 0.000062, acc = 50.00%) AAE: (mse = 0.070778, b_ce = 0.064353)
# Epoch: 4490 Disc: (loss = 0.000050, acc = 50.00%) AAE: (mse = 0.067693, b_ce = 0.061265)
# Epoch: 4500 Disc: (loss = 0.000047, acc = 50.00%) AAE: (mse = 0.065107, b_ce = 0.058661)
# Epoch: 4510 Disc: (loss = 0.000065, acc = 50.00%) AAE: (mse = 0.063739, b_ce = 0.057284)
# Epoch: 4520 Disc: (loss = 0.000069, acc = 50.00%) AAE: (mse = 0.065592, b_ce = 0.059119)
# Epoch: 4530 Disc: (loss = 0.000053, acc = 50.00%) AAE: (mse = 0.064677, b_ce = 0.058189)
# Epoch: 4540 Disc: (loss = 0.000065, acc = 50.00%) AAE: (mse = 0.065569, b_ce = 0.059081)
# Epoch: 4550 Disc: (loss = 0.000044, acc = 50.00%) AAE: (mse = 0.067339, b_ce = 0.060837)
# Epoch: 4560 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.063889, b_ce = 0.057375)
# Epoch: 4570 Disc: (loss = 0.000067, acc = 50.00%) AAE: (mse = 0.064548, b_ce = 0.058028)
# Epoch: 4580 Disc: (loss = 0.000050, acc = 50.00%) AAE: (mse = 0.064192, b_ce = 0.057664)
# Epoch: 4590 Disc: (loss = 0.000059, acc = 50.00%) AAE: (mse = 0.067526, b_ce = 0.060986)
# Epoch: 4600 Disc: (loss = 0.000060, acc = 50.00%) AAE: (mse = 0.070116, b_ce = 0.063567)
# Epoch: 4610 Disc: (loss = 0.000045, acc = 50.00%) AAE: (mse = 0.073886, b_ce = 0.067332)
# Epoch: 4620 Disc: (loss = 0.000037, acc = 50.00%) AAE: (mse = 0.067108, b_ce = 0.060533)
# Epoch: 4630 Disc: (loss = 0.000046, acc = 50.00%) AAE: (mse = 0.062985, b_ce = 0.056391)
# Epoch: 4640 Disc: (loss = 0.000046, acc = 50.00%) AAE: (mse = 0.065746, b_ce = 0.059145)
# Epoch: 4650 Disc: (loss = 0.000043, acc = 50.00%) AAE: (mse = 0.061852, b_ce = 0.055239)
# Epoch: 4660 Disc: (loss = 0.000047, acc = 50.00%) AAE: (mse = 0.072285, b_ce = 0.065665)
# Epoch: 4670 Disc: (loss = 0.000049, acc = 50.00%) AAE: (mse = 0.062307, b_ce = 0.055673)
# Epoch: 4680 Disc: (loss = 0.000042, acc = 50.00%) AAE: (mse = 0.065901, b_ce = 0.059260)
# Epoch: 4690 Disc: (loss = 0.000060, acc = 50.00%) AAE: (mse = 0.063532, b_ce = 0.056875)
# Epoch: 4700 Disc: (loss = 0.000054, acc = 50.00%) AAE: (mse = 0.059971, b_ce = 0.053307)
# Epoch: 4710 Disc: (loss = 0.000032, acc = 50.00%) AAE: (mse = 0.070088, b_ce = 0.063418)
# Epoch: 4720 Disc: (loss = 0.000057, acc = 50.00%) AAE: (mse = 0.070440, b_ce = 0.063760)
# Epoch: 4730 Disc: (loss = 0.000043, acc = 50.00%) AAE: (mse = 0.066837, b_ce = 0.060144)
# Epoch: 4740 Disc: (loss = 0.000040, acc = 50.00%) AAE: (mse = 0.067482, b_ce = 0.060773)
# Epoch: 4750 Disc: (loss = 0.000039, acc = 50.00%) AAE: (mse = 0.063739, b_ce = 0.057023)
# Epoch: 4760 Disc: (loss = 0.000062, acc = 50.00%) AAE: (mse = 0.065900, b_ce = 0.059172)
# Epoch: 4770 Disc: (loss = 0.000036, acc = 50.00%) AAE: (mse = 0.072036, b_ce = 0.065306)
# ...
# Epoch: 13660 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074360, b_ce = 0.058725)
# Epoch: 13670 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073615, b_ce = 0.057980)
# Epoch: 13680 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075017, b_ce = 0.059352)
# Epoch: 13690 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075224, b_ce = 0.059562)
# Epoch: 13700 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076265, b_ce = 0.060611)
# Epoch: 13710 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078077, b_ce = 0.062395)
# Epoch: 13720 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071746, b_ce = 0.056057)
# Epoch: 13730 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073660, b_ce = 0.057968)
# Epoch: 13740 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075526, b_ce = 0.059840)
# Epoch: 13750 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.080326, b_ce = 0.064634)
# Epoch: 13760 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074030, b_ce = 0.058326)
# Epoch: 13770 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073042, b_ce = 0.057313)
# Epoch: 13780 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076410, b_ce = 0.060687)
# Epoch: 13790 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078632, b_ce = 0.062909)
# Epoch: 13800 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078564, b_ce = 0.062839)
# Epoch: 13810 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076516, b_ce = 0.060791)
# Epoch: 13820 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074815, b_ce = 0.059076)
# Epoch: 13830 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078405, b_ce = 0.062646)
# Epoch: 13840 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076509, b_ce = 0.060749)
# Epoch: 13850 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078503, b_ce = 0.062708)
# Epoch: 13860 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074854, b_ce = 0.059091)
# Epoch: 13870 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075025, b_ce = 0.059247)
# Epoch: 13880 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078709, b_ce = 0.062921)
# Epoch: 13890 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074736, b_ce = 0.058922)
# Epoch: 13900 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078039, b_ce = 0.062232)
# Epoch: 13910 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074070, b_ce = 0.058263)
# Epoch: 13920 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072267, b_ce = 0.056438)
# Epoch: 13930 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079881, b_ce = 0.064047)
# Epoch: 13940 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078006, b_ce = 0.062172)
# Epoch: 13950 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074021, b_ce = 0.058180)
# Epoch: 13960 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077110, b_ce = 0.061235)
# Epoch: 13970 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073902, b_ce = 0.058043)
# Epoch: 13980 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074063, b_ce = 0.058179)
# Epoch: 13990 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077046, b_ce = 0.061166)
# Epoch: 14000 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077210, b_ce = 0.061332)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 14010 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.082700, b_ce = 0.066800)
# Epoch: 14020 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079109, b_ce = 0.063219)
# Epoch: 14030 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075799, b_ce = 0.059897)
# Epoch: 14040 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.070155, b_ce = 0.054262)
# Epoch: 14050 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073643, b_ce = 0.057759)
# Epoch: 14060 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075947, b_ce = 0.060027)
# Epoch: 14070 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073786, b_ce = 0.057867)
# Epoch: 14080 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076490, b_ce = 0.060561)
# Epoch: 14090 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074437, b_ce = 0.058525)
# Epoch: 14100 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077338, b_ce = 0.061387)
# Epoch: 14110 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072803, b_ce = 0.056866)
# Epoch: 14120 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075171, b_ce = 0.059227)
# Epoch: 14130 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.081888, b_ce = 0.065939)
# Epoch: 14140 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078682, b_ce = 0.062733)
# Epoch: 14150 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075849, b_ce = 0.059876)
# Epoch: 14160 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073514, b_ce = 0.057532)
# Epoch: 14170 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077972, b_ce = 0.061987)
# Epoch: 14180 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076023, b_ce = 0.060043)
# Epoch: 14190 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078006, b_ce = 0.062017)
# Epoch: 14200 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073406, b_ce = 0.057403)
# Epoch: 14210 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072164, b_ce = 0.056149)
# Epoch: 14220 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.068368, b_ce = 0.052344)
# Epoch: 14230 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078522, b_ce = 0.062501)
# Epoch: 14240 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078167, b_ce = 0.062153)
# Epoch: 14250 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071330, b_ce = 0.055300)
# Epoch: 14260 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072825, b_ce = 0.056784)
# Epoch: 14270 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073479, b_ce = 0.057439)
# Epoch: 14280 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077723, b_ce = 0.061676)
# Epoch: 14290 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074600, b_ce = 0.058539)
# Epoch: 14300 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078607, b_ce = 0.062526)
# Epoch: 14310 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.081430, b_ce = 0.065371)
# Epoch: 14320 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073497, b_ce = 0.057427)
# Epoch: 14330 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071103, b_ce = 0.055008)
# Epoch: 14340 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073347, b_ce = 0.057262)
# Epoch: 14350 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075850, b_ce = 0.059773)
# Epoch: 14360 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.080239, b_ce = 0.064149)
# Epoch: 14370 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078591, b_ce = 0.062483)
# Epoch: 14380 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.080735, b_ce = 0.064627)
# Epoch: 14390 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074165, b_ce = 0.058048)
# Epoch: 14400 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077260, b_ce = 0.061157)
# Epoch: 14410 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076731, b_ce = 0.060606)
# Epoch: 14420 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076090, b_ce = 0.059969)
# Epoch: 14430 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.069735, b_ce = 0.053585)
# Epoch: 14440 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078932, b_ce = 0.062795)
# Epoch: 14450 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076781, b_ce = 0.060636)
# Epoch: 14460 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.069473, b_ce = 0.053301)
# Epoch: 14470 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071849, b_ce = 0.055682)
# Epoch: 14480 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077749, b_ce = 0.061605)
# Epoch: 14490 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077801, b_ce = 0.061637)
# Epoch: 14500 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073128, b_ce = 0.056964)
# Epoch: 14510 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073468, b_ce = 0.057274)
# Epoch: 14520 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071631, b_ce = 0.055445)
# Epoch: 14530 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076023, b_ce = 0.059812)
# Epoch: 14540 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071235, b_ce = 0.055019)
# Epoch: 14550 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079145, b_ce = 0.062940)
# Epoch: 14560 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076870, b_ce = 0.060671)
# Epoch: 14570 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078663, b_ce = 0.062450)
# Epoch: 14580 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072261, b_ce = 0.056032)
# Epoch: 14590 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078790, b_ce = 0.062562)
# Epoch: 14600 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.069068, b_ce = 0.052794)
# Epoch: 14610 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078623, b_ce = 0.062363)
# Epoch: 14620 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076543, b_ce = 0.060303)
# Epoch: 14630 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076683, b_ce = 0.060441)
# Epoch: 14640 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072601, b_ce = 0.056339)
# Epoch: 14650 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.071694, b_ce = 0.055415)
# Epoch: 14660 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072480, b_ce = 0.056225)
# Epoch: 14670 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079554, b_ce = 0.063275)
# Epoch: 14680 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074856, b_ce = 0.058574)
# Epoch: 14690 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075371, b_ce = 0.059089)
# Epoch: 14700 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073912, b_ce = 0.057623)
# Epoch: 14710 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077993, b_ce = 0.061694)
# Epoch: 14720 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077043, b_ce = 0.060765)
# Epoch: 14730 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075463, b_ce = 0.059140)
# Epoch: 14740 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078553, b_ce = 0.062228)
# Epoch: 14750 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072544, b_ce = 0.056206)
# Epoch: 14760 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075555, b_ce = 0.059239)
# Epoch: 14770 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078712, b_ce = 0.062391)
# Epoch: 14780 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077586, b_ce = 0.061256)
# Epoch: 14790 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079574, b_ce = 0.063233)
# Epoch: 14800 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.083257, b_ce = 0.066930)
# Epoch: 14810 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079620, b_ce = 0.063264)
# Epoch: 14820 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.079437, b_ce = 0.063082)
# Epoch: 14830 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075298, b_ce = 0.058951)
# Epoch: 14840 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075013, b_ce = 0.058650)
# Epoch: 14850 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077771, b_ce = 0.061388)
# Epoch: 14860 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077865, b_ce = 0.061505)
# Epoch: 14870 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.074537, b_ce = 0.058132)
# Epoch: 14880 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.080439, b_ce = 0.064045)
# Epoch: 14890 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.072993, b_ce = 0.056593)
# Epoch: 14900 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075151, b_ce = 0.058746)
# Epoch: 14910 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.073320, b_ce = 0.056892)
# Epoch: 14920 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076227, b_ce = 0.059836)
# Epoch: 14930 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076839, b_ce = 0.060426)
# Epoch: 14940 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076683, b_ce = 0.060266)
# Epoch: 14950 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077387, b_ce = 0.060956)
# Epoch: 14960 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.078335, b_ce = 0.061907)
# Epoch: 14970 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.077981, b_ce = 0.061541)
# Epoch: 14980 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.075583, b_ce = 0.059149)
# Epoch: 14990 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076567, b_ce = 0.060139)
# Epoch: 15000 Disc: (loss = 0.000000, acc = 50.00%) AAE: (mse = 0.076367, b_ce = 0.059906)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import os.path

savefile = ruta+"/"+nombre+".h5"

if not os.path.isfile(savefile):
    a_autoencoder.save(savefile)
else:
    print("Ya hay un modelo guardado en "+savefile)

# %% [markdown]
# El autoencoder parece ser incapaz de reconstruir las imagenes de la entrada

# %%
sample_imgs(sample_from, a_autoencoder, 0, 4, False)

# %% [markdown]
# Esto tambien sucede con el autoencoder sin la parte del discriminador cuando no se permite entrenar al encoder (inicializado con los pesos de imagenet).

# %% [markdown]
# Sin embargo si permitimos entrenar al encoder del autoencoder adversario, los resultados de generar imagenes con el decoder son estos:
#
# ![aa](./adversarialautoencoder2.0/AAE_encoder_entrenado.png)
