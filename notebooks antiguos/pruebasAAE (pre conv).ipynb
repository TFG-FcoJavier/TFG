# %% [markdown]
# # Preparacion del entorno

# %% [markdown]
# Librerias

# %%
import tensorflow as tf
from tensorflow import keras

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
from keras import Sequential
from keras import losses, metrics, optimizers
from keras.applications import mobilenet
from keras.layers import Input, Dense, Conv2D, Flatten, LeakyReLU, MaxPooling2D, UpSampling2D, GlobalAveragePooling2D, Reshape
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# Num GPUs Available:  1

# %% [markdown]
# Funcion para extraer los datos de los ficheros

# %%
# https://www.cs.toronto.edu/~kriz/cifar.html
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin')
    return dict

# %% [markdown]
# Extraemos los datos del fichero.

# %%
batch1 = unpickle("Input\cifar-10-batches-py\data_batch_1")
batch2 = unpickle("Input\cifar-10-batches-py\data_batch_2")
batch3 = unpickle("Input\cifar-10-batches-py\data_batch_3")
batch4 = unpickle("Input\cifar-10-batches-py\data_batch_4")
batch5 = unpickle("Input\cifar-10-batches-py\data_batch_5")

# %% [markdown]
# En cifar10 los datos estan almacenados en un diccionario que contiene el nombre del lote, las etiquetas para clasificacion, los datos (imagenes) y los nombres de fichero correspondientes.

# %%
print(batch1.keys())
for i in batch1:
    print(i, type(batch1[i]))
# Out:
# dict_keys(['batch_label', 'labels', 'data', 'filenames'])
# batch_label <class 'str'>
# labels <class 'list'>
# data <class 'numpy.ndarray'>
# filenames <class 'list'>

# %% [markdown]
# Las imagenes vienen en el modo ``channelsfirst``, en este modo, tenemos 3 matrices de la dimension de la imagen, una para cada canal. Muchas de las funciones admiten por defecto el modo ``chanelslast`` en el que tenemos una matriz de la dimension de la imagen y cada posicion tiene un vector con los codigos de color de cada punto.
#
# Por simplicidad, como paso de preprocesamiento, voy a transformar las imagenes de ``channelsfirst`` a ``channelslast``.

# %%
# https://www.binarystudy.com/2021/09/how-to-load-preprocess-visualize-CIFAR-10-and-CIFAR-100.html
imagen = batch1["data"][0]
imagen = imagen.reshape(3,32,32)
imagen=imagen.transpose(1,2,0)
print(imagen.shape)
# Out:
# (32, 32, 3)

# %%
plt.imshow(imagen)
plt.axis("off")
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %% [markdown]
# # Preparacion de los datos

# %% [markdown]
# Cargamos todas las imagenes de entrenamiento en la variable ``X_train`` y borramos todo lo demás ya que no lo vamos a utilizar.

# %%
print(batch1["data"].shape)
X_train = batch1["data"].reshape(10000, 3, 32, 32)
del batch1
X_train = np.concatenate((X_train, batch2["data"].reshape(10000, 3, 32, 32)))
del batch2
X_train = np.concatenate((X_train, batch3["data"].reshape(10000, 3, 32, 32)))
del batch3
X_train = np.concatenate((X_train, batch4["data"].reshape(10000, 3, 32, 32)))
del batch4
X_train = np.concatenate((X_train, batch5["data"].reshape(10000, 3, 32, 32)))
del batch5
X_train = X_train.transpose(0,2,3,1)
X_train=X_train/255
# Out:
# (10000, 3072)

# %%
print(X_train.shape)
plt.figure()
f, arrx = plt.subplots(1,2)
arrx[0].imshow(X_train[np.random.randint(0,X_train.shape[0])])
arrx[1].imshow(X_train[np.random.randint(0,X_train.shape[0])])
for a in arrx:
    a.axis("off")
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# # Arquitectura del ``Autoencoder``

# %% [markdown]
# ## Regla de la piramide geometrica

# %% [markdown]
# La regla de la piramide geometrica sirve para ayudar determinar el tamaño de las capas ocultas en base al tamaño de las capas de input y output y al numero de capas ocultas.
#
# Esta aproximacion esta propuesta por Masters(1993):
# >  "For a three layer network with n input and m output neurons, the hidden layer would have sqrt(N * M) neurons."
# >
# > -- <cite> Masters, Timothy. Pratical neural network recipes in C++. Morgan Kaufmann, 1993.</cite>
#
# [Enlace al artículo](https://eulertech.wordpress.com/2018/01/02/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-network/)

# %%
def pyramid_rule(h_layers, input_size, output_size):
    layers = []
    if h_layers < 1:
        print("No layers")
        return []
    print("Layers for input %d and output %d:" % (input_size,  output_size))
    rate = (input_size/output_size)**(1/(h_layers+1))
    for l in range(h_layers):
        layer_size = output_size*(rate**(h_layers-l))
        layer_size = round(layer_size)
        layers.append(layer_size)
        print("Layer %d: %d neurons" % (l+1, layer_size))
    return layers

# %% [markdown]
# ## EMD(Earth Mover's Distance) ``WIP``

# %% [markdown]
# EMD es una medida de distancia entre distribuciones de probabilidad, que consiste en representar ambas distribuciones como montones de tierra, en los que la distancia se determina en cuanto es el trabajo minimo que llevaria transformar un monticulo en otro. Matematicamente a EMD se la conoce como la métrica de Wasserstein.
#
# Segun [este artículo](https://machinelearningmastery.com/how-to-implement-wasserstein-loss-for-generative-adversarial-networks/) esta metrica se puede aplicar de la siguiente manera:

# %%
#def wasserstein_loss(y_true, y_pred):
	#return keras.backend.mean(y_true * y_pred)

# %% [markdown]
# ## Encoders

# %% [markdown]
# ### Transfer Encoder

# %% [markdown]
# Éste ``encoder`` va a ser un modelo basado en ``transfer learning``, vamos a tomar la red de ``mobilenet``, entranada para imagenes de ``imagenet`` sin las capa de clasificacion final, con una entrada de tamaño _img\_shape_ y en el output colocamos la 'representacion latente' una codificacion de la imagen que nos permitiría reconstruirla con un ``decoder``.

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/mobilenet/preprocess_input
# https://keras.io/guides/transfer_learning/
def build_transf_encoder(dim_latente, img_shape, trainable=False):
    inputs = Input(shape=img_shape)
    x=tf.cast(inputs, tf.float32)
    #x=keras.applications.mobilenet.preprocess_input(x)  #dataformat por defecto es chanel last
    core = mobilenet.MobileNet(input_shape=(img_shape), weights="imagenet", include_top=False)
    core.trainable = trainable
    model = core(x, training=trainable)
    model = GlobalAveragePooling2D()(model)
    repr_latente = Dense(dim_latente)(model)
    return keras.Model(inputs, repr_latente)

# %% [markdown]
# ### Encoder denso

# %%
def build_dense_encoder(dim_latente, img_shape, depth=2):
    layer_sizes = pyramid_rule(depth, np.prod(img_shape), dim_latente)
    model =  keras.Sequential()
    model.add(Flatten(input_shape=img_shape))
    for ls in layer_sizes:
        model.add(Dense(ls))
        model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(dim_latente))
    img = Input(shape=img_shape)
    z = model(img)
    return keras.Model(img, z)

# %% [markdown]
# ### Encoder convolucional

# %%
def build_conv_encoder(dim_latente, img_shape, depth=2):
    model =  keras.Sequential()
    model.add(Conv2D(32, (3,3), activation="relu", input_shape=img_shape))
    model.add(MaxPooling2D())
    for _ in range(depth-1):
        model.add(Conv2D(32, (3,3), activation="relu"))
        model.add(MaxPooling2D())
    model.add(Dense(dim_latente))
    img = Input(shape=img_shape)
    z = model(img)
    return keras.Model(img, z)

# %% [markdown]
# ## Decoders

# %% [markdown]
# ### Decoder denso

# %%
def build_dense_decoder(dim_latente, img_shape, depth=2):
    model = keras.Sequential()
    layer_sizes = pyramid_rule(depth, dim_latente, np.prod(img_shape))
    model.add(Dense(layer_sizes[0], input_dim=dim_latente))
    model.add(LeakyReLU(alpha=0.2))
    for i in range(1, depth):
        model.add(Dense(layer_sizes[i], input_dim=dim_latente))
        model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(np.prod(img_shape), activation=keras.activations.sigmoid))
    model.add(Reshape(img_shape))
    z = Input(shape=(dim_latente))
    img = model(z)
    return keras.Model(z, img)

# %% [markdown]
# ### Decoder convolucional

# %%
def build_conv_decoder(dim_latente, img_shape, depth=2):
    model=keras.Sequential()
    model.add(Conv2D(32, (3,3), input_shape=dim_latente))
    model.add(UpSampling2D())
    for _ in range(depth-1):
        model.add(Conv2D(32, (3,3)))
        model.add(UpSampling2D())
    model.add(Dense(np.prod(img_shape), activation=keras.activations.sigmoid))
    model.add(Reshape(img_shape))
    z = Input(shape=(dim_latente))
    img = model(z)
    return keras.Model(z, img)

# %%
optimizer = keras.optimizers.Adam(0.0002, 0.5)
dim_latente=64
img_shape=X_train[0].shape

encoder = build_conv_encoder(dim_latente, img_shape)
decoder = build_conv_decoder(dim_latente, img_shape)
img = keras.layers.Input(img_shape)

encoder_rep = encoder(img)
autoencoder_out = decoder(encoder_rep)

autoencoder = keras.Model(img, autoencoder_out)
autoencoder.compile(loss='mse', optimizer=optimizer, metrics=["accuracy"])
out = autoencoder.predict(X_train[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-45841e711c92> in <module>
#       4
#       5 encoder = build_conv_encoder(dim_latente, img_shape)
# ----> 6 decoder = build_conv_decoder(dim_latente, img_shape)
#       7 img = keras.layers.Input(img_shape)
#       8
#
# <ipython-input-58-824e1dc29851> in build_conv_decoder(dim_latente, img_shape, depth)
#       1 def build_conv_decoder(dim_latente, img_shape, depth=2):
#       2     model=keras.Sequential()
# ----> 3     model.add(Conv2D(32, (3,3), input_shape=dim_latente))
#       4     model.add(UpSampling2D())
#       5     for _ in range(depth-1):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\layers\convolutional.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     669                bias_constraint=None,
#     670                **kwargs):
# --> 671     super(Conv2D, self).__init__(
#     672         rank=2,
#     673         filters=filters,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\layers\convolutional.py in __init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, trainable, name, conv_op, **kwargs)
#     123                conv_op=None,
#     124                **kwargs):
# --> 125     super(Conv, self).__init__(
#     126         trainable=trainable,
#     127         name=name,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     431         else:
#     432           batch_size = None
# --> 433         batch_input_shape = (batch_size,) + tuple(kwargs['input_shape'])
#     434       self._batch_input_shape = batch_input_shape
#     435
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# ## Discriminador

# %% [markdown]
# El discriminador va a tener como entrada la codificacion latente de las imagenes y como salida una neurona que discrimina entre imagenes "reales" y "falsas". De esta forma entrenamos al encoder para que codifique con la distribucion que usemos para generar las "imagenes reales", en este caso, una distribución normal.

# %%
def build_discriminator(dim_latente, depth = 2):
    layer_sizes = pyramid_rule(depth, dim_latente, 1)
    model = Sequential()
    model.add(Dense(layer_sizes[0], input_dim=dim_latente))
    model.add(LeakyReLU(alpha=0.2))
    for i in range(1, depth):
        model.add(Dense(layer_sizes[i]))
        model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation=keras.activations.sigmoid))
    encoded = Input(shape=dim_latente)
    valid = model(encoded)
    return keras.Model(encoded, valid)

# %% [markdown]
# # Redes

# %% [markdown]
# Parametros

# %%
optimizer = keras.optimizers.Adam(0.0002, 0.5)

# %% [markdown]
# Metodo para la construccion

# %%
def assemble_AAE(dim_latente, img_shape, enc_model=build_dense_encoder, dec_model=build_dense_decoder, disc_model = build_discriminator):
    # Discriminador
    discriminator = disc_model(dim_latente)
    discriminator.compile(loss=losses.binary_crossentropy, metrics="accuracy")

    # Encoder y decoder
    encoder = enc_model(dim_latente, img_shape)
    decoder = dec_model(dim_latente, img_shape)

    # Autoencoder
    # el encoder toma un imagen y la codifica y el decoder toma la codificacion e intenta regenerar la imagen
    img = Input(shape=img_shape)
    encoded = encoder(img)
    reconstructed = decoder(encoded)

    # para el autoencoder adversario solo queremos entrenar el generador, no el discriminador
    discriminator.trainable=False

    # El discriminador evalua la validez de la codificacion
    validez = discriminator(encoded)

    # Autoencoder adversario 
    a_autoencoder = keras.Model(img, [reconstructed, validez])
    a_autoencoder.compile(loss=[losses.mean_squared_error, losses.binary_crossentropy], loss_weights=[0.999, 0.001], optimizer=optimizer)
    return (encoder, decoder, discriminator, a_autoencoder)

# %% [markdown]
# # Entrenamiento

# %% [markdown]
# ## Persistencia

# %%
_raiz = "pruebasAAE"
_nombre = "pAAE"

# %% [markdown]
# Creamos las carpetas para almacenar el output

# %%
def mkfolders(ruta, output=False):
    try:
        os.makedirs(ruta)
    except OSError:
        print("Carpeta %s ya existe" % (ruta))
    if output:
        try:
            os.mkdir(ruta+"/output")
        except OSError:
            print("Carpeta %s ya existe" % (ruta+"/output"))

# %%
mkfolders(_raiz, True)
# Out:
# Carpeta pruebasAAE ya existe

# %% [markdown]
# ## Funciones de muestreo

# %%
def sample_imgs(dataset, model, epoch, sample_size=5, save_imgs=True, show=False, ruta=_raiz, nombre="", title="", output=True):
    # Tomamos sample_size imagenes de muestra
    ids = np.random.randint(0,dataset.shape[0], sample_size)
    sample=dataset[ids]
    # Intentamos regenerar las imagenes
    gen_img = model.predict(sample)[0]
    # Guardamos una grafica con la muestra (arriba) y las imagenes generadas (abajo)
    f, axxs = plt.subplots(2,sample_size)
    if title!="":
        f.suptitle(title+"_"+nombre, fontsize=12)
    for j in range(sample_size):
        axxs[0,j].imshow(sample[j])
        axxs[1,j].imshow(gen_img[j])
    for i in axxs:
        for j in i:
            j.axis("off")
    if save_imgs:
        if output:
            ruta+="/output"
        savefile= ruta+"/"+nombre+"generationCIFAR10_e%d.jpg" % (epoch)
        f.savefig(savefile)
    if show:
        plt.show()
    plt.close()

# %%
def true_sampler(dim_latente, batch_size):
    return np.random.normal(size=(batch_size, dim_latente))

# %%
def generate_samples(dim_latente, decoder, epoch, ruta=_raiz, nombre=_nombre, output=True, show=False):
    sample_shape = (5,5)
    latent_samples = true_sampler(dim_latente, np.prod(sample_shape))
    samples=decoder.predict(latent_samples)#*0.5 +0.5
    fig, axxs = plt.subplots(sample_shape[0], sample_shape[1])
    s=0
    for i in range(sample_shape[0]):
        for j in range(sample_shape[1]):
            axxs[i,j].imshow(samples[s])
            axxs[i,j].axis("off")
            s+=1
    if output:
        ruta+="\output"
    fig.savefig(ruta+"\\"+nombre+"progresscifar10_e%d.png" % (epoch))
    if show:
        plt.show()
    plt.close()

# %% [markdown]
# Imagenes para testing

# %%
sample_from = unpickle("Input\cifar-10-batches-py\\test_batch")
sample_from = sample_from["data"]
sample_from = sample_from.reshape(10000,3,32,32)
sample_from = sample_from.transpose(0,2,3,1)
sample_from = sample_from/255

# %% [markdown]
# ## Grafica de progreso

# %%
def plot_history(history, ruta=_raiz, nombre=_nombre, title=""):
    disc_loss = history[0]
    disc_acc  = history[1]
    aac_loss1 = history[2]
    aac_loss2 = history[3]

    fig, axxs = plt.subplots(1,3)
    if title != "":
        fig.suptitle(title, fontsize=16)

    fig.set_figwidth(24)
    fig.set_figheight(6)

    axxs[0].set_title("Discriminator")
    axxs[1].set_title("Discriminator")
    axxs[2].set_title("AdversarialAutoencoder")

    axxs[0].set_xlabel("Epoch")
    axxs[1].set_xlabel("Epoch")
    axxs[2].set_xlabel("Epoch")

    axxs[0].plot(disc_loss, label = "Loss")
    axxs[1].plot(disc_acc, label = "Accuracy")

    axxs[2].plot(aac_loss1, label = "Loss_decoder")
    axxs[2].plot(aac_loss2, label = "Loss_discriminator")

    axxs[0].legend()
    axxs[1].legend()
    axxs[2].legend()

    fig.savefig(ruta+"\\"+nombre+"progresscifar10_plot.jpg")
    plt.show()
    plt.close()

# %% [markdown]
# ## Funcion de entrenamiento

# %%
def fit_AAE(dim_latente, aae, epochs=5000, batch_size=120, sample_interval=100, ruta=_raiz, nombre=_nombre, verbose=True):
    history = np.empty([0,4])

    encoder, decoder, discriminator, a_autoencoder=aae
    
    valid = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    for epoch in range(epochs+1):
        # lote de imagenes
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]

        latent_fake = encoder.predict(imgs)
        latent_true =true_sampler(dim_latente, batch_size)

        #entrenamos el discriminador
        dis_loss_real = discriminator.train_on_batch(latent_true, valid)
        dis_loss_fake = discriminator.train_on_batch(latent_fake, fake)
        dis_avg_loss = 0.5*np.add(dis_loss_fake, dis_loss_real)

        # entrenamos al autoencoder
        aae_loss = a_autoencoder.train_on_batch(imgs,[imgs, valid])
        
        # Guardamos el progreso
        history = np.append(history, [np.append(dis_avg_loss[:2], aae_loss[:2])], axis=0)
        
        # monitorizamos el progreso
        if epoch % 10==0 and verbose:
            print("Epoch: %d Disc: (loss = %f, acc = %.2f%%) AAE: (mse = %f, b_ce = %f)" % (epoch, dis_avg_loss[0], 100*dis_avg_loss[1], aae_loss[0], aae_loss[1]))
        # Hacemos una muestra visual
        if epoch % sample_interval==0:
            # sample_imgs(sample_from, autoencoder, epoch)
            generate_samples(dim_latente, decoder, epoch, ruta=ruta, nombre=nombre, show=(epoch==epochs))
    return history.transpose(1,0)

# %% [markdown]
# ## Entrenamiento en grid

# %% [markdown]
# Tamaño de la capa latente:

# %%
dim_latente_cand = [64, 128, 256, 512, 1024]

# %% [markdown]
# Tamaño de las imagenes:

# %%
img_shape = X_train[0].shape

# %%
encoders = [(build_dense_encoder, "dense_enc"), (build_transf_encoder,"transf_enc")]
decoders = [(build_dense_decoder,"dense_dec")]
discriminators = [(build_discriminator ,"default_disc")]

# %% [markdown]
# for z in dim_latente_cand:
#     ruta = _raiz+"\z"+str(z)
#     mkfolders(ruta, True)
#     aae = assemble_AAE(z,img_shape)
#     history = fit_AAE(z, aae, ruta=ruta, epochs=100)
#     plot_history(history, ruta=ruta)

# %%
for enc in encoders:
    for dec in decoders:
        for disc in discriminators:
            for dim_latente in dim_latente_cand:
                ruta = _raiz+"\\"+enc[1]+"\\"+dec[1]+"\\"+disc[1]+"\\"+str(dim_latente)
                if os.path.isfile(ruta+"\\decoder.h5"):
                    print(ruta+" ya ha sido entrenada")
                    continue
                mkfolders(ruta, True)
                aae = assemble_AAE(dim_latente, img_shape, enc_model = enc[0], dec_model = dec[0], disc_model = disc[0])
                history = fit_AAE(dim_latente, aae, ruta = ruta)
                plot_history(history, ruta=ruta, title=ruta)
                (_, decoder, _, autoencoder) = aae
                sample_imgs(X_train, autoencoder, 5000, show=True, ruta=ruta, title=ruta+" regeneration", nombre="TRAINSET",output=False)
                sample_imgs(sample_from, autoencoder, 5000, show=True, ruta=ruta, title=ruta+" regeneration", nombre="TESTSET",output=False)
                decoder.save(ruta+"\\decoder.h5")
                autoencoder.save(ruta+"\\autoencoder.h5")
# Out:
# Layers for input 64 and output 1:
# Layer 1: 16 neurons
# Layer 2: 4 neurons
# Layers for input 3072 and output 64:
# Layer 1: 845 neurons
# Layer 2: 233 neurons
# Layers for input 64 and output 3072:
# Layer 1: 233 neurons
# Layer 2: 845 neurons
# Epoch: 0 Disc: (loss = 0.789365, acc = 62.50%) AAE: (mse = 0.057971, b_ce = 0.057174)
# Epoch: 10 Disc: (loss = 1.784211, acc = 23.33%) AAE: (mse = 0.057393, b_ce = 0.057356)
# Epoch: 20 Disc: (loss = 1.833234, acc = 25.00%) AAE: (mse = 0.054575, b_ce = 0.054536)
# Epoch: 30 Disc: (loss = 1.218880, acc = 20.42%) AAE: (mse = 0.059694, b_ce = 0.059462)
# Epoch: 40 Disc: (loss = 1.374530, acc = 20.00%) AAE: (mse = 0.043648, b_ce = 0.043399)
# Epoch: 50 Disc: (loss = 1.054099, acc = 29.58%) AAE: (mse = 0.041892, b_ce = 0.041428)
# Epoch: 60 Disc: (loss = 0.861856, acc = 47.08%) AAE: (mse = 0.045885, b_ce = 0.045251)
# Epoch: 70 Disc: (loss = 0.724023, acc = 55.42%) AAE: (mse = 0.044652, b_ce = 0.043803)
# Epoch: 80 Disc: (loss = 0.785812, acc = 36.67%) AAE: (mse = 0.042095, b_ce = 0.041444)
# Epoch: 90 Disc: (loss = 0.998842, acc = 31.25%) AAE: (mse = 0.038834, b_ce = 0.038380)
# Epoch: 100 Disc: (loss = 0.921265, acc = 32.92%) AAE: (mse = 0.045063, b_ce = 0.044572)
# Epoch: 110 Disc: (loss = 0.803711, acc = 38.75%) AAE: (mse = 0.038225, b_ce = 0.037551)
# Epoch: 120 Disc: (loss = 0.926421, acc = 34.17%) AAE: (mse = 0.037054, b_ce = 0.036538)
# Epoch: 130 Disc: (loss = 0.795593, acc = 39.58%) AAE: (mse = 0.035949, b_ce = 0.035331)
# Epoch: 140 Disc: (loss = 0.651202, acc = 66.67%) AAE: (mse = 0.039444, b_ce = 0.038516)
# Epoch: 150 Disc: (loss = 0.600546, acc = 74.17%) AAE: (mse = 0.039380, b_ce = 0.038486)
# Epoch: 160 Disc: (loss = 0.520873, acc = 77.92%) AAE: (mse = 0.033742, b_ce = 0.032659)
# Epoch: 170 Disc: (loss = 0.447455, acc = 84.17%) AAE: (mse = 0.035343, b_ce = 0.033960)
# Epoch: 180 Disc: (loss = 0.416120, acc = 84.17%) AAE: (mse = 0.034783, b_ce = 0.033291)
# Epoch: 190 Disc: (loss = 0.634339, acc = 61.67%) AAE: (mse = 0.034538, b_ce = 0.033588)
# Epoch: 200 Disc: (loss = 2.375578, acc = 33.75%) AAE: (mse = 0.034339, b_ce = 0.034292)
# Epoch: 210 Disc: (loss = 2.982195, acc = 34.17%) AAE: (mse = 0.031520, b_ce = 0.031510)
# Epoch: 220 Disc: (loss = 1.936513, acc = 28.75%) AAE: (mse = 0.033530, b_ce = 0.033348)
# Epoch: 230 Disc: (loss = 0.816359, acc = 54.58%) AAE: (mse = 0.038309, b_ce = 0.036924)
# Epoch: 240 Disc: (loss = 2.072544, acc = 23.33%) AAE: (mse = 0.034223, b_ce = 0.034105)
# Epoch: 250 Disc: (loss = 2.231644, acc = 23.33%) AAE: (mse = 0.033162, b_ce = 0.033086)
# Epoch: 260 Disc: (loss = 1.881103, acc = 24.17%) AAE: (mse = 0.029633, b_ce = 0.029529)
# Epoch: 270 Disc: (loss = 1.328635, acc = 30.83%) AAE: (mse = 0.032563, b_ce = 0.032090)
# Epoch: 280 Disc: (loss = 1.065420, acc = 36.25%) AAE: (mse = 0.032748, b_ce = 0.032220)
# Epoch: 290 Disc: (loss = 1.420271, acc = 19.58%) AAE: (mse = 0.031182, b_ce = 0.030933)
# Epoch: 300 Disc: (loss = 0.915557, acc = 37.92%) AAE: (mse = 0.033593, b_ce = 0.032814)
# Epoch: 310 Disc: (loss = 0.708005, acc = 57.08%) AAE: (mse = 0.030800, b_ce = 0.029789)
# Epoch: 320 Disc: (loss = 0.788983, acc = 46.25%) AAE: (mse = 0.032205, b_ce = 0.031395)
# Epoch: 330 Disc: (loss = 0.757614, acc = 45.00%) AAE: (mse = 0.028813, b_ce = 0.028129)
# Epoch: 340 Disc: (loss = 0.770452, acc = 40.00%) AAE: (mse = 0.030048, b_ce = 0.029371)
# Epoch: 350 Disc: (loss = 1.200364, acc = 30.42%) AAE: (mse = 0.028662, b_ce = 0.028103)
# Epoch: 360 Disc: (loss = 2.153837, acc = 19.17%) AAE: (mse = 0.028707, b_ce = 0.028548)
# Epoch: 370 Disc: (loss = 2.268123, acc = 20.83%) AAE: (mse = 0.029792, b_ce = 0.029716)
# Epoch: 380 Disc: (loss = 2.017037, acc = 16.25%) AAE: (mse = 0.030422, b_ce = 0.030254)
# Epoch: 390 Disc: (loss = 1.946287, acc = 13.33%) AAE: (mse = 0.028139, b_ce = 0.027970)
# Epoch: 400 Disc: (loss = 2.047853, acc = 16.25%) AAE: (mse = 0.030369, b_ce = 0.030190)
# Epoch: 410 Disc: (loss = 2.049633, acc = 10.42%) AAE: (mse = 0.026200, b_ce = 0.026019)
# Epoch: 420 Disc: (loss = 1.936568, acc = 11.67%) AAE: (mse = 0.030795, b_ce = 0.030584)
# Epoch: 430 Disc: (loss = 1.562318, acc = 12.50%) AAE: (mse = 0.026794, b_ce = 0.026462)
# Epoch: 440 Disc: (loss = 1.111017, acc = 20.00%) AAE: (mse = 0.027563, b_ce = 0.026925)
# Epoch: 450 Disc: (loss = 0.836761, acc = 43.75%) AAE: (mse = 0.029763, b_ce = 0.028903)
# Epoch: 460 Disc: (loss = 0.684256, acc = 64.17%) AAE: (mse = 0.031058, b_ce = 0.030057)
# Epoch: 470 Disc: (loss = 0.670970, acc = 67.92%) AAE: (mse = 0.028480, b_ce = 0.027501)
# Epoch: 480 Disc: (loss = 0.601687, acc = 72.50%) AAE: (mse = 0.030440, b_ce = 0.029335)
# Epoch: 490 Disc: (loss = 0.664050, acc = 59.58%) AAE: (mse = 0.026347, b_ce = 0.025411)
# Epoch: 500 Disc: (loss = 1.224375, acc = 37.08%) AAE: (mse = 0.031919, b_ce = 0.031415)
# Epoch: 510 Disc: (loss = 1.842412, acc = 21.25%) AAE: (mse = 0.028687, b_ce = 0.028465)
# Epoch: 520 Disc: (loss = 1.945778, acc = 17.92%) AAE: (mse = 0.026007, b_ce = 0.025848)
# Epoch: 530 Disc: (loss = 1.552774, acc = 15.00%) AAE: (mse = 0.027303, b_ce = 0.027065)
# Epoch: 540 Disc: (loss = 1.494814, acc = 10.00%) AAE: (mse = 0.027373, b_ce = 0.027095)
# Epoch: 550 Disc: (loss = 1.274472, acc = 9.17%) AAE: (mse = 0.025486, b_ce = 0.025161)
# Epoch: 560 Disc: (loss = 1.086369, acc = 8.33%) AAE: (mse = 0.026771, b_ce = 0.026258)
# Epoch: 570 Disc: (loss = 0.927420, acc = 13.75%) AAE: (mse = 0.024183, b_ce = 0.023572)
# Epoch: 580 Disc: (loss = 0.823328, acc = 30.42%) AAE: (mse = 0.026078, b_ce = 0.025241)
# Epoch: 590 Disc: (loss = 0.669751, acc = 58.75%) AAE: (mse = 0.026892, b_ce = 0.025705)
# Epoch: 600 Disc: (loss = 0.687047, acc = 60.83%) AAE: (mse = 0.026271, b_ce = 0.025210)
# Epoch: 610 Disc: (loss = 0.642196, acc = 64.17%) AAE: (mse = 0.024412, b_ce = 0.023293)
# Epoch: 620 Disc: (loss = 1.008556, acc = 32.50%) AAE: (mse = 0.024879, b_ce = 0.024301)
# Epoch: 630 Disc: (loss = 2.190250, acc = 19.17%) AAE: (mse = 0.026722, b_ce = 0.026598)
# Epoch: 640 Disc: (loss = 1.650146, acc = 14.58%) AAE: (mse = 0.024664, b_ce = 0.024472)
# Epoch: 650 Disc: (loss = 1.050910, acc = 13.75%) AAE: (mse = 0.025711, b_ce = 0.025227)
# Epoch: 660 Disc: (loss = 0.903065, acc = 17.08%) AAE: (mse = 0.025467, b_ce = 0.024890)
# Epoch: 670 Disc: (loss = 0.732595, acc = 43.33%) AAE: (mse = 0.026483, b_ce = 0.025541)
# Epoch: 680 Disc: (loss = 0.636305, acc = 57.50%) AAE: (mse = 0.022231, b_ce = 0.020982)
# Epoch: 690 Disc: (loss = 0.578787, acc = 56.67%) AAE: (mse = 0.041856, b_ce = 0.040226)
# Epoch: 700 Disc: (loss = 0.873219, acc = 29.58%) AAE: (mse = 0.025056, b_ce = 0.024399)
# Epoch: 710 Disc: (loss = 1.059357, acc = 18.75%) AAE: (mse = 0.022235, b_ce = 0.021779)
# Epoch: 720 Disc: (loss = 0.795497, acc = 33.75%) AAE: (mse = 0.025171, b_ce = 0.024483)
# Epoch: 730 Disc: (loss = 0.638820, acc = 58.75%) AAE: (mse = 0.029425, b_ce = 0.028346)
# Epoch: 740 Disc: (loss = 0.574769, acc = 67.50%) AAE: (mse = 0.023628, b_ce = 0.022329)
# Epoch: 750 Disc: (loss = 0.577382, acc = 68.75%) AAE: (mse = 0.024192, b_ce = 0.023064)
# Epoch: 760 Disc: (loss = 1.853498, acc = 26.25%) AAE: (mse = 0.021041, b_ce = 0.020861)
# Epoch: 770 Disc: (loss = 1.720480, acc = 17.92%) AAE: (mse = 0.025668, b_ce = 0.025482)
# Epoch: 780 Disc: (loss = 1.219488, acc = 12.08%) AAE: (mse = 0.021498, b_ce = 0.021159)
# Epoch: 790 Disc: (loss = 0.915827, acc = 13.75%) AAE: (mse = 0.022360, b_ce = 0.021846)
# Epoch: 800 Disc: (loss = 0.730708, acc = 47.50%) AAE: (mse = 0.023053, b_ce = 0.022204)
# Epoch: 810 Disc: (loss = 0.702109, acc = 52.50%) AAE: (mse = 0.023312, b_ce = 0.022333)
# Epoch: 820 Disc: (loss = 0.607830, acc = 57.08%) AAE: (mse = 0.023580, b_ce = 0.022187)
# Epoch: 830 Disc: (loss = 0.604569, acc = 59.58%) AAE: (mse = 0.023751, b_ce = 0.022402)
# Epoch: 840 Disc: (loss = 0.830185, acc = 40.42%) AAE: (mse = 0.023839, b_ce = 0.023150)
# Epoch: 850 Disc: (loss = 0.879192, acc = 32.08%) AAE: (mse = 0.019616, b_ce = 0.019003)
# Epoch: 860 Disc: (loss = 0.706229, acc = 53.33%) AAE: (mse = 0.024062, b_ce = 0.023243)
# Epoch: 870 Disc: (loss = 0.607172, acc = 69.58%) AAE: (mse = 0.021968, b_ce = 0.020914)
# Epoch: 880 Disc: (loss = 0.571368, acc = 69.17%) AAE: (mse = 0.020810, b_ce = 0.019626)
# Epoch: 890 Disc: (loss = 0.824347, acc = 36.25%) AAE: (mse = 0.022471, b_ce = 0.021822)
# Epoch: 900 Disc: (loss = 0.827168, acc = 32.50%) AAE: (mse = 0.022538, b_ce = 0.021954)
# Epoch: 910 Disc: (loss = 0.813741, acc = 31.25%) AAE: (mse = 0.022221, b_ce = 0.021573)
# Epoch: 920 Disc: (loss = 0.818988, acc = 27.50%) AAE: (mse = 0.023943, b_ce = 0.023350)
# Epoch: 930 Disc: (loss = 1.580358, acc = 13.33%) AAE: (mse = 0.020682, b_ce = 0.020443)
# Epoch: 940 Disc: (loss = 1.073115, acc = 17.08%) AAE: (mse = 0.021692, b_ce = 0.021256)
# Epoch: 950 Disc: (loss = 0.976525, acc = 18.75%) AAE: (mse = 0.020924, b_ce = 0.020418)
# Epoch: 960 Disc: (loss = 0.748379, acc = 42.92%) AAE: (mse = 0.020947, b_ce = 0.020161)
# Epoch: 970 Disc: (loss = 0.660840, acc = 62.92%) AAE: (mse = 0.020316, b_ce = 0.019368)
# Epoch: 980 Disc: (loss = 0.588583, acc = 66.25%) AAE: (mse = 0.023327, b_ce = 0.022074)
# Epoch: 990 Disc: (loss = 0.604726, acc = 68.75%) AAE: (mse = 0.020696, b_ce = 0.019621)
# Epoch: 1000 Disc: (loss = 0.740250, acc = 52.08%) AAE: (mse = 0.021548, b_ce = 0.020788)
# Epoch: 1010 Disc: (loss = 1.358320, acc = 20.42%) AAE: (mse = 0.020063, b_ce = 0.019771)
# Epoch: 1020 Disc: (loss = 1.069646, acc = 25.42%) AAE: (mse = 0.020650, b_ce = 0.020254)
# Epoch: 1030 Disc: (loss = 1.061788, acc = 16.67%) AAE: (mse = 0.022180, b_ce = 0.021763)
# Epoch: 1040 Disc: (loss = 0.848442, acc = 20.83%) AAE: (mse = 0.028065, b_ce = 0.027453)
# Epoch: 1050 Disc: (loss = 0.642975, acc = 63.75%) AAE: (mse = 0.019832, b_ce = 0.018863)
# Epoch: 1060 Disc: (loss = 0.649580, acc = 61.67%) AAE: (mse = 0.020901, b_ce = 0.019950)
# Epoch: 1070 Disc: (loss = 0.599300, acc = 62.08%) AAE: (mse = 0.023199, b_ce = 0.021951)
# Epoch: 1080 Disc: (loss = 0.588350, acc = 67.50%) AAE: (mse = 0.020301, b_ce = 0.019173)
# Epoch: 1090 Disc: (loss = 0.715193, acc = 43.33%) AAE: (mse = 0.019957, b_ce = 0.019211)
# Epoch: 1100 Disc: (loss = 0.828553, acc = 30.83%) AAE: (mse = 0.019059, b_ce = 0.018440)
# Epoch: 1110 Disc: (loss = 0.627212, acc = 64.58%) AAE: (mse = 0.044839, b_ce = 0.043874)
# Epoch: 1120 Disc: (loss = 1.474939, acc = 17.08%) AAE: (mse = 0.021802, b_ce = 0.021585)
# Epoch: 1130 Disc: (loss = 1.011481, acc = 16.25%) AAE: (mse = 0.022107, b_ce = 0.021647)
# Epoch: 1140 Disc: (loss = 1.109551, acc = 17.08%) AAE: (mse = 0.026769, b_ce = 0.026391)
# Epoch: 1150 Disc: (loss = 0.735123, acc = 39.58%) AAE: (mse = 0.018988, b_ce = 0.018244)
# Epoch: 1160 Disc: (loss = 0.655608, acc = 63.75%) AAE: (mse = 0.020821, b_ce = 0.019862)
# Epoch: 1170 Disc: (loss = 0.585399, acc = 68.75%) AAE: (mse = 0.020439, b_ce = 0.019323)
# Epoch: 1180 Disc: (loss = 0.521769, acc = 69.58%) AAE: (mse = 0.020154, b_ce = 0.018773)
# Epoch: 1190 Disc: (loss = 0.499111, acc = 72.50%) AAE: (mse = 0.020960, b_ce = 0.019461)
# Epoch: 1200 Disc: (loss = 0.521394, acc = 75.83%) AAE: (mse = 0.020280, b_ce = 0.019037)
# Epoch: 1210 Disc: (loss = 0.959912, acc = 26.25%) AAE: (mse = 0.020169, b_ce = 0.019745)
# Epoch: 1220 Disc: (loss = 1.136946, acc = 25.83%) AAE: (mse = 0.019262, b_ce = 0.018967)
# Epoch: 1230 Disc: (loss = 1.417016, acc = 25.00%) AAE: (mse = 0.017939, b_ce = 0.017752)
# Epoch: 1240 Disc: (loss = 0.834803, acc = 23.75%) AAE: (mse = 0.018171, b_ce = 0.017653)
# Epoch: 1250 Disc: (loss = 0.776621, acc = 27.92%) AAE: (mse = 0.019639, b_ce = 0.019030)
# Epoch: 1260 Disc: (loss = 0.733893, acc = 40.00%) AAE: (mse = 0.018512, b_ce = 0.017790)
# Epoch: 1270 Disc: (loss = 0.632046, acc = 66.25%) AAE: (mse = 0.017937, b_ce = 0.017014)
# Epoch: 1280 Disc: (loss = 0.558714, acc = 71.25%) AAE: (mse = 0.018995, b_ce = 0.017878)
# Epoch: 1290 Disc: (loss = 0.580783, acc = 62.08%) AAE: (mse = 0.024432, b_ce = 0.023272)
# Epoch: 1300 Disc: (loss = 0.839299, acc = 40.00%) AAE: (mse = 0.021167, b_ce = 0.020536)
# Epoch: 1310 Disc: (loss = 1.648604, acc = 19.17%) AAE: (mse = 0.018562, b_ce = 0.018400)
# Epoch: 1320 Disc: (loss = 1.255859, acc = 19.17%) AAE: (mse = 0.019807, b_ce = 0.019531)
# Epoch: 1330 Disc: (loss = 0.939935, acc = 22.50%) AAE: (mse = 0.023627, b_ce = 0.023166)
# Epoch: 1340 Disc: (loss = 1.030384, acc = 16.67%) AAE: (mse = 0.018705, b_ce = 0.018280)
# Epoch: 1350 Disc: (loss = 0.639166, acc = 65.00%) AAE: (mse = 0.018973, b_ce = 0.018122)
# Epoch: 1360 Disc: (loss = 0.611720, acc = 69.17%) AAE: (mse = 0.019280, b_ce = 0.018328)
# Epoch: 1370 Disc: (loss = 0.526111, acc = 72.08%) AAE: (mse = 0.017723, b_ce = 0.016480)
# Epoch: 1380 Disc: (loss = 0.465855, acc = 77.50%) AAE: (mse = 0.019191, b_ce = 0.017769)
# Epoch: 1390 Disc: (loss = 0.469104, acc = 78.33%) AAE: (mse = 0.019164, b_ce = 0.017789)
# Epoch: 1400 Disc: (loss = 0.933076, acc = 36.67%) AAE: (mse = 0.025620, b_ce = 0.025214)
# Epoch: 1410 Disc: (loss = 1.718617, acc = 29.17%) AAE: (mse = 0.017940, b_ce = 0.017833)
# Epoch: 1420 Disc: (loss = 1.679954, acc = 26.25%) AAE: (mse = 0.017259, b_ce = 0.017141)
# Epoch: 1430 Disc: (loss = 1.442605, acc = 21.67%) AAE: (mse = 0.019095, b_ce = 0.018927)
# Epoch: 1440 Disc: (loss = 1.332383, acc = 21.25%) AAE: (mse = 0.018400, b_ce = 0.018185)
# Epoch: 1450 Disc: (loss = 1.039191, acc = 19.17%) AAE: (mse = 0.018701, b_ce = 0.018342)
# Epoch: 1460 Disc: (loss = 0.673360, acc = 58.33%) AAE: (mse = 0.020948, b_ce = 0.020070)
# Epoch: 1470 Disc: (loss = 0.814746, acc = 24.17%) AAE: (mse = 0.018524, b_ce = 0.017927)
# Epoch: 1480 Disc: (loss = 0.675674, acc = 58.33%) AAE: (mse = 0.020054, b_ce = 0.019204)
# Epoch: 1490 Disc: (loss = 1.064433, acc = 17.50%) AAE: (mse = 0.018408, b_ce = 0.017966)
# Epoch: 1500 Disc: (loss = 0.583008, acc = 70.42%) AAE: (mse = 0.017896, b_ce = 0.016853)
# Epoch: 1510 Disc: (loss = 0.625685, acc = 68.75%) AAE: (mse = 0.017983, b_ce = 0.017059)
# Epoch: 1520 Disc: (loss = 0.541347, acc = 72.92%) AAE: (mse = 0.020801, b_ce = 0.019635)
# Epoch: 1530 Disc: (loss = 0.454664, acc = 78.33%) AAE: (mse = 0.018205, b_ce = 0.016703)
# Epoch: 1540 Disc: (loss = 0.435412, acc = 81.25%) AAE: (mse = 0.018246, b_ce = 0.016498)
# Epoch: 1550 Disc: (loss = 0.586226, acc = 69.58%) AAE: (mse = 0.018967, b_ce = 0.018015)
# Epoch: 1560 Disc: (loss = 1.610906, acc = 28.33%) AAE: (mse = 0.020859, b_ce = 0.020749)
# Epoch: 1570 Disc: (loss = 1.394298, acc = 33.75%) AAE: (mse = 0.017077, b_ce = 0.016936)
# Epoch: 1580 Disc: (loss = 1.274547, acc = 29.58%) AAE: (mse = 0.017361, b_ce = 0.017177)
# Epoch: 1590 Disc: (loss = 1.061230, acc = 28.33%) AAE: (mse = 0.018453, b_ce = 0.018164)
# Epoch: 1600 Disc: (loss = 0.864347, acc = 29.17%) AAE: (mse = 0.018091, b_ce = 0.017639)
# Epoch: 1610 Disc: (loss = 0.761405, acc = 32.92%) AAE: (mse = 0.017325, b_ce = 0.016658)
# Epoch: 1620 Disc: (loss = 0.609425, acc = 70.42%) AAE: (mse = 0.018241, b_ce = 0.017314)
# Epoch: 1630 Disc: (loss = 0.571655, acc = 70.42%) AAE: (mse = 0.017453, b_ce = 0.016258)
# Epoch: 1640 Disc: (loss = 0.592761, acc = 67.92%) AAE: (mse = 0.017232, b_ce = 0.016141)
# Epoch: 1650 Disc: (loss = 0.828618, acc = 27.50%) AAE: (mse = 0.017883, b_ce = 0.017313)
# Epoch: 1660 Disc: (loss = 1.859272, acc = 20.83%) AAE: (mse = 0.017215, b_ce = 0.017120)
# Epoch: 1670 Disc: (loss = 0.657685, acc = 57.50%) AAE: (mse = 0.020643, b_ce = 0.019756)
# Epoch: 1680 Disc: (loss = 1.384333, acc = 16.25%) AAE: (mse = 0.017884, b_ce = 0.017687)
# Epoch: 1690 Disc: (loss = 1.238071, acc = 11.67%) AAE: (mse = 0.017276, b_ce = 0.017017)
# Epoch: 1700 Disc: (loss = 0.788587, acc = 32.92%) AAE: (mse = 0.016247, b_ce = 0.015638)
# Epoch: 1710 Disc: (loss = 0.694055, acc = 54.17%) AAE: (mse = 0.017725, b_ce = 0.016991)
# Epoch: 1720 Disc: (loss = 0.629070, acc = 67.92%) AAE: (mse = 0.017372, b_ce = 0.016502)
# Epoch: 1730 Disc: (loss = 0.545881, acc = 75.83%) AAE: (mse = 0.017564, b_ce = 0.016458)
# Epoch: 1740 Disc: (loss = 0.473925, acc = 77.50%) AAE: (mse = 0.017355, b_ce = 0.016045)
# Epoch: 1750 Disc: (loss = 0.512924, acc = 74.17%) AAE: (mse = 0.017976, b_ce = 0.016687)
# Epoch: 1760 Disc: (loss = 0.931911, acc = 35.83%) AAE: (mse = 0.018223, b_ce = 0.017808)
# Epoch: 1770 Disc: (loss = 1.403614, acc = 28.33%) AAE: (mse = 0.015982, b_ce = 0.015814)
# Epoch: 1780 Disc: (loss = 1.348446, acc = 27.50%) AAE: (mse = 0.016407, b_ce = 0.016240)
# Epoch: 1790 Disc: (loss = 1.289840, acc = 27.50%) AAE: (mse = 0.015940, b_ce = 0.015741)
# Epoch: 1800 Disc: (loss = 1.127697, acc = 22.08%) AAE: (mse = 0.016611, b_ce = 0.016339)
# Epoch: 1810 Disc: (loss = 0.853915, acc = 21.67%) AAE: (mse = 0.017056, b_ce = 0.016592)
# Epoch: 1820 Disc: (loss = 0.790550, acc = 20.83%) AAE: (mse = 0.016087, b_ce = 0.015523)
# Epoch: 1830 Disc: (loss = 0.670776, acc = 59.17%) AAE: (mse = 0.016812, b_ce = 0.015942)
# Epoch: 1840 Disc: (loss = 0.625026, acc = 68.75%) AAE: (mse = 0.017635, b_ce = 0.016665)
# Epoch: 1850 Disc: (loss = 0.597479, acc = 64.58%) AAE: (mse = 0.018029, b_ce = 0.016931)
# Epoch: 1860 Disc: (loss = 0.637345, acc = 65.00%) AAE: (mse = 0.019913, b_ce = 0.018901)
# Epoch: 1870 Disc: (loss = 1.356728, acc = 24.58%) AAE: (mse = 0.017333, b_ce = 0.017143)
# Epoch: 1880 Disc: (loss = 1.327252, acc = 26.67%) AAE: (mse = 0.016336, b_ce = 0.016152)
# Epoch: 1890 Disc: (loss = 1.331279, acc = 23.75%) AAE: (mse = 0.016525, b_ce = 0.016340)
# Epoch: 1900 Disc: (loss = 0.895631, acc = 27.92%) AAE: (mse = 0.017942, b_ce = 0.017481)
# Epoch: 1910 Disc: (loss = 0.942279, acc = 21.67%) AAE: (mse = 0.017785, b_ce = 0.017335)
# Epoch: 1920 Disc: (loss = 0.697259, acc = 54.58%) AAE: (mse = 0.017193, b_ce = 0.016452)
# Epoch: 1930 Disc: (loss = 0.752091, acc = 37.92%) AAE: (mse = 0.016164, b_ce = 0.015504)
# Epoch: 1940 Disc: (loss = 0.697612, acc = 50.00%) AAE: (mse = 0.015492, b_ce = 0.014729)
# Epoch: 1950 Disc: (loss = 0.687083, acc = 58.75%) AAE: (mse = 0.017651, b_ce = 0.016845)
# Epoch: 1960 Disc: (loss = 0.604114, acc = 65.00%) AAE: (mse = 0.016361, b_ce = 0.015374)
# Epoch: 1970 Disc: (loss = 0.646364, acc = 62.50%) AAE: (mse = 0.017197, b_ce = 0.016320)
# Epoch: 1980 Disc: (loss = 0.668224, acc = 60.42%) AAE: (mse = 0.017172, b_ce = 0.016287)
# Epoch: 1990 Disc: (loss = 0.732184, acc = 45.83%) AAE: (mse = 0.016563, b_ce = 0.015810)
# Epoch: 2000 Disc: (loss = 0.793292, acc = 28.33%) AAE: (mse = 0.018921, b_ce = 0.018278)
# Epoch: 2010 Disc: (loss = 1.022844, acc = 16.67%) AAE: (mse = 0.017551, b_ce = 0.017165)
# Epoch: 2020 Disc: (loss = 0.817217, acc = 25.42%) AAE: (mse = 0.017024, b_ce = 0.016413)
# Epoch: 2030 Disc: (loss = 0.698107, acc = 54.58%) AAE: (mse = 0.016568, b_ce = 0.015707)
# Epoch: 2040 Disc: (loss = 0.822652, acc = 25.83%) AAE: (mse = 0.017459, b_ce = 0.016868)
# Epoch: 2050 Disc: (loss = 0.875687, acc = 15.42%) AAE: (mse = 0.016535, b_ce = 0.016028)
# Epoch: 2060 Disc: (loss = 0.912030, acc = 12.08%) AAE: (mse = 0.018758, b_ce = 0.018315)
# Epoch: 2070 Disc: (loss = 0.792289, acc = 14.17%) AAE: (mse = 0.015468, b_ce = 0.014894)
# Epoch: 2080 Disc: (loss = 0.790170, acc = 12.92%) AAE: (mse = 0.015855, b_ce = 0.015285)
# Epoch: 2090 Disc: (loss = 0.694794, acc = 47.08%) AAE: (mse = 0.019728, b_ce = 0.019029)
# Epoch: 2100 Disc: (loss = 0.653224, acc = 69.17%) AAE: (mse = 0.016132, b_ce = 0.015322)
# Epoch: 2110 Disc: (loss = 0.572109, acc = 75.83%) AAE: (mse = 0.015683, b_ce = 0.014708)
# Epoch: 2120 Disc: (loss = 0.541312, acc = 76.25%) AAE: (mse = 0.016645, b_ce = 0.015581)
# Epoch: 2130 Disc: (loss = 0.710026, acc = 46.67%) AAE: (mse = 0.016751, b_ce = 0.016121)
# Epoch: 2140 Disc: (loss = 0.963087, acc = 26.67%) AAE: (mse = 0.016770, b_ce = 0.016411)
# Epoch: 2150 Disc: (loss = 1.504291, acc = 27.08%) AAE: (mse = 0.015321, b_ce = 0.015200)
# Epoch: 2160 Disc: (loss = 1.050104, acc = 23.33%) AAE: (mse = 0.016882, b_ce = 0.016588)
# Epoch: 2170 Disc: (loss = 1.051239, acc = 23.75%) AAE: (mse = 0.016049, b_ce = 0.015748)
# Epoch: 2180 Disc: (loss = 0.786397, acc = 20.00%) AAE: (mse = 0.015205, b_ce = 0.014642)
# Epoch: 2190 Disc: (loss = 0.656649, acc = 64.17%) AAE: (mse = 0.017346, b_ce = 0.016549)
# Epoch: 2200 Disc: (loss = 0.605029, acc = 70.00%) AAE: (mse = 0.015490, b_ce = 0.014541)
# Epoch: 2210 Disc: (loss = 0.584120, acc = 70.00%) AAE: (mse = 0.015424, b_ce = 0.014415)
# Epoch: 2220 Disc: (loss = 0.560648, acc = 75.42%) AAE: (mse = 0.015170, b_ce = 0.014180)
# Epoch: 2230 Disc: (loss = 0.699189, acc = 50.83%) AAE: (mse = 0.015502, b_ce = 0.014829)
# Epoch: 2240 Disc: (loss = 1.009242, acc = 24.17%) AAE: (mse = 0.016030, b_ce = 0.015711)
# Epoch: 2250 Disc: (loss = 1.247207, acc = 27.92%) AAE: (mse = 0.013491, b_ce = 0.013310)
# Epoch: 2260 Disc: (loss = 0.944455, acc = 28.33%) AAE: (mse = 0.020791, b_ce = 0.020451)
# Epoch: 2270 Disc: (loss = 0.917757, acc = 27.50%) AAE: (mse = 0.016323, b_ce = 0.015956)
# Epoch: 2280 Disc: (loss = 0.841418, acc = 29.17%) AAE: (mse = 0.015726, b_ce = 0.015295)
# Epoch: 2290 Disc: (loss = 0.697369, acc = 35.42%) AAE: (mse = 0.015692, b_ce = 0.015107)
# Epoch: 2300 Disc: (loss = 0.609176, acc = 71.25%) AAE: (mse = 0.019493, b_ce = 0.018691)
# Epoch: 2310 Disc: (loss = 0.512209, acc = 82.92%) AAE: (mse = 0.014733, b_ce = 0.013730)
# Epoch: 2320 Disc: (loss = 0.492407, acc = 80.42%) AAE: (mse = 0.015221, b_ce = 0.014041)
# Epoch: 2330 Disc: (loss = 0.453261, acc = 87.92%) AAE: (mse = 0.016156, b_ce = 0.015082)
# Epoch: 2340 Disc: (loss = 1.290434, acc = 31.67%) AAE: (mse = 0.018398, b_ce = 0.018217)
# Epoch: 2350 Disc: (loss = 1.925682, acc = 34.58%) AAE: (mse = 0.013893, b_ce = 0.013855)
# Epoch: 2360 Disc: (loss = 1.734989, acc = 34.58%) AAE: (mse = 0.015471, b_ce = 0.015412)
# Epoch: 2370 Disc: (loss = 1.539125, acc = 37.92%) AAE: (mse = 0.014959, b_ce = 0.014868)
# Epoch: 2380 Disc: (loss = 1.299834, acc = 33.33%) AAE: (mse = 0.014167, b_ce = 0.014007)
# Epoch: 2390 Disc: (loss = 1.136411, acc = 37.08%) AAE: (mse = 0.014687, b_ce = 0.014469)
# Epoch: 2400 Disc: (loss = 0.835979, acc = 40.00%) AAE: (mse = 0.013898, b_ce = 0.013488)
# Epoch: 2410 Disc: (loss = 0.819409, acc = 31.25%) AAE: (mse = 0.016389, b_ce = 0.015932)
# Epoch: 2420 Disc: (loss = 0.669860, acc = 46.25%) AAE: (mse = 0.018303, b_ce = 0.017629)
# Epoch: 2430 Disc: (loss = 0.592870, acc = 72.92%) AAE: (mse = 0.015412, b_ce = 0.014522)
# Epoch: 2440 Disc: (loss = 0.545701, acc = 77.08%) AAE: (mse = 0.016446, b_ce = 0.015435)
# Epoch: 2450 Disc: (loss = 0.532383, acc = 75.83%) AAE: (mse = 0.016047, b_ce = 0.015045)
# Epoch: 2460 Disc: (loss = 0.938878, acc = 35.42%) AAE: (mse = 0.015259, b_ce = 0.014845)
# Epoch: 2470 Disc: (loss = 1.736146, acc = 27.92%) AAE: (mse = 0.015972, b_ce = 0.015902)
# Epoch: 2480 Disc: (loss = 1.730005, acc = 28.33%) AAE: (mse = 0.014167, b_ce = 0.014094)
# Epoch: 2490 Disc: (loss = 1.086337, acc = 26.25%) AAE: (mse = 0.016061, b_ce = 0.015773)
# Epoch: 2500 Disc: (loss = 1.239350, acc = 25.83%) AAE: (mse = 0.015308, b_ce = 0.015103)
# Epoch: 2510 Disc: (loss = 1.029886, acc = 23.33%) AAE: (mse = 0.015090, b_ce = 0.014732)
# Epoch: 2520 Disc: (loss = 0.837790, acc = 27.92%) AAE: (mse = 0.016641, b_ce = 0.016093)
# Epoch: 2530 Disc: (loss = 0.834564, acc = 27.50%) AAE: (mse = 0.014620, b_ce = 0.014071)
# Epoch: 2540 Disc: (loss = 1.216030, acc = 15.42%) AAE: (mse = 0.014619, b_ce = 0.014356)
# Epoch: 2550 Disc: (loss = 1.265589, acc = 14.58%) AAE: (mse = 0.016218, b_ce = 0.015993)
# Epoch: 2560 Disc: (loss = 1.017977, acc = 22.92%) AAE: (mse = 0.016497, b_ce = 0.016156)
# Epoch: 2570 Disc: (loss = 0.809910, acc = 23.75%) AAE: (mse = 0.015696, b_ce = 0.015133)
# Epoch: 2580 Disc: (loss = 0.715033, acc = 45.83%) AAE: (mse = 0.015888, b_ce = 0.015160)
# Epoch: 2590 Disc: (loss = 0.666071, acc = 56.67%) AAE: (mse = 0.014866, b_ce = 0.014041)
# Epoch: 2600 Disc: (loss = 0.724791, acc = 45.00%) AAE: (mse = 0.014815, b_ce = 0.014146)
# Epoch: 2610 Disc: (loss = 0.696821, acc = 49.17%) AAE: (mse = 0.022078, b_ce = 0.021323)
# Epoch: 2620 Disc: (loss = 1.162900, acc = 14.58%) AAE: (mse = 0.014065, b_ce = 0.013784)
# Epoch: 2630 Disc: (loss = 0.993526, acc = 16.67%) AAE: (mse = 0.014950, b_ce = 0.014559)
# Epoch: 2640 Disc: (loss = 0.847981, acc = 14.17%) AAE: (mse = 0.018935, b_ce = 0.018370)
# Epoch: 2650 Disc: (loss = 0.814876, acc = 22.50%) AAE: (mse = 0.016139, b_ce = 0.015491)
# Epoch: 2660 Disc: (loss = 0.683062, acc = 57.50%) AAE: (mse = 0.017420, b_ce = 0.016501)
# Epoch: 2670 Disc: (loss = 0.660460, acc = 57.92%) AAE: (mse = 0.015104, b_ce = 0.014116)
# Epoch: 2680 Disc: (loss = 0.778720, acc = 36.67%) AAE: (mse = 0.015344, b_ce = 0.014681)
# Epoch: 2690 Disc: (loss = 0.987812, acc = 12.92%) AAE: (mse = 0.015886, b_ce = 0.015469)
# Epoch: 2700 Disc: (loss = 0.823136, acc = 19.58%) AAE: (mse = 0.015724, b_ce = 0.015166)
# Epoch: 2710 Disc: (loss = 0.739165, acc = 38.33%) AAE: (mse = 0.015068, b_ce = 0.014394)
# Epoch: 2720 Disc: (loss = 0.665628, acc = 65.00%) AAE: (mse = 0.014421, b_ce = 0.013617)
# Epoch: 2730 Disc: (loss = 0.634361, acc = 66.67%) AAE: (mse = 0.014809, b_ce = 0.013878)
# Epoch: 2740 Disc: (loss = 0.616180, acc = 65.83%) AAE: (mse = 0.014804, b_ce = 0.013810)
# Epoch: 2750 Disc: (loss = 0.613988, acc = 67.92%) AAE: (mse = 0.014627, b_ce = 0.013685)
# Epoch: 2760 Disc: (loss = 0.739980, acc = 45.83%) AAE: (mse = 0.023049, b_ce = 0.022420)
# Epoch: 2770 Disc: (loss = 0.704827, acc = 43.33%) AAE: (mse = 0.069282, b_ce = 0.068677)
# Epoch: 2780 Disc: (loss = 0.597789, acc = 70.00%) AAE: (mse = 0.027413, b_ce = 0.026488)
# Epoch: 2790 Disc: (loss = 0.738386, acc = 36.67%) AAE: (mse = 0.025052, b_ce = 0.024436)
# Epoch: 2800 Disc: (loss = 0.865434, acc = 26.25%) AAE: (mse = 0.018314, b_ce = 0.017863)
# Epoch: 2810 Disc: (loss = 0.687963, acc = 56.67%) AAE: (mse = 0.021250, b_ce = 0.020516)
# Epoch: 2820 Disc: (loss = 0.683307, acc = 52.08%) AAE: (mse = 0.015718, b_ce = 0.015005)
# Epoch: 2830 Disc: (loss = 0.610375, acc = 68.75%) AAE: (mse = 0.016506, b_ce = 0.015609)
# Epoch: 2840 Disc: (loss = 0.538033, acc = 71.67%) AAE: (mse = 0.020202, b_ce = 0.019077)
# Epoch: 2850 Disc: (loss = 0.504270, acc = 76.25%) AAE: (mse = 0.016423, b_ce = 0.015192)
# Epoch: 2860 Disc: (loss = 0.454943, acc = 80.42%) AAE: (mse = 0.016778, b_ce = 0.015481)
# Epoch: 2870 Disc: (loss = 0.693609, acc = 53.33%) AAE: (mse = 0.015407, b_ce = 0.014779)
# Epoch: 2880 Disc: (loss = 0.810867, acc = 38.75%) AAE: (mse = 0.015927, b_ce = 0.015449)
# Epoch: 2890 Disc: (loss = 0.877523, acc = 31.67%) AAE: (mse = 0.016439, b_ce = 0.015993)
# Epoch: 2900 Disc: (loss = 0.808705, acc = 33.75%) AAE: (mse = 0.018171, b_ce = 0.017712)
# Epoch: 2910 Disc: (loss = 0.666485, acc = 47.50%) AAE: (mse = 0.014730, b_ce = 0.014062)
# Epoch: 2920 Disc: (loss = 0.658559, acc = 59.58%) AAE: (mse = 0.016547, b_ce = 0.015815)
# Epoch: 2930 Disc: (loss = 0.715476, acc = 50.83%) AAE: (mse = 0.016540, b_ce = 0.015861)
# Epoch: 2940 Disc: (loss = 0.878395, acc = 40.42%) AAE: (mse = 0.015386, b_ce = 0.014825)
# Epoch: 2950 Disc: (loss = 1.537778, acc = 26.67%) AAE: (mse = 0.019901, b_ce = 0.019704)
# Epoch: 2960 Disc: (loss = 1.838300, acc = 25.42%) AAE: (mse = 0.014622, b_ce = 0.014508)
# Epoch: 2970 Disc: (loss = 1.579511, acc = 23.75%) AAE: (mse = 0.015119, b_ce = 0.014974)
# Epoch: 2980 Disc: (loss = 1.477655, acc = 19.58%) AAE: (mse = 0.015348, b_ce = 0.015185)
# Epoch: 2990 Disc: (loss = 1.570307, acc = 17.50%) AAE: (mse = 0.013468, b_ce = 0.013344)
# Epoch: 3000 Disc: (loss = 1.158787, acc = 25.00%) AAE: (mse = 0.015011, b_ce = 0.014737)
# Epoch: 3010 Disc: (loss = 1.011362, acc = 24.58%) AAE: (mse = 0.019732, b_ce = 0.019361)
# Epoch: 3020 Disc: (loss = 0.922906, acc = 27.50%) AAE: (mse = 0.015444, b_ce = 0.014928)
# Epoch: 3030 Disc: (loss = 0.751365, acc = 49.58%) AAE: (mse = 0.014904, b_ce = 0.014101)
# Epoch: 3040 Disc: (loss = 0.684038, acc = 55.00%) AAE: (mse = 0.015802, b_ce = 0.014926)
# Epoch: 3050 Disc: (loss = 0.609629, acc = 65.00%) AAE: (mse = 0.016904, b_ce = 0.015786)
# Epoch: 3060 Disc: (loss = 0.612300, acc = 67.92%) AAE: (mse = 0.016707, b_ce = 0.015660)
# Epoch: 3070 Disc: (loss = 0.940163, acc = 32.92%) AAE: (mse = 0.015481, b_ce = 0.014973)
# Epoch: 3080 Disc: (loss = 0.981478, acc = 27.08%) AAE: (mse = 0.014413, b_ce = 0.013964)
# Epoch: 3090 Disc: (loss = 0.990983, acc = 31.25%) AAE: (mse = 0.015166, b_ce = 0.014789)
# Epoch: 3100 Disc: (loss = 0.955443, acc = 32.92%) AAE: (mse = 0.014067, b_ce = 0.013641)
# Epoch: 3110 Disc: (loss = 0.840648, acc = 33.75%) AAE: (mse = 0.014594, b_ce = 0.014096)
# Epoch: 3120 Disc: (loss = 0.745037, acc = 40.00%) AAE: (mse = 0.014201, b_ce = 0.013608)
# Epoch: 3130 Disc: (loss = 0.652866, acc = 53.33%) AAE: (mse = 0.013967, b_ce = 0.013291)
# Epoch: 3140 Disc: (loss = 0.678795, acc = 47.08%) AAE: (mse = 0.014940, b_ce = 0.014272)
# Epoch: 3150 Disc: (loss = 0.663341, acc = 59.17%) AAE: (mse = 0.015288, b_ce = 0.014532)
# Epoch: 3160 Disc: (loss = 0.631051, acc = 56.25%) AAE: (mse = 0.014708, b_ce = 0.013955)
# Epoch: 3170 Disc: (loss = 0.650653, acc = 58.75%) AAE: (mse = 0.015008, b_ce = 0.014215)
# Epoch: 3180 Disc: (loss = 0.737622, acc = 47.50%) AAE: (mse = 0.014248, b_ce = 0.013553)
# Epoch: 3190 Disc: (loss = 0.576296, acc = 69.17%) AAE: (mse = 0.017395, b_ce = 0.016448)
# Epoch: 3200 Disc: (loss = 0.585104, acc = 67.92%) AAE: (mse = 0.015825, b_ce = 0.014932)
# Epoch: 3210 Disc: (loss = 0.631795, acc = 62.08%) AAE: (mse = 0.016126, b_ce = 0.015226)
# Epoch: 3220 Disc: (loss = 0.498890, acc = 77.92%) AAE: (mse = 0.016870, b_ce = 0.015781)
# Epoch: 3230 Disc: (loss = 0.622594, acc = 61.25%) AAE: (mse = 0.015414, b_ce = 0.014631)
# Epoch: 3240 Disc: (loss = 0.809141, acc = 37.50%) AAE: (mse = 0.015734, b_ce = 0.015228)
# Epoch: 3250 Disc: (loss = 0.746333, acc = 33.75%) AAE: (mse = 0.015112, b_ce = 0.014531)
# Epoch: 3260 Disc: (loss = 0.633794, acc = 57.92%) AAE: (mse = 0.015166, b_ce = 0.014406)
# Epoch: 3270 Disc: (loss = 0.833775, acc = 34.58%) AAE: (mse = 0.015879, b_ce = 0.015336)
# Epoch: 3280 Disc: (loss = 0.620076, acc = 65.42%) AAE: (mse = 0.016989, b_ce = 0.016192)
# Epoch: 3290 Disc: (loss = 0.639579, acc = 60.83%) AAE: (mse = 0.014316, b_ce = 0.013541)
# Epoch: 3300 Disc: (loss = 1.217672, acc = 30.00%) AAE: (mse = 0.015123, b_ce = 0.014818)
# Epoch: 3310 Disc: (loss = 1.396965, acc = 23.75%) AAE: (mse = 0.014521, b_ce = 0.014304)
# Epoch: 3320 Disc: (loss = 1.343320, acc = 25.42%) AAE: (mse = 0.014636, b_ce = 0.014432)
# Epoch: 3330 Disc: (loss = 1.236376, acc = 27.92%) AAE: (mse = 0.014130, b_ce = 0.013882)
# Epoch: 3340 Disc: (loss = 0.847716, acc = 40.42%) AAE: (mse = 0.016627, b_ce = 0.016067)
# Epoch: 3350 Disc: (loss = 0.903487, acc = 23.75%) AAE: (mse = 0.019067, b_ce = 0.018547)
# Epoch: 3360 Disc: (loss = 0.705075, acc = 54.58%) AAE: (mse = 0.015877, b_ce = 0.015009)
# Epoch: 3370 Disc: (loss = 0.661692, acc = 61.67%) AAE: (mse = 0.015199, b_ce = 0.014100)
# Epoch: 3380 Disc: (loss = 0.666827, acc = 57.92%) AAE: (mse = 0.014739, b_ce = 0.013764)
# Epoch: 3390 Disc: (loss = 1.052228, acc = 28.33%) AAE: (mse = 0.015014, b_ce = 0.014593)
# Epoch: 3400 Disc: (loss = 1.111344, acc = 28.75%) AAE: (mse = 0.013117, b_ce = 0.012783)
# Epoch: 3410 Disc: (loss = 1.001656, acc = 33.33%) AAE: (mse = 0.014705, b_ce = 0.014350)
# Epoch: 3420 Disc: (loss = 0.882129, acc = 32.08%) AAE: (mse = 0.013733, b_ce = 0.013292)
# Epoch: 3430 Disc: (loss = 0.785614, acc = 30.42%) AAE: (mse = 0.014030, b_ce = 0.013503)
# Epoch: 3440 Disc: (loss = 0.737608, acc = 41.25%) AAE: (mse = 0.015492, b_ce = 0.014880)
# Epoch: 3450 Disc: (loss = 0.660386, acc = 59.17%) AAE: (mse = 0.013070, b_ce = 0.012344)
# Epoch: 3460 Disc: (loss = 0.730121, acc = 52.08%) AAE: (mse = 0.014774, b_ce = 0.014073)
# Epoch: 3470 Disc: (loss = 0.880258, acc = 41.67%) AAE: (mse = 0.015028, b_ce = 0.014473)
# Epoch: 3480 Disc: (loss = 1.133184, acc = 24.17%) AAE: (mse = 0.014674, b_ce = 0.014331)
# Epoch: 3490 Disc: (loss = 0.744539, acc = 50.00%) AAE: (mse = 0.015474, b_ce = 0.014799)
# Epoch: 3500 Disc: (loss = 0.688167, acc = 53.33%) AAE: (mse = 0.015149, b_ce = 0.014422)
# Epoch: 3510 Disc: (loss = 0.863329, acc = 40.00%) AAE: (mse = 0.024572, b_ce = 0.024113)
# Epoch: 3520 Disc: (loss = 0.762182, acc = 44.17%) AAE: (mse = 0.014230, b_ce = 0.013703)
# Epoch: 3530 Disc: (loss = 0.874561, acc = 31.25%) AAE: (mse = 0.015144, b_ce = 0.014711)
# Epoch: 3540 Disc: (loss = 1.070946, acc = 30.00%) AAE: (mse = 0.014228, b_ce = 0.013923)
# Epoch: 3550 Disc: (loss = 0.907236, acc = 27.92%) AAE: (mse = 0.014605, b_ce = 0.014159)
# Epoch: 3560 Disc: (loss = 0.899777, acc = 34.58%) AAE: (mse = 0.014127, b_ce = 0.013594)
# Epoch: 3570 Disc: (loss = 0.733192, acc = 52.92%) AAE: (mse = 0.013930, b_ce = 0.013173)
# Epoch: 3580 Disc: (loss = 0.630507, acc = 63.33%) AAE: (mse = 0.016600, b_ce = 0.015586)
# Epoch: 3590 Disc: (loss = 0.629882, acc = 64.58%) AAE: (mse = 0.015457, b_ce = 0.014303)
# Epoch: 3600 Disc: (loss = 0.878648, acc = 36.25%) AAE: (mse = 0.013921, b_ce = 0.013356)
# Epoch: 3610 Disc: (loss = 1.012424, acc = 32.50%) AAE: (mse = 0.013953, b_ce = 0.013594)
# Epoch: 3620 Disc: (loss = 0.949570, acc = 30.83%) AAE: (mse = 0.014154, b_ce = 0.013772)
# Epoch: 3630 Disc: (loss = 0.901109, acc = 29.17%) AAE: (mse = 0.013580, b_ce = 0.013161)
# Epoch: 3640 Disc: (loss = 0.755310, acc = 32.50%) AAE: (mse = 0.014401, b_ce = 0.013861)
# Epoch: 3650 Disc: (loss = 0.679837, acc = 47.08%) AAE: (mse = 0.013445, b_ce = 0.012796)
# Epoch: 3660 Disc: (loss = 0.619600, acc = 64.58%) AAE: (mse = 0.014362, b_ce = 0.013600)
# Epoch: 3670 Disc: (loss = 0.622989, acc = 65.42%) AAE: (mse = 0.014218, b_ce = 0.013369)
# Epoch: 3680 Disc: (loss = 0.618843, acc = 63.75%) AAE: (mse = 0.014283, b_ce = 0.013395)
# Epoch: 3690 Disc: (loss = 0.810768, acc = 42.50%) AAE: (mse = 0.014038, b_ce = 0.013453)
# Epoch: 3700 Disc: (loss = 0.976054, acc = 30.42%) AAE: (mse = 0.014272, b_ce = 0.013810)
# Epoch: 3710 Disc: (loss = 1.346919, acc = 24.17%) AAE: (mse = 0.015302, b_ce = 0.015057)
# Epoch: 3720 Disc: (loss = 1.615397, acc = 17.92%) AAE: (mse = 0.013496, b_ce = 0.013307)
# Epoch: 3730 Disc: (loss = 0.772692, acc = 46.25%) AAE: (mse = 0.015460, b_ce = 0.014774)
# Epoch: 3740 Disc: (loss = 1.193360, acc = 28.75%) AAE: (mse = 0.014742, b_ce = 0.014376)
# Epoch: 3750 Disc: (loss = 0.673455, acc = 53.75%) AAE: (mse = 0.016990, b_ce = 0.016224)
# Epoch: 3760 Disc: (loss = 0.734333, acc = 44.58%) AAE: (mse = 0.014522, b_ce = 0.013848)
# Epoch: 3770 Disc: (loss = 0.712468, acc = 44.17%) AAE: (mse = 0.014538, b_ce = 0.013874)
# Epoch: 3780 Disc: (loss = 0.703926, acc = 46.67%) AAE: (mse = 0.014770, b_ce = 0.014061)
# Epoch: 3790 Disc: (loss = 0.666995, acc = 59.17%) AAE: (mse = 0.013923, b_ce = 0.013139)
# Epoch: 3800 Disc: (loss = 0.672138, acc = 59.17%) AAE: (mse = 0.015630, b_ce = 0.014871)
# Epoch: 3810 Disc: (loss = 0.814860, acc = 47.50%) AAE: (mse = 0.013207, b_ce = 0.012582)
# Epoch: 3820 Disc: (loss = 1.013119, acc = 32.92%) AAE: (mse = 0.014717, b_ce = 0.014313)
# Epoch: 3830 Disc: (loss = 0.922070, acc = 37.92%) AAE: (mse = 0.013693, b_ce = 0.013274)
# Epoch: 3840 Disc: (loss = 0.836651, acc = 32.08%) AAE: (mse = 0.014506, b_ce = 0.013981)
# Epoch: 3850 Disc: (loss = 0.868698, acc = 38.33%) AAE: (mse = 0.016133, b_ce = 0.015640)
# Epoch: 3860 Disc: (loss = 1.085665, acc = 25.83%) AAE: (mse = 0.014930, b_ce = 0.014596)
# Epoch: 3870 Disc: (loss = 0.923013, acc = 32.08%) AAE: (mse = 0.014182, b_ce = 0.013750)
# Epoch: 3880 Disc: (loss = 0.833402, acc = 32.92%) AAE: (mse = 0.014303, b_ce = 0.013780)
# Epoch: 3890 Disc: (loss = 0.772891, acc = 32.92%) AAE: (mse = 0.013389, b_ce = 0.012788)
# Epoch: 3900 Disc: (loss = 0.701987, acc = 47.50%) AAE: (mse = 0.014265, b_ce = 0.013571)
# Epoch: 3910 Disc: (loss = 0.624441, acc = 58.75%) AAE: (mse = 0.014894, b_ce = 0.014047)
# Epoch: 3920 Disc: (loss = 0.617507, acc = 65.00%) AAE: (mse = 0.014752, b_ce = 0.013798)
# Epoch: 3930 Disc: (loss = 0.544576, acc = 72.92%) AAE: (mse = 0.014813, b_ce = 0.013809)
# Epoch: 3940 Disc: (loss = 0.630820, acc = 67.92%) AAE: (mse = 0.014329, b_ce = 0.013504)
# Epoch: 3950 Disc: (loss = 0.775344, acc = 47.92%) AAE: (mse = 0.013728, b_ce = 0.013068)
# Epoch: 3960 Disc: (loss = 0.736359, acc = 51.67%) AAE: (mse = 0.016031, b_ce = 0.015368)
# Epoch: 3970 Disc: (loss = 0.889517, acc = 42.08%) AAE: (mse = 0.015688, b_ce = 0.015170)
# Epoch: 3980 Disc: (loss = 1.109884, acc = 23.33%) AAE: (mse = 0.014140, b_ce = 0.013821)
# Epoch: 3990 Disc: (loss = 0.602523, acc = 67.50%) AAE: (mse = 0.014878, b_ce = 0.013955)
# Epoch: 4000 Disc: (loss = 0.552719, acc = 70.83%) AAE: (mse = 0.014188, b_ce = 0.013256)
# Epoch: 4010 Disc: (loss = 0.650092, acc = 63.75%) AAE: (mse = 0.014379, b_ce = 0.013525)
# Epoch: 4020 Disc: (loss = 1.251142, acc = 27.50%) AAE: (mse = 0.012005, b_ce = 0.011756)
# Epoch: 4030 Disc: (loss = 1.535467, acc = 22.92%) AAE: (mse = 0.013753, b_ce = 0.013615)
# Epoch: 4040 Disc: (loss = 1.227470, acc = 22.92%) AAE: (mse = 0.014375, b_ce = 0.014109)
# Epoch: 4050 Disc: (loss = 0.749820, acc = 44.58%) AAE: (mse = 0.014295, b_ce = 0.013485)
# Epoch: 4060 Disc: (loss = 0.694331, acc = 61.25%) AAE: (mse = 0.015222, b_ce = 0.014191)
# Epoch: 4070 Disc: (loss = 0.990468, acc = 27.50%) AAE: (mse = 0.014388, b_ce = 0.013875)
# Epoch: 4080 Disc: (loss = 0.945438, acc = 27.50%) AAE: (mse = 0.014418, b_ce = 0.013952)
# Epoch: 4090 Disc: (loss = 0.895183, acc = 27.50%) AAE: (mse = 0.014506, b_ce = 0.014038)
# Epoch: 4100 Disc: (loss = 0.748719, acc = 35.83%) AAE: (mse = 0.013013, b_ce = 0.012423)
# Epoch: 4110 Disc: (loss = 0.668059, acc = 52.92%) AAE: (mse = 0.013368, b_ce = 0.012651)
# Epoch: 4120 Disc: (loss = 0.601358, acc = 65.00%) AAE: (mse = 0.013361, b_ce = 0.012540)
# Epoch: 4130 Disc: (loss = 0.557290, acc = 73.33%) AAE: (mse = 0.013222, b_ce = 0.012298)
# Epoch: 4140 Disc: (loss = 0.656548, acc = 64.58%) AAE: (mse = 0.013880, b_ce = 0.013065)
# Epoch: 4150 Disc: (loss = 0.920267, acc = 42.92%) AAE: (mse = 0.014980, b_ce = 0.014509)
# Epoch: 4160 Disc: (loss = 1.473097, acc = 29.17%) AAE: (mse = 0.018573, b_ce = 0.018420)
# Epoch: 4170 Disc: (loss = 1.313812, acc = 29.58%) AAE: (mse = 0.013515, b_ce = 0.013318)
# Epoch: 4180 Disc: (loss = 0.906875, acc = 24.58%) AAE: (mse = 0.013940, b_ce = 0.013419)
# Epoch: 4190 Disc: (loss = 0.751105, acc = 45.00%) AAE: (mse = 0.014214, b_ce = 0.013396)
# Epoch: 4200 Disc: (loss = 0.532766, acc = 70.42%) AAE: (mse = 0.015091, b_ce = 0.013638)
# Epoch: 4210 Disc: (loss = 0.611794, acc = 68.75%) AAE: (mse = 0.014880, b_ce = 0.013678)
# Epoch: 4220 Disc: (loss = 0.849798, acc = 36.67%) AAE: (mse = 0.014316, b_ce = 0.013738)
# Epoch: 4230 Disc: (loss = 0.940673, acc = 29.17%) AAE: (mse = 0.013678, b_ce = 0.013255)
# Epoch: 4240 Disc: (loss = 0.930051, acc = 30.42%) AAE: (mse = 0.013449, b_ce = 0.013059)
# Epoch: 4250 Disc: (loss = 0.750733, acc = 32.50%) AAE: (mse = 0.014734, b_ce = 0.014178)
# Epoch: 4260 Disc: (loss = 0.736515, acc = 32.92%) AAE: (mse = 0.013460, b_ce = 0.012884)
# Epoch: 4270 Disc: (loss = 0.713772, acc = 50.42%) AAE: (mse = 0.013511, b_ce = 0.012851)
# Epoch: 4280 Disc: (loss = 0.763131, acc = 48.33%) AAE: (mse = 0.016902, b_ce = 0.016230)
# Epoch: 4290 Disc: (loss = 0.595023, acc = 67.50%) AAE: (mse = 0.013026, b_ce = 0.012086)
# Epoch: 4300 Disc: (loss = 0.833176, acc = 46.25%) AAE: (mse = 0.015999, b_ce = 0.015434)
# Epoch: 4310 Disc: (loss = 1.133217, acc = 29.17%) AAE: (mse = 0.013430, b_ce = 0.013130)
# Epoch: 4320 Disc: (loss = 0.818186, acc = 34.58%) AAE: (mse = 0.013998, b_ce = 0.013362)
# Epoch: 4330 Disc: (loss = 0.655836, acc = 64.58%) AAE: (mse = 0.013815, b_ce = 0.012792)
# Epoch: 4340 Disc: (loss = 1.048740, acc = 27.50%) AAE: (mse = 0.012836, b_ce = 0.012500)
# Epoch: 4350 Disc: (loss = 1.078698, acc = 23.75%) AAE: (mse = 0.013232, b_ce = 0.012914)
# Epoch: 4360 Disc: (loss = 0.892586, acc = 24.17%) AAE: (mse = 0.012720, b_ce = 0.012248)
# Epoch: 4370 Disc: (loss = 0.843756, acc = 25.00%) AAE: (mse = 0.013333, b_ce = 0.012849)
# Epoch: 4380 Disc: (loss = 0.689926, acc = 53.33%) AAE: (mse = 0.014542, b_ce = 0.013810)
# Epoch: 4390 Disc: (loss = 0.557403, acc = 74.58%) AAE: (mse = 0.013934, b_ce = 0.012952)
# Epoch: 4400 Disc: (loss = 0.499393, acc = 77.08%) AAE: (mse = 0.014152, b_ce = 0.013099)
# Epoch: 4410 Disc: (loss = 0.484287, acc = 78.33%) AAE: (mse = 0.013658, b_ce = 0.012583)
# Epoch: 4420 Disc: (loss = 0.904767, acc = 49.58%) AAE: (mse = 0.014499, b_ce = 0.013982)
# Epoch: 4430 Disc: (loss = 1.445394, acc = 37.08%) AAE: (mse = 0.015298, b_ce = 0.015157)
# Epoch: 4440 Disc: (loss = 1.107558, acc = 22.50%) AAE: (mse = 0.014510, b_ce = 0.014199)
# Epoch: 4450 Disc: (loss = 0.744558, acc = 45.00%) AAE: (mse = 0.015001, b_ce = 0.014225)
# Epoch: 4460 Disc: (loss = 0.747868, acc = 45.83%) AAE: (mse = 0.014062, b_ce = 0.013237)
# Epoch: 4470 Disc: (loss = 1.055981, acc = 17.08%) AAE: (mse = 0.012544, b_ce = 0.012150)
# Epoch: 4480 Disc: (loss = 0.953863, acc = 19.58%) AAE: (mse = 0.014654, b_ce = 0.014229)
# Epoch: 4490 Disc: (loss = 0.792741, acc = 28.75%) AAE: (mse = 0.013203, b_ce = 0.012637)
# Epoch: 4500 Disc: (loss = 0.644718, acc = 63.33%) AAE: (mse = 0.015093, b_ce = 0.014221)
# Epoch: 4510 Disc: (loss = 0.620162, acc = 67.50%) AAE: (mse = 0.012456, b_ce = 0.011593)
# Epoch: 4520 Disc: (loss = 0.626569, acc = 67.50%) AAE: (mse = 0.012524, b_ce = 0.011590)
# Epoch: 4530 Disc: (loss = 0.654818, acc = 65.42%) AAE: (mse = 0.013453, b_ce = 0.012622)
# Epoch: 4540 Disc: (loss = 0.781364, acc = 47.92%) AAE: (mse = 0.014287, b_ce = 0.013669)
# Epoch: 4550 Disc: (loss = 1.213124, acc = 30.42%) AAE: (mse = 0.013874, b_ce = 0.013621)
# Epoch: 4560 Disc: (loss = 0.847322, acc = 25.83%) AAE: (mse = 0.014144, b_ce = 0.013568)
# Epoch: 4570 Disc: (loss = 0.562290, acc = 73.75%) AAE: (mse = 0.014794, b_ce = 0.013631)
# Epoch: 4580 Disc: (loss = 0.549080, acc = 76.25%) AAE: (mse = 0.014038, b_ce = 0.012812)
# Epoch: 4590 Disc: (loss = 1.189450, acc = 25.00%) AAE: (mse = 0.013055, b_ce = 0.012785)
# Epoch: 4600 Disc: (loss = 1.105425, acc = 32.08%) AAE: (mse = 0.014025, b_ce = 0.013748)
# Epoch: 4610 Disc: (loss = 1.057348, acc = 25.42%) AAE: (mse = 0.014158, b_ce = 0.013859)
# Epoch: 4620 Disc: (loss = 0.866350, acc = 30.42%) AAE: (mse = 0.012989, b_ce = 0.012549)
# Epoch: 4630 Disc: (loss = 0.722933, acc = 36.25%) AAE: (mse = 0.016762, b_ce = 0.016186)
# Epoch: 4640 Disc: (loss = 0.668627, acc = 57.50%) AAE: (mse = 0.014423, b_ce = 0.013669)
# Epoch: 4650 Disc: (loss = 0.602393, acc = 69.58%) AAE: (mse = 0.014010, b_ce = 0.013150)
# Epoch: 4660 Disc: (loss = 0.948090, acc = 45.00%) AAE: (mse = 0.013034, b_ce = 0.012521)
# Epoch: 4670 Disc: (loss = 1.386256, acc = 28.75%) AAE: (mse = 0.013091, b_ce = 0.012914)
# Epoch: 4680 Disc: (loss = 1.014953, acc = 15.83%) AAE: (mse = 0.013236, b_ce = 0.012791)
# Epoch: 4690 Disc: (loss = 0.735752, acc = 49.58%) AAE: (mse = 0.014268, b_ce = 0.013346)
# Epoch: 4700 Disc: (loss = 1.009781, acc = 22.50%) AAE: (mse = 0.012959, b_ce = 0.012482)
# Epoch: 4710 Disc: (loss = 0.865766, acc = 21.25%) AAE: (mse = 0.012706, b_ce = 0.012117)
# Epoch: 4720 Disc: (loss = 0.841425, acc = 18.33%) AAE: (mse = 0.013069, b_ce = 0.012516)
# Epoch: 4730 Disc: (loss = 0.869556, acc = 21.67%) AAE: (mse = 0.013943, b_ce = 0.013400)
# Epoch: 4740 Disc: (loss = 0.771386, acc = 47.92%) AAE: (mse = 0.017015, b_ce = 0.016266)
# Epoch: 4750 Disc: (loss = 0.754730, acc = 47.08%) AAE: (mse = 0.012778, b_ce = 0.011967)
# Epoch: 4760 Disc: (loss = 0.815356, acc = 38.75%) AAE: (mse = 0.014150, b_ce = 0.013369)
# Epoch: 4770 Disc: (loss = 0.735976, acc = 49.58%) AAE: (mse = 0.013386, b_ce = 0.012498)
# Epoch: 4780 Disc: (loss = 0.695017, acc = 59.58%) AAE: (mse = 0.014440, b_ce = 0.013552)
# Epoch: 4790 Disc: (loss = 0.764640, acc = 47.50%) AAE: (mse = 0.013206, b_ce = 0.012499)
# Epoch: 4800 Disc: (loss = 0.716221, acc = 57.92%) AAE: (mse = 0.013485, b_ce = 0.012733)
# Epoch: 4810 Disc: (loss = 0.621327, acc = 69.58%) AAE: (mse = 0.013697, b_ce = 0.012795)
# Epoch: 4820 Disc: (loss = 0.613614, acc = 65.00%) AAE: (mse = 0.013915, b_ce = 0.013057)
# Epoch: 4830 Disc: (loss = 0.559837, acc = 75.00%) AAE: (mse = 0.013517, b_ce = 0.012604)
# Epoch: 4840 Disc: (loss = 1.358873, acc = 26.67%) AAE: (mse = 0.014217, b_ce = 0.014019)
# Epoch: 4850 Disc: (loss = 1.158064, acc = 29.58%) AAE: (mse = 0.012492, b_ce = 0.012204)
# Epoch: 4860 Disc: (loss = 0.902519, acc = 26.25%) AAE: (mse = 0.013187, b_ce = 0.012657)
# Epoch: 4870 Disc: (loss = 0.868961, acc = 31.25%) AAE: (mse = 0.013850, b_ce = 0.013212)
# Epoch: 4880 Disc: (loss = 0.826766, acc = 31.67%) AAE: (mse = 0.013722, b_ce = 0.013132)
# Epoch: 4890 Disc: (loss = 0.866712, acc = 21.67%) AAE: (mse = 0.012829, b_ce = 0.012304)
# Epoch: 4900 Disc: (loss = 0.872716, acc = 19.58%) AAE: (mse = 0.013612, b_ce = 0.013109)
# Epoch: 4910 Disc: (loss = 0.931344, acc = 16.25%) AAE: (mse = 0.014253, b_ce = 0.013747)
# Epoch: 4920 Disc: (loss = 0.659392, acc = 59.58%) AAE: (mse = 0.014730, b_ce = 0.013791)
# Epoch: 4930 Disc: (loss = 0.712072, acc = 56.25%) AAE: (mse = 0.013527, b_ce = 0.012684)
# Epoch: 4940 Disc: (loss = 0.721251, acc = 51.25%) AAE: (mse = 0.012701, b_ce = 0.011706)
# Epoch: 4950 Disc: (loss = 0.767723, acc = 46.25%) AAE: (mse = 0.014636, b_ce = 0.013801)
# Epoch: 4960 Disc: (loss = 0.673759, acc = 63.33%) AAE: (mse = 0.014113, b_ce = 0.013134)
# Epoch: 4970 Disc: (loss = 0.664694, acc = 62.08%) AAE: (mse = 0.014453, b_ce = 0.013431)
# Epoch: 4980 Disc: (loss = 0.887092, acc = 35.83%) AAE: (mse = 0.012951, b_ce = 0.012263)
# Epoch: 4990 Disc: (loss = 0.726090, acc = 51.25%) AAE: (mse = 0.014188, b_ce = 0.013168)
# Epoch: 5000 Disc: (loss = 0.600071, acc = 58.33%) AAE: (mse = 0.015141, b_ce = 0.013726)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Layers for input 128 and output 1:
# Layer 1: 25 neurons
# Layer 2: 5 neurons
# Layers for input 3072 and output 128:
# Layer 1: 1065 neurons
# Layer 2: 369 neurons
# Layers for input 128 and output 3072:
# Layer 1: 369 neurons
# Layer 2: 1065 neurons
# Epoch: 0 Disc: (loss = 0.834230, acc = 34.17%) AAE: (mse = 0.066733, b_ce = 0.065996)
# Epoch: 10 Disc: (loss = 2.146361, acc = 23.33%) AAE: (mse = 0.086560, b_ce = 0.086485)
# Epoch: 20 Disc: (loss = 1.888527, acc = 23.75%) AAE: (mse = 0.066076, b_ce = 0.065982)
# Epoch: 30 Disc: (loss = 0.721802, acc = 57.92%) AAE: (mse = 0.056198, b_ce = 0.055389)
# Epoch: 40 Disc: (loss = 1.352666, acc = 25.83%) AAE: (mse = 0.053731, b_ce = 0.053393)
# Epoch: 50 Disc: (loss = 1.119717, acc = 31.67%) AAE: (mse = 0.050375, b_ce = 0.049921)
# Epoch: 60 Disc: (loss = 0.513046, acc = 78.33%) AAE: (mse = 0.055593, b_ce = 0.054345)
# Epoch: 70 Disc: (loss = 1.074720, acc = 35.42%) AAE: (mse = 0.046526, b_ce = 0.046034)
# Epoch: 80 Disc: (loss = 2.889290, acc = 30.83%) AAE: (mse = 0.047992, b_ce = 0.047959)
# Epoch: 90 Disc: (loss = 1.465858, acc = 32.08%) AAE: (mse = 0.043836, b_ce = 0.043280)
# Epoch: 100 Disc: (loss = 1.165883, acc = 30.83%) AAE: (mse = 0.047380, b_ce = 0.047082)
# Epoch: 110 Disc: (loss = 1.032700, acc = 35.00%) AAE: (mse = 0.042198, b_ce = 0.041776)
# Epoch: 120 Disc: (loss = 0.859995, acc = 39.17%) AAE: (mse = 0.047630, b_ce = 0.046801)
# Epoch: 130 Disc: (loss = 0.786762, acc = 39.58%) AAE: (mse = 0.040609, b_ce = 0.039834)
# Epoch: 140 Disc: (loss = 0.767769, acc = 39.58%) AAE: (mse = 0.043830, b_ce = 0.042946)
# Epoch: 150 Disc: (loss = 1.539763, acc = 30.42%) AAE: (mse = 0.041642, b_ce = 0.041188)
# Epoch: 160 Disc: (loss = 1.565335, acc = 21.67%) AAE: (mse = 0.037480, b_ce = 0.037179)
# Epoch: 170 Disc: (loss = 1.630735, acc = 21.67%) AAE: (mse = 0.038169, b_ce = 0.037989)
# Epoch: 180 Disc: (loss = 1.143980, acc = 17.92%) AAE: (mse = 0.039015, b_ce = 0.038590)
# Epoch: 190 Disc: (loss = 1.407945, acc = 18.75%) AAE: (mse = 0.039325, b_ce = 0.039029)
# Epoch: 200 Disc: (loss = 0.929797, acc = 28.75%) AAE: (mse = 0.037490, b_ce = 0.036717)
# Epoch: 210 Disc: (loss = 1.023237, acc = 23.33%) AAE: (mse = 0.034690, b_ce = 0.034204)
# Epoch: 220 Disc: (loss = 0.871881, acc = 31.25%) AAE: (mse = 0.039650, b_ce = 0.039002)
# Epoch: 230 Disc: (loss = 0.768164, acc = 42.08%) AAE: (mse = 0.034850, b_ce = 0.033991)
# Epoch: 240 Disc: (loss = 1.807146, acc = 27.50%) AAE: (mse = 0.037212, b_ce = 0.036912)
# Epoch: 250 Disc: (loss = 2.860022, acc = 27.08%) AAE: (mse = 0.034846, b_ce = 0.034780)
# Epoch: 260 Disc: (loss = 2.091385, acc = 20.00%) AAE: (mse = 0.033176, b_ce = 0.033020)
# Epoch: 270 Disc: (loss = 2.091692, acc = 22.92%) AAE: (mse = 0.030971, b_ce = 0.030748)
# Epoch: 280 Disc: (loss = 1.619371, acc = 16.25%) AAE: (mse = 0.032070, b_ce = 0.031683)
# Epoch: 290 Disc: (loss = 1.148745, acc = 22.50%) AAE: (mse = 0.034134, b_ce = 0.033569)
# Epoch: 300 Disc: (loss = 1.190495, acc = 20.83%) AAE: (mse = 0.031612, b_ce = 0.031173)
# Epoch: 310 Disc: (loss = 0.971481, acc = 30.00%) AAE: (mse = 0.032842, b_ce = 0.032193)
# ...
# Epoch: 3250 Disc: (loss = 0.000453, acc = 100.00%) AAE: (mse = 0.072651, b_ce = 0.065230)
# Epoch: 3260 Disc: (loss = 0.003970, acc = 99.58%) AAE: (mse = 0.069526, b_ce = 0.062257)
# Epoch: 3270 Disc: (loss = 0.000665, acc = 100.00%) AAE: (mse = 0.073223, b_ce = 0.066039)
# Epoch: 3280 Disc: (loss = 0.001605, acc = 100.00%) AAE: (mse = 0.064974, b_ce = 0.057934)
# Epoch: 3290 Disc: (loss = 0.000453, acc = 100.00%) AAE: (mse = 0.070860, b_ce = 0.063449)
# Epoch: 3300 Disc: (loss = 0.000303, acc = 100.00%) AAE: (mse = 0.066784, b_ce = 0.059161)
# Epoch: 3310 Disc: (loss = 0.000409, acc = 100.00%) AAE: (mse = 0.070685, b_ce = 0.063141)
# Epoch: 3320 Disc: (loss = 0.000615, acc = 100.00%) AAE: (mse = 0.065862, b_ce = 0.058366)
# Epoch: 3330 Disc: (loss = 0.000585, acc = 100.00%) AAE: (mse = 0.061683, b_ce = 0.053458)
# Epoch: 3340 Disc: (loss = 0.002309, acc = 100.00%) AAE: (mse = 0.064398, b_ce = 0.056941)
# Epoch: 3350 Disc: (loss = 0.000286, acc = 100.00%) AAE: (mse = 0.069531, b_ce = 0.061632)
# Epoch: 3360 Disc: (loss = 0.000217, acc = 100.00%) AAE: (mse = 0.069658, b_ce = 0.061425)
# Epoch: 3370 Disc: (loss = 0.000322, acc = 100.00%) AAE: (mse = 0.065901, b_ce = 0.057830)
# Epoch: 3380 Disc: (loss = 0.000264, acc = 100.00%) AAE: (mse = 0.071035, b_ce = 0.062743)
# Epoch: 3390 Disc: (loss = 0.001125, acc = 100.00%) AAE: (mse = 0.066164, b_ce = 0.058658)
# Epoch: 3400 Disc: (loss = 0.000324, acc = 100.00%) AAE: (mse = 0.068797, b_ce = 0.060573)
# Epoch: 3410 Disc: (loss = 0.000664, acc = 100.00%) AAE: (mse = 0.068935, b_ce = 0.061814)
# Epoch: 3420 Disc: (loss = 0.000514, acc = 100.00%) AAE: (mse = 0.069497, b_ce = 0.062173)
# Epoch: 3430 Disc: (loss = 0.001099, acc = 100.00%) AAE: (mse = 0.068006, b_ce = 0.060622)
# Epoch: 3440 Disc: (loss = 0.012505, acc = 99.58%) AAE: (mse = 0.066081, b_ce = 0.059201)
# Epoch: 3450 Disc: (loss = 0.004306, acc = 99.58%) AAE: (mse = 0.069572, b_ce = 0.062232)
# Epoch: 3460 Disc: (loss = 0.003218, acc = 100.00%) AAE: (mse = 0.072298, b_ce = 0.064428)
# Epoch: 3470 Disc: (loss = 0.011391, acc = 99.58%) AAE: (mse = 0.065530, b_ce = 0.058130)
# Epoch: 3480 Disc: (loss = 0.003146, acc = 100.00%) AAE: (mse = 0.069744, b_ce = 0.061739)
# Epoch: 3490 Disc: (loss = 0.000426, acc = 100.00%) AAE: (mse = 0.067866, b_ce = 0.060235)
# Epoch: 3500 Disc: (loss = 0.002496, acc = 100.00%) AAE: (mse = 0.064854, b_ce = 0.057257)
# Epoch: 3510 Disc: (loss = 0.000369, acc = 100.00%) AAE: (mse = 0.063497, b_ce = 0.055669)
# Epoch: 3520 Disc: (loss = 0.000691, acc = 100.00%) AAE: (mse = 0.064134, b_ce = 0.057024)
# Epoch: 3530 Disc: (loss = 0.001074, acc = 100.00%) AAE: (mse = 0.069721, b_ce = 0.062152)
# Epoch: 3540 Disc: (loss = 0.000824, acc = 100.00%) AAE: (mse = 0.069345, b_ce = 0.062254)
# Epoch: 3550 Disc: (loss = 0.001276, acc = 100.00%) AAE: (mse = 0.061202, b_ce = 0.054015)
# Epoch: 3560 Disc: (loss = 0.000367, acc = 100.00%) AAE: (mse = 0.062924, b_ce = 0.055324)
# Epoch: 3570 Disc: (loss = 0.000662, acc = 100.00%) AAE: (mse = 0.061874, b_ce = 0.054325)
# Epoch: 3580 Disc: (loss = 0.000333, acc = 100.00%) AAE: (mse = 0.069542, b_ce = 0.061986)
# Epoch: 3590 Disc: (loss = 0.000781, acc = 100.00%) AAE: (mse = 0.070657, b_ce = 0.063432)
# Epoch: 3600 Disc: (loss = 0.000544, acc = 100.00%) AAE: (mse = 0.066946, b_ce = 0.059605)
# Epoch: 3610 Disc: (loss = 0.001574, acc = 100.00%) AAE: (mse = 0.070273, b_ce = 0.063115)
# Epoch: 3620 Disc: (loss = 0.000616, acc = 100.00%) AAE: (mse = 0.067620, b_ce = 0.060555)
# Epoch: 3630 Disc: (loss = 0.000644, acc = 100.00%) AAE: (mse = 0.064939, b_ce = 0.057879)
# Epoch: 3640 Disc: (loss = 0.005506, acc = 99.58%) AAE: (mse = 0.068787, b_ce = 0.061149)
# Epoch: 3650 Disc: (loss = 0.000556, acc = 100.00%) AAE: (mse = 0.063725, b_ce = 0.056580)
# Epoch: 3660 Disc: (loss = 0.000277, acc = 100.00%) AAE: (mse = 0.071097, b_ce = 0.063320)
# Epoch: 3670 Disc: (loss = 0.000423, acc = 100.00%) AAE: (mse = 0.066321, b_ce = 0.058979)
# Epoch: 3680 Disc: (loss = 0.000653, acc = 100.00%) AAE: (mse = 0.064033, b_ce = 0.056974)
# Epoch: 3690 Disc: (loss = 0.000801, acc = 100.00%) AAE: (mse = 0.070132, b_ce = 0.062120)
# Epoch: 3700 Disc: (loss = 0.000490, acc = 100.00%) AAE: (mse = 0.070566, b_ce = 0.062820)
# Epoch: 3710 Disc: (loss = 0.002714, acc = 100.00%) AAE: (mse = 0.063179, b_ce = 0.056605)
# Epoch: 3720 Disc: (loss = 0.000580, acc = 100.00%) AAE: (mse = 0.069336, b_ce = 0.062282)
# Epoch: 3730 Disc: (loss = 0.003560, acc = 100.00%) AAE: (mse = 0.073713, b_ce = 0.065991)
# Epoch: 3740 Disc: (loss = 0.000552, acc = 100.00%) AAE: (mse = 0.067623, b_ce = 0.059999)
# Epoch: 3750 Disc: (loss = 0.000558, acc = 100.00%) AAE: (mse = 0.069541, b_ce = 0.062172)
# Epoch: 3760 Disc: (loss = 0.000985, acc = 100.00%) AAE: (mse = 0.069540, b_ce = 0.062289)
# Epoch: 3770 Disc: (loss = 0.008809, acc = 99.58%) AAE: (mse = 0.067295, b_ce = 0.059963)
# Epoch: 3780 Disc: (loss = 0.014952, acc = 99.58%) AAE: (mse = 0.067843, b_ce = 0.060938)
# Epoch: 3790 Disc: (loss = 0.000872, acc = 100.00%) AAE: (mse = 0.066312, b_ce = 0.059044)
# Epoch: 3800 Disc: (loss = 0.000416, acc = 100.00%) AAE: (mse = 0.065129, b_ce = 0.057353)
# Epoch: 3810 Disc: (loss = 0.000498, acc = 100.00%) AAE: (mse = 0.068592, b_ce = 0.061006)
# Epoch: 3820 Disc: (loss = 0.000700, acc = 100.00%) AAE: (mse = 0.069280, b_ce = 0.061899)
# Epoch: 3830 Disc: (loss = 0.000542, acc = 100.00%) AAE: (mse = 0.066580, b_ce = 0.058757)
# Epoch: 3840 Disc: (loss = 0.018259, acc = 99.58%) AAE: (mse = 0.064438, b_ce = 0.057020)
# Epoch: 3850 Disc: (loss = 0.000765, acc = 100.00%) AAE: (mse = 0.070802, b_ce = 0.063868)
# Epoch: 3860 Disc: (loss = 0.001192, acc = 100.00%) AAE: (mse = 0.060159, b_ce = 0.052706)
# Epoch: 3870 Disc: (loss = 0.000475, acc = 100.00%) AAE: (mse = 0.063416, b_ce = 0.055838)
# Epoch: 3880 Disc: (loss = 0.037796, acc = 99.58%) AAE: (mse = 0.068590, b_ce = 0.061632)
# Epoch: 3890 Disc: (loss = 0.000893, acc = 100.00%) AAE: (mse = 0.068793, b_ce = 0.061690)
# Epoch: 3900 Disc: (loss = 0.000536, acc = 100.00%) AAE: (mse = 0.067896, b_ce = 0.060299)
# Epoch: 3910 Disc: (loss = 0.000216, acc = 100.00%) AAE: (mse = 0.064962, b_ce = 0.056781)
# Epoch: 3920 Disc: (loss = 0.000800, acc = 100.00%) AAE: (mse = 0.065881, b_ce = 0.058602)
# Epoch: 3930 Disc: (loss = 0.000583, acc = 100.00%) AAE: (mse = 0.069352, b_ce = 0.062069)
# Epoch: 3940 Disc: (loss = 0.002917, acc = 100.00%) AAE: (mse = 0.071202, b_ce = 0.063688)
# Epoch: 3950 Disc: (loss = 0.007569, acc = 99.58%) AAE: (mse = 0.071226, b_ce = 0.063470)
# Epoch: 3960 Disc: (loss = 0.000891, acc = 100.00%) AAE: (mse = 0.076061, b_ce = 0.068182)
# Epoch: 3970 Disc: (loss = 0.000309, acc = 100.00%) AAE: (mse = 0.064877, b_ce = 0.056818)
# Epoch: 3980 Disc: (loss = 0.000343, acc = 100.00%) AAE: (mse = 0.071590, b_ce = 0.063606)
# Epoch: 3990 Disc: (loss = 0.000445, acc = 100.00%) AAE: (mse = 0.069401, b_ce = 0.061443)
# Epoch: 4000 Disc: (loss = 0.001469, acc = 100.00%) AAE: (mse = 0.065863, b_ce = 0.058070)
# Epoch: 4010 Disc: (loss = 0.000579, acc = 100.00%) AAE: (mse = 0.069007, b_ce = 0.061303)
# Epoch: 4020 Disc: (loss = 0.000239, acc = 100.00%) AAE: (mse = 0.068097, b_ce = 0.059890)
# Epoch: 4030 Disc: (loss = 0.000384, acc = 100.00%) AAE: (mse = 0.061318, b_ce = 0.053137)
# Epoch: 4040 Disc: (loss = 0.000844, acc = 100.00%) AAE: (mse = 0.066959, b_ce = 0.059720)
# Epoch: 4050 Disc: (loss = 0.000402, acc = 100.00%) AAE: (mse = 0.067581, b_ce = 0.059827)
# Epoch: 4060 Disc: (loss = 0.000460, acc = 100.00%) AAE: (mse = 0.070820, b_ce = 0.063329)
# Epoch: 4070 Disc: (loss = 0.000798, acc = 100.00%) AAE: (mse = 0.069276, b_ce = 0.061792)
# Epoch: 4080 Disc: (loss = 0.000690, acc = 100.00%) AAE: (mse = 0.067890, b_ce = 0.060575)
# Epoch: 4090 Disc: (loss = 0.002764, acc = 100.00%) AAE: (mse = 0.067951, b_ce = 0.060556)
# Epoch: 4100 Disc: (loss = 0.000646, acc = 100.00%) AAE: (mse = 0.073705, b_ce = 0.066153)
# Epoch: 4110 Disc: (loss = 0.000703, acc = 100.00%) AAE: (mse = 0.063301, b_ce = 0.056308)
# Epoch: 4120 Disc: (loss = 0.006470, acc = 99.58%) AAE: (mse = 0.066535, b_ce = 0.059461)
# Epoch: 4130 Disc: (loss = 0.000503, acc = 100.00%) AAE: (mse = 0.067074, b_ce = 0.059534)
# Epoch: 4140 Disc: (loss = 0.000527, acc = 100.00%) AAE: (mse = 0.069206, b_ce = 0.061784)
# Epoch: 4150 Disc: (loss = 0.004694, acc = 100.00%) AAE: (mse = 0.067019, b_ce = 0.059488)
# Epoch: 4160 Disc: (loss = 0.024862, acc = 99.17%) AAE: (mse = 0.064226, b_ce = 0.058063)
# Epoch: 4170 Disc: (loss = 0.000851, acc = 100.00%) AAE: (mse = 0.065792, b_ce = 0.058930)
# Epoch: 4180 Disc: (loss = 0.003817, acc = 99.58%) AAE: (mse = 0.070416, b_ce = 0.063332)
# Epoch: 4190 Disc: (loss = 0.000746, acc = 100.00%) AAE: (mse = 0.064822, b_ce = 0.057560)
# Epoch: 4200 Disc: (loss = 0.000571, acc = 100.00%) AAE: (mse = 0.059891, b_ce = 0.051758)
# Epoch: 4210 Disc: (loss = 0.000734, acc = 100.00%) AAE: (mse = 0.064022, b_ce = 0.056765)
# Epoch: 4220 Disc: (loss = 0.000679, acc = 100.00%) AAE: (mse = 0.063330, b_ce = 0.055597)
# Epoch: 4230 Disc: (loss = 0.000484, acc = 100.00%) AAE: (mse = 0.066844, b_ce = 0.058161)
# Epoch: 4240 Disc: (loss = 0.010490, acc = 99.58%) AAE: (mse = 0.066904, b_ce = 0.059793)
# Epoch: 4250 Disc: (loss = 0.000616, acc = 100.00%) AAE: (mse = 0.071940, b_ce = 0.064759)
# Epoch: 4260 Disc: (loss = 0.002857, acc = 100.00%) AAE: (mse = 0.069231, b_ce = 0.062126)
# Epoch: 4270 Disc: (loss = 0.000632, acc = 100.00%) AAE: (mse = 0.061650, b_ce = 0.054391)
# Epoch: 4280 Disc: (loss = 0.001017, acc = 100.00%) AAE: (mse = 0.075726, b_ce = 0.068434)
# Epoch: 4290 Disc: (loss = 0.000526, acc = 100.00%) AAE: (mse = 0.069230, b_ce = 0.061809)
# Epoch: 4300 Disc: (loss = 0.003071, acc = 100.00%) AAE: (mse = 0.069127, b_ce = 0.061577)
# Epoch: 4310 Disc: (loss = 0.000343, acc = 100.00%) AAE: (mse = 0.070468, b_ce = 0.062772)
# Epoch: 4320 Disc: (loss = 0.000707, acc = 100.00%) AAE: (mse = 0.062988, b_ce = 0.056022)
# Epoch: 4330 Disc: (loss = 0.001177, acc = 100.00%) AAE: (mse = 0.069742, b_ce = 0.063178)
# Epoch: 4340 Disc: (loss = 0.000566, acc = 100.00%) AAE: (mse = 0.068052, b_ce = 0.060714)
# Epoch: 4350 Disc: (loss = 0.000807, acc = 100.00%) AAE: (mse = 0.067157, b_ce = 0.060380)
# Epoch: 4360 Disc: (loss = 0.016730, acc = 99.58%) AAE: (mse = 0.067864, b_ce = 0.060930)
# Epoch: 4370 Disc: (loss = 0.000916, acc = 100.00%) AAE: (mse = 0.062451, b_ce = 0.055132)
# Epoch: 4380 Disc: (loss = 0.001120, acc = 100.00%) AAE: (mse = 0.071113, b_ce = 0.064210)
# Epoch: 4390 Disc: (loss = 0.000760, acc = 100.00%) AAE: (mse = 0.067348, b_ce = 0.060202)
# Epoch: 4400 Disc: (loss = 0.000434, acc = 100.00%) AAE: (mse = 0.070535, b_ce = 0.063101)
# Epoch: 4410 Disc: (loss = 0.001334, acc = 100.00%) AAE: (mse = 0.071166, b_ce = 0.063517)
# Epoch: 4420 Disc: (loss = 0.000247, acc = 100.00%) AAE: (mse = 0.073910, b_ce = 0.065754)
# Epoch: 4430 Disc: (loss = 0.005742, acc = 99.58%) AAE: (mse = 0.069574, b_ce = 0.061772)
# Epoch: 4440 Disc: (loss = 0.000209, acc = 100.00%) AAE: (mse = 0.067770, b_ce = 0.059559)
# Epoch: 4450 Disc: (loss = 0.013637, acc = 99.58%) AAE: (mse = 0.067147, b_ce = 0.058745)
# Epoch: 4460 Disc: (loss = 0.000634, acc = 100.00%) AAE: (mse = 0.065482, b_ce = 0.058252)
# Epoch: 4470 Disc: (loss = 0.000876, acc = 100.00%) AAE: (mse = 0.069745, b_ce = 0.062517)
# Epoch: 4480 Disc: (loss = 0.001130, acc = 100.00%) AAE: (mse = 0.068416, b_ce = 0.061332)
# Epoch: 4490 Disc: (loss = 0.000517, acc = 100.00%) AAE: (mse = 0.073868, b_ce = 0.066409)
# Epoch: 4500 Disc: (loss = 0.000589, acc = 100.00%) AAE: (mse = 0.068445, b_ce = 0.061086)
# Epoch: 4510 Disc: (loss = 0.000238, acc = 100.00%) AAE: (mse = 0.070636, b_ce = 0.062427)
# Epoch: 4520 Disc: (loss = 0.000273, acc = 100.00%) AAE: (mse = 0.064974, b_ce = 0.057110)
# Epoch: 4530 Disc: (loss = 0.000763, acc = 100.00%) AAE: (mse = 0.065538, b_ce = 0.057971)
# Epoch: 4540 Disc: (loss = 0.000763, acc = 100.00%) AAE: (mse = 0.064293, b_ce = 0.056820)
# Epoch: 4550 Disc: (loss = 0.002689, acc = 100.00%) AAE: (mse = 0.067021, b_ce = 0.059745)
# Epoch: 4560 Disc: (loss = 0.000704, acc = 100.00%) AAE: (mse = 0.068839, b_ce = 0.061314)
# Epoch: 4570 Disc: (loss = 0.000394, acc = 100.00%) AAE: (mse = 0.066729, b_ce = 0.058852)
# Epoch: 4580 Disc: (loss = 0.000179, acc = 100.00%) AAE: (mse = 0.062621, b_ce = 0.054408)
# Epoch: 4590 Disc: (loss = 0.000710, acc = 100.00%) AAE: (mse = 0.067761, b_ce = 0.060420)
# Epoch: 4600 Disc: (loss = 0.000641, acc = 100.00%) AAE: (mse = 0.063642, b_ce = 0.056299)
# Epoch: 4610 Disc: (loss = 0.000421, acc = 100.00%) AAE: (mse = 0.064681, b_ce = 0.057164)
# Epoch: 4620 Disc: (loss = 0.000499, acc = 100.00%) AAE: (mse = 0.071294, b_ce = 0.063842)
# Epoch: 4630 Disc: (loss = 0.000257, acc = 100.00%) AAE: (mse = 0.067046, b_ce = 0.058868)
# Epoch: 4640 Disc: (loss = 0.007180, acc = 99.58%) AAE: (mse = 0.070986, b_ce = 0.063604)
# Epoch: 4650 Disc: (loss = 0.000930, acc = 100.00%) AAE: (mse = 0.063484, b_ce = 0.056696)
# Epoch: 4660 Disc: (loss = 0.000437, acc = 100.00%) AAE: (mse = 0.063029, b_ce = 0.055441)
# Epoch: 4670 Disc: (loss = 0.000780, acc = 100.00%) AAE: (mse = 0.068095, b_ce = 0.060693)
# Epoch: 4680 Disc: (loss = 0.001082, acc = 100.00%) AAE: (mse = 0.064417, b_ce = 0.056915)
# Epoch: 4690 Disc: (loss = 0.000386, acc = 100.00%) AAE: (mse = 0.066975, b_ce = 0.059240)
# Epoch: 4700 Disc: (loss = 0.000315, acc = 100.00%) AAE: (mse = 0.066052, b_ce = 0.057804)
# Epoch: 4710 Disc: (loss = 0.005191, acc = 99.58%) AAE: (mse = 0.064591, b_ce = 0.056870)
# Epoch: 4720 Disc: (loss = 0.000588, acc = 100.00%) AAE: (mse = 0.072838, b_ce = 0.065249)
# Epoch: 4730 Disc: (loss = 0.000703, acc = 100.00%) AAE: (mse = 0.066592, b_ce = 0.059014)
# Epoch: 4740 Disc: (loss = 0.018866, acc = 99.58%) AAE: (mse = 0.074129, b_ce = 0.066760)
# Epoch: 4750 Disc: (loss = 0.006427, acc = 99.58%) AAE: (mse = 0.067622, b_ce = 0.060549)
# Epoch: 4760 Disc: (loss = 0.000759, acc = 100.00%) AAE: (mse = 0.065804, b_ce = 0.058799)
# Epoch: 4770 Disc: (loss = 0.000805, acc = 100.00%) AAE: (mse = 0.069161, b_ce = 0.062029)
# Epoch: 4780 Disc: (loss = 0.000611, acc = 100.00%) AAE: (mse = 0.067082, b_ce = 0.059970)
# Epoch: 4790 Disc: (loss = 0.000558, acc = 100.00%) AAE: (mse = 0.068016, b_ce = 0.060168)
# Epoch: 4800 Disc: (loss = 0.000245, acc = 100.00%) AAE: (mse = 0.069376, b_ce = 0.061070)
# Epoch: 4810 Disc: (loss = 0.001176, acc = 100.00%) AAE: (mse = 0.063010, b_ce = 0.054519)
# Epoch: 4820 Disc: (loss = 0.000175, acc = 100.00%) AAE: (mse = 0.070719, b_ce = 0.062318)
# Epoch: 4830 Disc: (loss = 0.000385, acc = 100.00%) AAE: (mse = 0.071327, b_ce = 0.063347)
# Epoch: 4840 Disc: (loss = 0.000441, acc = 100.00%) AAE: (mse = 0.067251, b_ce = 0.059946)
# Epoch: 4850 Disc: (loss = 0.001193, acc = 100.00%) AAE: (mse = 0.066090, b_ce = 0.058961)
# Epoch: 4860 Disc: (loss = 0.000574, acc = 100.00%) AAE: (mse = 0.064120, b_ce = 0.056606)
# Epoch: 4870 Disc: (loss = 0.000492, acc = 100.00%) AAE: (mse = 0.068336, b_ce = 0.060913)
# Epoch: 4880 Disc: (loss = 0.000960, acc = 100.00%) AAE: (mse = 0.065958, b_ce = 0.058743)
# Epoch: 4890 Disc: (loss = 0.000572, acc = 100.00%) AAE: (mse = 0.071056, b_ce = 0.063844)
# Epoch: 4900 Disc: (loss = 0.000769, acc = 100.00%) AAE: (mse = 0.066013, b_ce = 0.058797)
# Epoch: 4910 Disc: (loss = 0.000860, acc = 100.00%) AAE: (mse = 0.063972, b_ce = 0.057050)
# Epoch: 4920 Disc: (loss = 0.000353, acc = 100.00%) AAE: (mse = 0.068092, b_ce = 0.060410)
# Epoch: 4930 Disc: (loss = 0.000601, acc = 100.00%) AAE: (mse = 0.070714, b_ce = 0.062920)
# Epoch: 4940 Disc: (loss = 0.000458, acc = 100.00%) AAE: (mse = 0.063933, b_ce = 0.056447)
# Epoch: 4950 Disc: (loss = 0.003120, acc = 100.00%) AAE: (mse = 0.066132, b_ce = 0.058520)
# Epoch: 4960 Disc: (loss = 0.000429, acc = 100.00%) AAE: (mse = 0.071510, b_ce = 0.063655)
# Epoch: 4970 Disc: (loss = 0.000255, acc = 100.00%) AAE: (mse = 0.069904, b_ce = 0.061998)
# Epoch: 4980 Disc: (loss = 0.000662, acc = 100.00%) AAE: (mse = 0.066465, b_ce = 0.058999)
# Epoch: 4990 Disc: (loss = 0.000504, acc = 100.00%) AAE: (mse = 0.071036, b_ce = 0.063793)
# Epoch: 5000 Disc: (loss = 0.000555, acc = 100.00%) AAE: (mse = 0.065709, b_ce = 0.058364)
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
